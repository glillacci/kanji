# %% [markdown]
# # Create kanji flashcards

# %%
import datetime
import hashlib
import numpy as np
import pandas as pd

# %%
(datetime.date(2021, 12, 1) - datetime.date.today()).days * 20
# Out:
# 2720

# %%
DATA_PATH = '/Users/gabriele/OneDrive - Tesco/Personal/Data/kanjidata'

# %% [markdown]
# ## Select flashcard set to produce based on grade

# %%
GRADE_SETTINGS = {
    1: '１年生',
    2: '２年生',
    3: '３年生',
    4: '４年生',
    5: '５年生',
    6: '６年生',
    8.1: '常用ー漢検４級',
    8.2: '常用ー漢検３級',
    8.3: '常用ー漢検準２級',
    8.4: '常用ー漢検２級',
    9.1: '人名用ー日本語能力試験１級'
}

SET_NUMBER = 8.4

GRADE = GRADE_SETTINGS[SET_NUMBER]

# %% [markdown]
# ## Load Kanjidic with additional data

# %%
kanji = pd.read_parquet(f'{DATA_PATH}/kanjidic_with_additional_data.parquet')

kanji = kanji[['kanji', 'stroke_count', 'grade', 'jlpt_level', 'onyomi', 'kunyomi',
               'nanori', 'n_onyomi', 'n_onyomi_in_jouyou', 'n_kunyomi', 'n_kunyomi_in_jouyou',
               'n_kunyomi_distinct', 'n_nanori', 'skip_code_corrected', 'kkld_no', 'kkd_no',
               'core_meaning_1', 'core_meaning_2', 'core_meaning_3',
               'radical_element', 'rad_names', 'non_rad_strokes', 'jis_level', 'unicode']]

kanji = kanji.rename({
    'skip_code_corrected': 'skip_code'
}, axis=1)

kanji['jlpt_level'] = kanji['jlpt_level'].fillna(0).astype(int)
kanji['kkld_no'] = kanji['kkld_no'].fillna(0).astype(int)
kanji['kkd_no'] = kanji['kkd_no'].fillna(0).astype(int)

kanji.sample(frac=0.001)
# Out:
#       kanji  stroke_count     grade  jlpt_level            onyomi  \
# 8015      斦             8   11(nan)           0  [ギン, ゴン, シツ, シチ]
# 6376      乣             4   11(nan)           0             [キュウ]
# 12244     𣏓             7   11(nan)           0              None
# 10202     蓀            13   11(nan)           0              [ソン]
# 11640     顥            21   11(nan)           0              [コウ]
# 1953      定             8       ３年生           2         [テイ, ジョウ]
# 10001     臽             8   11(nan)           0      [カン, ゲン, コン]
# 8378      櫖            19   11(nan)           0           [リョ, ロ]
# 6785      叀             8   11(nan)           0              [セン]
# 4300      浚            10   11(1.0)           0             [シュン]
# 2894      鈴            13  常用ー漢検準２級           1          [レイ, リン]
# 3799      懴            18   11(1.0)           0          [ザン, サン]
# 2792      翼            17   常用ー漢検４級           1              [ヨク]
#
#                     kunyomi nanori  n_onyomi  n_onyomi_in_jouyou  n_kunyomi  \
# 8015                [あき.らか]   None         4                   0          1
# 6376                   None   None         1                   0          0
# 12244                  None   None         0                   0          0
# 10202                  None   None         1                   0          0
# 11640                [しろ.い]   None         1                   0          1
# 1953   [さだ.める, さだ.まる, さだ.か]   [さた]         2                   2          3
# 10001               [おとしあな]   None         3                   0          1
# 8378                   [ふざ]   None         2                   0          1
# 6785          [つつし.む, か.ける]   None         1                   0          2
# 4300          [さら.える, さら.う]   None         1                   0          2
# 2894                   [すず]    [ず]         2                   2          1
# 3799                 [くい.る]   None         2                   0          1
# 2792                  [つばさ]   None         1                   1          1
#
#        ...  kkld_no  kkd_no  core_meaning_1 core_meaning_2  core_meaning_3  \
# 8015   ...        0       0            None           None            None
# 6376   ...        0       0            None           None            None
# 12244  ...        0       0            None           None            None
# 10202  ...        0       0            None           None            None
# 11640  ...        0       0            None           None            None
# 1953   ...     1420    2770             fix           None            None
# 10001  ...        0       0            None           None            None
# 8378   ...        0       0            None           None            None
# 6785   ...        0       0            None           None            None
# 4300   ...        0       0            None           None            None
# 2894   ...     1125    2146            bell           None            None
# 3799   ...        0       0            None           None            None
# 2792   ...     1745    3379            wing           None            None
#
#        radical_element rad_names non_rad_strokes jis_level unicode
# 8015              None      None               0         0    65A6
# 6376              None      None               0         0    4E63
# 12244             None      None               0         0   233D3
# 10202             None      None               0         0    84C0
# 11640             None      None               0         0    9865
# 1953                 ⼧     うかんむり               5         1    5B9A
# 10001             None      None               0         0    81FD
# 8378              None      None               0         0    6AD6
# 6785              None      None               0         0    53C0
# 4300              None      None               0         2    6D5A
# 2894               「金」      かねへん               5         1    9234
# 3799              None      None               0         2    61F4
# 2792                 ⽻        はね              11         1    7FFC
#
# [13 rows x 24 columns]

# %% [markdown]
# ## Create the desired set of flashcards

# %%
subset = (
    kanji.loc[kanji['grade'] == GRADE]
).copy()

# %% [markdown]
# ## Expand the readings

# %%
def expand_readings(x):
    if x is None:
        return None
    
    if len(x):
        jouyou = []
        non_jouyou = []
        
        for reading in x:
            if '[' in reading:
                non_jouyou.append(reading[1:-1])
            else:
                jouyou.append(reading)

        if len(jouyou) and len(non_jouyou):
            return f"{', '.join(jouyou)}, [{', '.join(non_jouyou)}]"
        elif len(jouyou):
            return ', '.join(jouyou)
        else:
            return f"[{', '.join(non_jouyou)}]"
        
    return None

# %%
subset['onyomi'] = subset['onyomi'].apply(expand_readings)
subset['kunyomi'] = subset['kunyomi'].apply(expand_readings)
subset['nanori'] = subset['nanori'].apply(expand_readings)

# %%
subset
# Out:
#       kanji  stroke_count    grade  jlpt_level     onyomi  \
# 6         挨            10  常用ー漢検２級           0         アイ
# 23        宛             8  常用ー漢検２級           0       [エン]
# 38        闇            17  常用ー漢検２級           0   [アン, オン]
# 55        椅            12  常用ー漢検２級           0          イ
# 57        畏             9  常用ー漢検２級           0          イ
# ...     ...           ...      ...         ...        ...
# 5699      踪            15  常用ー漢検２級           0  ソウ, [ショウ]
# 5759      辣            14  常用ー漢検２級           0         ラツ
# 5878      錮            16  常用ー漢検２級           0          コ
# 7126      塡            13  常用ー漢検２級           0   テン, [チン]
# 11622     頰            16  常用ー漢検２級           0      [キョウ]
#
#                            kunyomi nanori  n_onyomi  n_onyomi_in_jouyou  \
# 6                           [ひら.く]   None         1                   1
# 23         あ.てる, [-あて, -づつ, あたか.も]   None         1                   0
# 38                      やみ, [くら.い]   None         2                   0
# 55                            None   None         1                   1
# 57     おそ.れる, [かしこま.る, かしこ, かしこ.し]   None         1                   1
# ...                            ...    ...       ...                 ...
# 5699                          [あと]   None         2                   1
# 5759                        [から.い]   None         1                   1
# 5878                        [ふさ.ぐ]   None         1                   1
# 7126     [はま.る, うず.める, は.める, ふさ.ぐ]   None         2                   1
# 11622                     ほお, [ほほ]   None         1                   0
#
#        n_kunyomi  ...  kkld_no  kkd_no  core_meaning_1 core_meaning_2  \
# 6              1  ...        0     510            push           None
# 23             4  ...        0    2762         address           None
# 38             2  ...        0    4134            dark           None
# 55             0  ...        0    1239           chair           None
# 57             4  ...        0    3170     be overawed           None
# ...          ...  ...      ...     ...             ...            ...
# 5699           1  ...        0    1996      footprints           None
# 5759           1  ...        0    1965         pungent         severe
# 5878           1  ...        0    2182        imprison           None
# 7126           4  ...        0     777            fill           None
# 11622          2  ...        0    2043           cheek           None
#
#        core_meaning_3  radical_element      rad_names non_rad_strokes  \
# 6                None                ⺘            てへん               7
# 23               None                ⼧          うかんむり               5
# 38               None                ⾨  もん（がまえ）・かどがまえ               9
# 55               None              「木」            きへん               8
# 57               None                ⽥              た               4
# ...               ...              ...            ...             ...
# 5699             None                ⻊           あしへん               8
# 5759             None                ⾟         しん・からい               7
# 5878             None              「金」           かねへん               8
# 7126             None              「土」       「つち・ど」へん              10
# 11622            None                ⾴     おおがい・いちのかい               7
#
#       jis_level unicode
# 6             1    6328
# 23            1    5B9B
# 38            1    95C7
# 55            1    6905
# 57            1    754F
# ...         ...     ...
# 5699          2    8E2A
# 5759          2    8FA3
# 5878          2    932E
# 7126          0    5861
# 11622         0    9830
#
# [185 rows x 24 columns]

# %% [markdown]
# ## Add unique id

# %%
def create_kanji_id(kanji):
    return hashlib.sha1(kanji.encode('utf-8')).hexdigest()

# %%
subset['id'] = subset['kanji'].apply(create_kanji_id)

# %% [markdown]
# ## Export final results

# %%
subset = subset[['id', 'kanji', 'stroke_count', 'grade', 'jlpt_level', 'onyomi', 'kunyomi',
                 'nanori', 'n_onyomi', 'n_onyomi_in_jouyou', 'n_kunyomi', 'n_kunyomi_in_jouyou',
                 'n_kunyomi_distinct', 'n_nanori', 'skip_code', 'kkld_no', 'kkd_no',
                 'core_meaning_1', 'core_meaning_2', 'core_meaning_3',
                 'radical_element', 'rad_names', 'non_rad_strokes']]

# %%
assert np.sum(subset['id'].duplicated()) == 0

# %%
len(subset)
# Out:
# 185

# %%
subset.sample(n=10)
# Out:
#                                             id kanji  stroke_count    grade  \
# 2023  7a84fc225b6f4e77325e49d2f122927fce5dab91     賭            15  常用ー漢検２級
# 847   f2717ed4bf371959408d5fd0235d02dd989b9fca     喉            12  常用ー漢検２級
# 1629  084876f53d6ef629baa151c8a3176c8dddc5f307     狙             8  常用ー漢検２級
# 1035  fe07b4546e7baedf59ed01a3b2dfb8a85231787a     拶             9  常用ー漢検２級
# 1971  e3d09e6db771fe73d8b43b81b50bda3af9718fa8     諦            16  常用ー漢検２級
# 873   4a2f2d900c50ad38dffc28860968eace086d2e37     梗            11  常用ー漢検２級
# 613   d4cb222f86c963ea2623b3d85f1fc11673c450f2     巾             3  常用ー漢検２級
# 782   39a177844226c13af1a307f423fd8ef654eab7e4     舷            11  常用ー漢検２級
# 38    0e9f166c7e132f194a7fc4bd27e01274334d94b9     闇            17  常用ー漢検２級
# 433   f7eec70f868b2c9e4822f503c2dcc2760e332c24     韓            18  常用ー漢検２級
#
#       jlpt_level     onyomi               kunyomi nanori  n_onyomi  \
# 2023           0          ト            か.ける, [かけ]   None         1
# 847            0         コウ                    のど   None         1
# 1629           0    ソ, [ショ]          ねら.う, [ねら.い]   None         2
# 1035           0         サツ                [せま.る]   None         1
# 1971           0   テイ, [タイ]  あきら.める, [つまびらか, まこと]   None         2
# 873            0  コウ, [キョウ]     [ふさぐ, やまにれ, おおむね]   None         2
# 613            0   キン, [フク]       [おお.い, ちきり, きれ]   None         2
# 782            0         ゲン          [ふなばた, ふなべり]   None         1
# 38             0   [アン, オン]            やみ, [くら.い]   None         2
# 433            0         カン             [から, いげた]   None         1
#
#       n_onyomi_in_jouyou  ...  n_nanori  skip_code  kkld_no  kkd_no  \
# 2023                   1  ...         0      1-7-9        0    2021
# 847                    1  ...         0      1-3-9        0     669
# 1629                   1  ...         0      1-3-5        0     406
# 1035                   1  ...         0      1-3-6        0     451
# 1971                   1  ...         0      1-7-9        0    2010
# 873                    1  ...         0      1-4-7        0    1204
# 613                    1  ...         0      4-3-3        0    4217
# 782                    1  ...         0      1-6-5        0    1698
# 38                     0  ...         0      3-8-9        0    4134
# 433                    1  ...         0     1-8-10        0    2218
#
#      core_meaning_1  core_meaning_2  core_meaning_3 radical_element  \
# 2023          wager            None            None             「貝」
# 847          throat            None            None             「⼝」
# 1629            aim            None            None               ⺨
# 1035          press            None            None               ⺘
# 1971        give up            None            None             「言」
# 873         stop up            None            None             「木」
# 613           cloth            None            None               ⼱
# 782         gunwale            None            None             「⾈」
# 38             dark            None            None               ⾨
# 433     South Korea            None            None               ⾱
#
#           rad_names non_rad_strokes
# 2023           かいへん               8
# 847            くちへん               9
# 1629          けものへん               5
# 1035            てへん               6
# 1971           ごんべん               9
# 873             きへん               7
# 613              はば               0
# 782            ふねへん               5
# 38    もん（がまえ）・かどがまえ               9
# 433           なめしがわ               8
#
# [10 rows x 23 columns]

# %%
subset.to_csv(f'{DATA_PATH}/kanji_flashcards_{GRADE}.csv', index=False, header=False)

f'{DATA_PATH}/kanji_flashcards_{GRADE}.csv'
# Out:
# '/Users/gabriele/OneDrive - Tesco/Personal/Data/kanjidata/kanji_flashcards_常用ー漢検２級.csv'
