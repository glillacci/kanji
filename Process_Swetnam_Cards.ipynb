# %% [markdown]
# # Process Swetnam Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_LESSON = 7

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'swetnam_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'swetnam_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#       greek remarks_greek                    italian  \
# 82      ἐγώ           NaN                         io
# 79  Ἀνδρέας        -ου, ὁ                     Andrea
# 44  ἁμαρτία        -ας, ἡ     peccato; colpa; errore
# 99      γάρ           NaN  infatti, poiché, dato che
# 89  θάνατος        -ου, ὁ                      morte
#
#                                       remarks_italian part_of_speech  lesson
# 82                                                NaN        pronome       6
# 79                                                NaN     sostantivo       6
# 44                                                NaN     sostantivo       4
# 99  pospositiva = non si incontra mai all’inizio d...   congiunzione       7
# 89                                                NaN     sostantivo       7

# %%
df_grammar = df_grammar.loc[df_grammar['lesson'] <= MAX_LESSON].copy()
df_grammar['lesson'] = df_grammar['lesson'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                               prompt remarks_prompt   answer remarks_answer  \
# 122              santo (voc. m. sg.)          ἅγιος     ἅγιε            NaN
# 55    pronome relativo (dat. f. sg.)       ὅς, ἥ, ὅ        ᾗ            NaN
# 145              santo (dat. n. pl.)          ἅγιος   ἁγίοις            NaN
# 282  a te (dat. sg., forma completa)             σύ      σοί            NaN
# 174              buono (dat. f. pl.)         ἀγαθός  ἀγαθαῖς            NaN
#
#      lesson                           topic
# 122       4   declinazione di ἅγιος [Agg 2]
# 55        3                pronome relativo
# 145       4   declinazione di ἅγιος [Agg 2]
# 282       7        declinazione di σύ [Prn]
# 174       4  declinazione di ἀγαθός [Agg 1]

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['greek'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, lesson, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'greek', 'remarks_greek', 'italian', 'remarks_italian',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                           id      greek remarks_greek  \
# 36  6790c22aabb7c60d9ad32e2a22406654f59774a6        ἀπό           NaN
# 94  c9cad329188736be71373c074d92fd38ca97585a      ὄχλος        -ου, ὁ
# 77  853b41f57f22b719f3b21faa3235d6ea743b365f  ὑποκριτής        -οῦ, ὁ
# 87  d8febc493337663923dd108f965de3229fa8f718      ἄρτος        -ου, ὁ
# 3   99ec2466d17dd12b213fa0c2baeccf77ccc4b0e6    ἔρχεται           NaN
# 29  cf7acec492926850ec1d382db8d01bd46c1ebe0a      ἴδιος       -α, -ον
# 93  e9a5979a846638303e4bdc72311e744afc8c12dc   ὀφθαλμός        -οῦ, ὁ
# 44  9d5d7cc93db6b1feff2fd392d2dcb294ffddccfb    ἁμαρτία        -ας, ἡ
# 74  86c9fd17f95bde48f7d990bb49045d02368a94f1    μαθητής        -οῦ, ὁ
# 79  800596c288a2855296c3ad84e00f4199932ac644    Ἀνδρέας        -ου, ὁ
#
#                                italian            remarks_italian  \
# 36                        (lontano) da           regge sempre gen
# 94                  folla, moltitudine                        NaN
# 77                    ipocrita; attore                        NaN
# 87                          pane, cibo  pl. = pani, pezzi di pane
# 3                viene, arriva, giunge                        NaN
# 29  proprio, personale, appartenente a                        NaN
# 93                              occhio                        NaN
# 44              peccato; colpa; errore                        NaN
# 74                           discepolo                        NaN
# 79                              Andrea                        NaN
#
#    part_of_speech  lesson last_updated_on
# 36   preposizione       4      2022-04-19
# 94     sostantivo       7      2022-04-19
# 77     sostantivo       6      2022-04-19
# 87     sostantivo       7      2022-04-19
# 3           verbo       2      2022-04-19
# 29      aggettivo       3      2022-04-19
# 93     sostantivo       7      2022-04-19
# 44     sostantivo       4      2022-04-19
# 74     sostantivo       6      2022-04-19
# 79     sostantivo       6      2022-04-19

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'lesson', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                            id                          prompt  \
# 168  0d8438cdda2021dcbdc2ef56983216c6ec6bc98a             buono (voc. f. pl.)
# 170  b656929021ac110615f0222d2543de40f89bf93a             buono (gen. m. pl.)
# 67   dcad5441cb65c47dd093ecbb15e14bb005361717  pronome relativo (dat. f. pl.)
# 204  7efc7dc510d6c0bc7117d70b98e2ef0cff1f01b3            questo (dat. f. pl.)
# 190  b6ac2fd2a4ad1f95cf7c3aa9edd0842ead581ac0            questo (gen. n. sg.)
# 79   950b38b8f4e36409822e87a2ccb900a615d246cc               lavoro (gen. pl.)
# 23   8959920daca569d74cd16c871a2c6a5dbbe491e5          articolo (gen. n. pl.)
# 59   224d3ae9dc4ac1b1e5030e039b38e42c87292511  pronome relativo (acc. n. sg.)
# 248  ec62e5c8cad5978b852f4692ceecd6e42d82f1c9                  noi (acc. pl.)
# 105  0e1b588bc6ca94e0ea76b758fe6366f86c22e936              peccato (voc. pl.)
#
#     remarks_prompt    answer remarks_answer  lesson  \
# 168         ἀγαθός    ἀγαθαί            NaN       4
# 170         ἀγαθός    ἀγαθῶν            NaN       4
# 67        ὅς, ἥ, ὅ       αἷς            NaN       3
# 204          οὗτος   ταύταις            NaN       5
# 190          οὗτος    τούτου            NaN       5
# 79        τό ἔργον     ἔργων            NaN       3
# 23        ὁ, ἡ, τό       τῶν            NaN       2
# 59        ὅς, ἥ, ὅ         ὅ            NaN       3
# 248            ἐγώ      ἡμᾶς            NaN       6
# 105      ἡ ἁμαρτία  ἁμαρτίαι            NaN       4
#
#                                  topic last_updated_on
# 168     declinazione di ἀγαθός [Agg 1]      2022-04-19
# 170     declinazione di ἀγαθός [Agg 1]      2022-04-19
# 67                    pronome relativo      2022-04-19
# 204  declinazione di οὗτος [Agg 1 Prn]      2022-04-19
# 190  declinazione di οὗτος [Agg 1 Prn]      2022-04-19
# 79       declinazione di ἔργον [Sst 7]      2022-04-19
# 23                            articolo      2022-04-19
# 59                    pronome relativo      2022-04-19
# 248          declinazione di ἐγώ [Prn]      2022-04-19
# 105    declinazione di ἁμαρτία [Sst 2]      2022-04-19

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_swetnam_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 100

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_swetnam_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 290
