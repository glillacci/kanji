# %% [markdown]
# # Create kanji flashcards

# %%
import datetime
import hashlib
import numpy as np
import pandas as pd

# %%
(datetime.date(2021, 12, 1) - datetime.date.today()).days * 20
# Out:
# 2860

# %% [markdown]
# ## Select flashcard set to produce based on grade

# %%
GRADE_SETTINGS = {
    1: '１年生',
    2: '２年生',
    3: '３年生',
    4: '４年生',
    5: '５年生',
    6: '６年生',
    8.1: '常用ー漢検４級',
    8.2: '常用ー漢検３級',
    8.3: '常用ー漢検準２級',
    8.4: '常用ー漢検２級',
    9.1: '人名用ー日本語能力試験１級'
}

SET_NUMBER = 8.4

GRADE = GRADE_SETTINGS[SET_NUMBER]

# %% [markdown]
# ## Load Kanjidic with additional data

# %%
kanji = pd.read_parquet('./data/kanjidic_with_additional_data.parquet')

kanji = kanji[['kanji', 'stroke_count', 'grade', 'jlpt_level', 'onyomi', 'kunyomi',
               'nanori', 'n_onyomi', 'n_onyomi_in_jouyou', 'n_kunyomi', 'n_kunyomi_in_jouyou',
               'n_kunyomi_distinct', 'n_nanori', 'skip_code_corrected', 'kkld_no', 'kkd_no',
               'core_meaning_1', 'core_meaning_2', 'core_meaning_3',
               'radical_element', 'rad_names', 'non_rad_strokes', 'jis_level', 'unicode']]

kanji = kanji.rename({
    'skip_code_corrected': 'skip_code'
}, axis=1)

kanji['jlpt_level'] = kanji['jlpt_level'].fillna(0).astype(int)
kanji['kkld_no'] = kanji['kkld_no'].fillna(0).astype(int)
kanji['kkd_no'] = kanji['kkd_no'].fillna(0).astype(int)

kanji.sample(frac=0.001)
# Out:
#       kanji  stroke_count    grade  jlpt_level             onyomi  \
# 11010     逩            11  11(nan)           0           [ホン, カム]
# 4285      泪             8  11(1.0)           0           [ルイ, レイ]
# 7650      恱             9  11(nan)           0           [エツ, エチ]
# 11034     邌            18  11(nan)           0     [レイ, ライ, チ, ジ]
# 5850      鈞            12  11(1.0)           0               [キン]
# 6475      俉             9  11(nan)           0                [ゴ]
# 1757      隊            12      ４年生           1               [タイ]
# 11855     魿            16  11(nan)           0      [レイ, リョウ, リン]
# 12415     𨫍            18  11(nan)           0               None
# 11152     釓             9  11(nan)           0  [ヒュウ, グ, キュウ, ワン]
# 6606      儳            19  11(nan)           0               [サン]
# 407       汗             6  常用ー漢検４級           2               [カン]
# 6410      伒             6  11(nan)           0           [キン, コン]
#
#                    kunyomi    nanori  n_onyomi  n_onyomi_in_jouyou  n_kunyomi  \
# 11010               [はし.る]      None         2                   0          1
# 4285                 [なみだ]      None         2                   0          1
# 7650       [よろこ.ぶ, よろこ.ばす]  [のぶ, よし]         2                   0          2
# 11034     [ね.る, おもむろ, おそい]      None         4                   0          3
# 5850               [ひと.しい]      None         1                   0          1
# 6475          [むか.える, あ.う]      None         1                   0          2
# 1757                  None      None         1                   1          0
# 11855          [う.ねる, うろこ]      None         3                   0          2
# 12415                 None      None         0                   0          0
# 11152               [いしゆみ]      None         4                   0          1
# 6606   [ととのわぬ, はや.い, わる.い]      None         1                   0          3
# 407                   [あせ]      None         1                   1          1
# 6410               [たす.ける]      None         2                   0          1
#
#        ...  kkld_no  kkd_no  core_meaning_1 core_meaning_2  core_meaning_3  \
# 11010  ...        0       0            None           None            None
# 4285   ...        0     403            tear           None            None
# 7650   ...        0       0            None           None            None
# 11034  ...        0       0            None           None            None
# 5850   ...        0       0            None           None            None
# 6475   ...        0       0            None           None            None
# 1757   ...      452     762           party           None            None
# 11855  ...        0       0            None           None            None
# 12415  ...        0       0            None           None            None
# 11152  ...        0       0            None           None            None
# 6606   ...        0       0            None           None            None
# 407    ...      161     256           sweat           None            None
# 6410   ...        0       0            None           None            None
#
#        radical_element rad_names non_rad_strokes jis_level unicode
# 11010             None      None               0         0    9029
# 4285                 ⺡      さんずい               5         2    6CEA
# 7650              None      None               0         0    6071
# 11034             None      None               0         0    908C
# 5850              None      None               0         2    921E
# 6475              None      None               0         0    4FC9
# 1757                 ⻖     こざとへん               9         1    968A
# 11855             None      None               0         0    9B7F
# 12415             None      None               0         0   28ACD
# 11152             None      None               0         0    91D3
# 6606              None      None               0         0    5133
# 407                  ⺡      さんずい               3         1    6C57
# 6410              None      None               0         0    4F12
#
# [13 rows x 24 columns]

# %% [markdown]
# ## Create the desired set of flashcards

# %%
subset = (
    kanji.loc[kanji['grade'] == GRADE]
).copy()

# %% [markdown]
# ## Expand the readings

# %%
def expand_readings(x):
    if x is None:
        return None
    
    if len(x):
        jouyou = []
        non_jouyou = []
        
        for reading in x:
            if '[' in reading:
                non_jouyou.append(reading[1:-1])
            else:
                jouyou.append(reading)

        if len(jouyou) and len(non_jouyou):
            return f"{', '.join(jouyou)}, [{', '.join(non_jouyou)}]"
        elif len(jouyou):
            return ', '.join(jouyou)
        else:
            return f"[{', '.join(non_jouyou)}]"
        
    return None

# %%
subset['onyomi'] = subset['onyomi'].apply(expand_readings)
subset['kunyomi'] = subset['kunyomi'].apply(expand_readings)
subset['nanori'] = subset['nanori'].apply(expand_readings)

# %%
subset
# Out:
#       kanji  stroke_count    grade  jlpt_level     onyomi  \
# 6         挨            10  常用ー漢検２級           0         アイ
# 23        宛             8  常用ー漢検２級           0       [エン]
# 38        闇            17  常用ー漢検２級           0   [アン, オン]
# 55        椅            12  常用ー漢検２級           0          イ
# 57        畏             9  常用ー漢検２級           0          イ
# ...     ...           ...      ...         ...        ...
# 5699      踪            15  常用ー漢検２級           0  ソウ, [ショウ]
# 5759      辣            14  常用ー漢検２級           0         ラツ
# 5878      錮            16  常用ー漢検２級           0          コ
# 7126      塡            13  常用ー漢検２級           0   テン, [チン]
# 11622     頰            16  常用ー漢検２級           0        キョウ
#
#                            kunyomi nanori  n_onyomi  n_onyomi_in_jouyou  \
# 6                           [ひら.く]   None         1                   1
# 23         あ.てる, [-あて, -づつ, あたか.も]   None         1                   0
# 38                      やみ, [くら.い]   None         2                   0
# 55                            None   None         1                   1
# 57     おそ.れる, [かしこま.る, かしこ, かしこ.し]   None         1                   1
# ...                            ...    ...       ...                 ...
# 5699                          [あと]   None         2                   1
# 5759                        [から.い]   None         1                   1
# 5878                        [ふさ.ぐ]   None         1                   1
# 7126     [はま.る, うず.める, は.める, ふさ.ぐ]   None         2                   1
# 11622                       ほお, ほほ   None         1                   0
#
#        n_kunyomi  ...  kkld_no  kkd_no  core_meaning_1 core_meaning_2  \
# 6              1  ...        0     510            push           None
# 23             4  ...        0    2762         address           None
# 38             2  ...        0    4134            dark           None
# 55             0  ...        0    1239           chair           None
# 57             4  ...        0    3170     be overawed           None
# ...          ...  ...      ...     ...             ...            ...
# 5699           1  ...        0    1996      footprints           None
# 5759           1  ...        0    1965         pungent         severe
# 5878           1  ...        0    2182        imprison           None
# 7126           4  ...        0     777            fill           None
# 11622          2  ...        0    2043           cheek           None
#
#        core_meaning_3  radical_element      rad_names non_rad_strokes  \
# 6                None                ⺘            てへん               7
# 23               None                ⼧          うかんむり               5
# 38               None                ⾨  もん（がまえ）・かどがまえ               9
# 55               None              「木」            きへん               8
# 57               None                ⽥              た               4
# ...               ...              ...            ...             ...
# 5699             None                ⻊           あしへん               8
# 5759             None                ⾟         しん・からい               7
# 5878             None              「金」           かねへん               8
# 7126             None              「土」       「つち・ど」へん              10
# 11622            None                ⾴     おおがい・いちのかい               7
#
#       jis_level unicode
# 6             1    6328
# 23            1    5B9B
# 38            1    95C7
# 55            1    6905
# 57            1    754F
# ...         ...     ...
# 5699          2    8E2A
# 5759          2    8FA3
# 5878          2    932E
# 7126          0    5861
# 11622         0    9830
#
# [185 rows x 24 columns]

# %% [markdown]
# ## Add unique id

# %%
def create_kanji_id(kanji):
    return hashlib.sha1(kanji.encode('utf-8')).hexdigest()

# %%
subset['id'] = subset['kanji'].apply(create_kanji_id)

# %% [markdown]
# ## Export final results

# %%
subset = subset[['id', 'kanji', 'stroke_count', 'grade', 'jlpt_level', 'onyomi', 'kunyomi',
                 'nanori', 'n_onyomi', 'n_onyomi_in_jouyou', 'n_kunyomi', 'n_kunyomi_in_jouyou',
                 'n_kunyomi_distinct', 'n_nanori', 'skip_code', 'kkld_no', 'kkd_no',
                 'core_meaning_1', 'core_meaning_2', 'core_meaning_3',
                 'radical_element', 'rad_names', 'non_rad_strokes']]

# %%
assert np.sum(subset['id'].duplicated()) == 0

# %%
len(subset)
# Out:
# 185

# %%
subset.sample(n=10)
# Out:
#                                             id kanji  stroke_count    grade  \
# 1207  c270bd684832c0e9844ee597558fc372720b2c6a     腫            13  常用ー漢検２級
# 2489  468972b61557e2eb4dcc98429482cc5e48eeb6fc     蔑            14  常用ー漢検２級
# 782   39a177844226c13af1a307f423fd8ef654eab7e4     舷            11  常用ー漢検２級
# 2348  89254e5b9f84d28a130ce33e11e3a089333e05e1     眉             9  常用ー漢検２級
# 341   5e3ee7e4c87ee38df8b086b9eb094e85535138bb     顎            18  常用ー漢検２級
# 2789  8effdb4aa54198fff6cf94108cd2dd763092a6a1     沃             7  常用ー漢検２級
# 2705  206518af031f85c7c21775b902d660252bc0c569     冶             7  常用ー漢検２級
# 703   8aa50bc9ef758b5953e187e6072f5d437064a637     稽            15  常用ー漢検２級
# 2292  7820629b6acc9b6a9746ed74bd64c50f9cccd30b     氾             5  常用ー漢検２級
# 1035  fe07b4546e7baedf59ed01a3b2dfb8a85231787a     拶             9  常用ー漢検２級
#
#       jlpt_level        onyomi                     kunyomi nanori  n_onyomi  \
# 1207           0     シュ, [ショウ]     は.れる, は.らす, [は.れ, はれもの]   None         2
# 2489           0            ベツ  さげす.む, [ないがしろ, なみ.する, くらい]   None         1
# 782            0            ゲン                [ふなばた, ふなべり]   None         1
# 2348           1          ビ, ミ                          まゆ   None         2
# 341            0            ガク                   あご, [あぎと]   None         1
# 2789           0  ヨク, [ヨウ, オク]                      [そそ.ぐ]   None         3
# 2705           1             ヤ                       [い.る]      じ         1
# 703            0            ケイ             [かんが.える, とど.める]   None         1
# 2292           0            ハン                     [ひろ.がる]   None         1
# 1035           0            サツ                      [せま.る]   None         1
#
#       n_onyomi_in_jouyou  ...  n_nanori  skip_code  kkld_no  kkd_no  \
# 1207                   1  ...         0      1-4-9        0    1310
# 2489                   1  ...         0     2-3-11        0    2969
# 782                    1  ...         0      1-6-5        0    1698
# 2348                   2  ...         0      3-4-5     2050    3991
# 341                    1  ...         0      1-9-9        0    2276
# 2789                   1  ...         0      1-3-4        0     315
# 2705                   1  ...         1      1-2-5       58      89
# 703                    1  ...         0     1-5-10        0    1573
# 2292                   1  ...         0      1-3-2        0     226
# 1035                   1  ...         0      1-3-6        0     451
#
#      core_meaning_1  core_meaning_2  core_meaning_3 radical_element  \
# 1207       swelling            None            None               ⺝
# 2489        despise            None            None               ⺾
# 782         gunwale            None            None             「⾈」
# 2348        eyebrow            None            None               ⽬
# 341             jaw            None            None               ⾴
# 2789        fertile            None            None               ⺡
# 2705    work metals            None            None               ⼎
# 703           think            None            None             「禾」
# 2292   spread about            None            None               ⺡
# 1035          press            None            None               ⺘
#
#        rad_names non_rad_strokes
# 1207        にくづき               9
# 2489      くさかんむり              11
# 782         ふねへん               5
# 2348           め               4
# 341   おおがい・いちのかい               9
# 2789        さんずい               4
# 2705         にすい               5
# 703         のぎへん              10
# 2292        さんずい               2
# 1035         てへん               6
#
# [10 rows x 23 columns]

# %%
subset.to_csv('./data/kanji_flashcards_{}.csv'.format(GRADE), index=False, header=False)

'./data/kanji_flashcards_{}.csv'.format(GRADE)
# Out:
# './data/kanji_flashcards_常用ー漢検２級.csv'
