# %% [markdown]
# # Process Swetnam Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_LESSON = 6

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'swetnam_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'swetnam_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#       greek remarks_greek                       italian   remarks_italian  \
# 26  ἱμάτιον       -ου, τό  vestito, indumento, mantello               NaN
# 51     δόξα        -ης, ἡ             gloria; splendore               NaN
# 59       ἐν           NaN   in, dentro a; con, mediante  regge sempre dat
# 25    ἱερόν       -ου, τό             santuario, tempio          non ναός
# 43  ἀλήθεια        -ας, ἡ                        verità               NaN
#
#    part_of_speech  lesson
# 26     sostantivo       3
# 51     sostantivo       4
# 59   preposizione       5
# 25     sostantivo       3
# 43     sostantivo       4

# %%
df_grammar = df_grammar.loc[df_grammar['lesson'] <= MAX_LESSON].copy()
df_grammar['lesson'] = df_grammar['lesson'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                              prompt remarks_prompt answer remarks_answer  \
# 63   pronome relativo (gen. m. pl.)       ὅς, ἥ, ὅ     ὧν            NaN
# 49   pronome relativo (nom. f. sg.)       ὅς, ἥ, ὅ      ἥ            NaN
# 246               di noi (gen. pl.)            ἐγώ   ἡμῶν            NaN
# 12           articolo (dat. m. sg.)       ὁ, ἡ, τό     τῷ            NaN
# 70   pronome relativo (acc. f. pl.)       ὅς, ἥ, ὅ     ἅς            NaN
#
#      lesson                      topic
# 63        3           pronome relativo
# 49        3           pronome relativo
# 246       6  declinazione di ἐγώ [Prn]
# 12        2                   articolo
# 70        3           pronome relativo

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['greek'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, lesson, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'greek', 'remarks_greek', 'italian', 'remarks_italian',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                           id       greek remarks_greek  \
# 4   f77965cf40a3bc7c73da16c195e10325319103af    ἔρχονται           NaN
# 82  0e8140bbee77ce28c27e5ee249d201b819e33c0d         ἐγώ           NaN
# 18  b0fba91157d178f8a82b7caf001763ae77928b83          οὐ           NaN
# 23  2cfa6b48c5d78b3cae453907be6e9d23d6ad009f       ἔργον       -ου, τό
# 68  7baddd6b4d777353cbc5fd05b38f9d5f4710374c   βαπτιστής        -οῦ, ὁ
# 25  984fba8d91691b9f5180786d6827ed5a9a287633       ἱερόν       -ου, τό
# 24  46882e74f025b3838a1f2a4d025a18781c12e43a  εὐαγγέλιον       -ου, τό
# 75  9b45a4ed6d3b2b8c0ee068ea20e94725e24768fa    προφήτης        -ου, ὁ
# 74  86c9fd17f95bde48f7d990bb49045d02368a94f1     μαθητής        -οῦ, ὁ
# 16  6569f8809cb9f99ab02ea1a661a5aee9146bd38c       καλός       -ή, -όν
#
#                                         italian  \
# 4                   vengono, arrivano, giungono
# 82                                           io
# 18                   non (davanti a consonante)
# 23  opera, lavoro, cosa fatta, attività, azione
# 68                       battezzatore, battista
# 25                            santuario, tempio
# 24                                      Vangelo
# 75                                      profeta
# 74                                    discepolo
# 16                                 bello, buono
#
#                              remarks_italian part_of_speech  lesson  \
# 4                                        NaN          verbo       2
# 82                                       NaN        pronome       6
# 18  negazione usata con verbi all'indicativo          altra       2
# 23                                       NaN     sostantivo       3
# 68                                       NaN     sostantivo       6
# 25                                  non ναός     sostantivo       3
# 24                                       NaN     sostantivo       3
# 75                                       NaN     sostantivo       6
# 74                                       NaN     sostantivo       6
# 16                                       NaN      aggettivo       2
#
#    last_updated_on
# 4       2022-03-19
# 82      2022-03-19
# 18      2022-03-19
# 23      2022-03-19
# 68      2022-03-19
# 25      2022-03-19
# 24      2022-03-19
# 75      2022-03-19
# 74      2022-03-19
# 16      2022-03-19

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'lesson', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                            id                          prompt  \
# 85   86d0c43cd51427391be8e81383a22118afa30250               sia! (forma in η)
# 143  4a387be66d654aa2671b83bbcb2598fa1bcdc5ca             santo (dat. m. pl.)
# 169  abb9b3357a56c7c720a983235ce80c24163de9de             buono (voc. n. pl.)
# 180  7d3812968b430a925a38c8db2332d3207b97f25b                    (che tu) sia
# 69   7d00edf91ff33a0cd9e52e8667c9e0a3bcc8779e  pronome relativo (acc. m. pl.)
# 182  d6d977db0011348f2d2e8f83e8c9ab0406091c23                 (che noi) siamo
# 104  e776a5d3aa7b0bdda4b03dd4a43e84bc2d7ca655              peccato (nom. pl.)
# 186  662c441c632130a198fd971d27fe312fb3753ad7            questo (nom. f. sg.)
# 116  9be506e611daebf1284f869b1209807f4018c891               gloria (gen. pl.)
# 106  2c3a31d9362ce7090be33ae951856c28f3539caf              peccato (gen. pl.)
#
#     remarks_prompt    answer remarks_answer  lesson  \
# 85            εἰμί       ἤτω            NaN       4
# 143          ἅγιος    ἁγίοις            NaN       4
# 169         ἀγαθός     ἀγαθά            NaN       4
# 180           εἰμί        ᾖς            NaN       5
# 69        ὅς, ἥ, ὅ       οὕς            NaN       3
# 182           εἰμί      ὦμεν            NaN       5
# 104      ἡ ἁμαρτία  ἁμαρτίαι            NaN       4
# 186          οὗτος      αὕτη            NaN       5
# 116         ἡ δόξα     δοξῶν            NaN       4
# 106      ἡ ἁμαρτία  ἁμαρτιῶν            NaN       4
#
#                                  topic last_updated_on
# 85         imperativo presente di εἰμί      2022-03-19
# 143      declinazione di ἅγιος [Agg 2]      2022-03-19
# 169     declinazione di ἀγαθός [Agg 1]      2022-03-19
# 180       congiuntivo presente di εἰμί      2022-03-19
# 69                    pronome relativo      2022-03-19
# 182       congiuntivo presente di εἰμί      2022-03-19
# 104    declinazione di ἁμαρτία [Sst 2]      2022-03-19
# 186  declinazione di οὗτος [Agg 1 Prn]      2022-03-19
# 116       declinazione di δόξα [Sst 3]      2022-03-19
# 106    declinazione di ἁμαρτία [Sst 2]      2022-03-19

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_swetnam_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 86

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_swetnam_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 249
