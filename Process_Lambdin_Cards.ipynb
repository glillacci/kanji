# %% [markdown]
# # Process Lambdin Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_VOCAB_LESSON = 54
MAX_GRAMMAR_PARAGRAPH = 195

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_VOCAB_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#        hebrew remarks_hebrew                                   english  \
# 599    בָּעַר        יִבְעַר                                   to burn
# 166  שִׁפְחָה            NaN                 maidservant, female slave
# 644     הֲלֹם            NaN                                    hither
# 759   הוֹאִיל        יוֹאִיל  to be willing or content to do something
# 784   בָּחוּר            NaN                                 young man
#
#                       remarks_english part_of_speech  lesson
# 599     tr. or intr., Qal, not שָׂרַף           verb      40
# 166                not אָמָה, pl. -ôṯ           noun      13
# 644  less frequent synonym of הֵֿנָּה         adverb      42
# 759                               NaN           verb      48
# 784                        not נַֿעַר           noun      49

# %%
df_grammar = df_grammar.loc[df_grammar['paragraph'] <= MAX_GRAMMAR_PARAGRAPH].copy()
df_grammar['paragraph'] = df_grammar['paragraph'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                            prompt remarks_prompt         answer  \
# 1408          we will exterminate           שׁמד      נַשְׁמִיד
# 919               build! (m. pl.)            בנה         בְּנוּ
# 1973           he will abandon me        יַעֲזֹב   יַעַזְבֵֿנִי
# 1022  you (f. sg.) will go around            סבב     תָּסֹֿבִּי
# 1954         you (f. sg.) bore me      יָלַדְתְּ  יְלִדְתִּֿנִי
#
#                                          remarks_answer  paragraph  \
# 1408                                                NaN        158
# 919                                                 NaN        122
# 1973  or יַעַזְבֶֿנִּי; when the stem vowel is ē or ...        192
# 1022                                                NaN        126
# 1954                                                NaN        190
#
#                                                   topic
# 1408                            basic hiphil imperfect
# 919          imperfect and related forms of verbs III-ה
# 1973                   object suffixes on the imperfect
# 1022  imperfect and imperative of geminate verbs, ty...
# 1954                     a group of irregular qal verbs

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['hebrew'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, paragraph, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'hebrew', 'remarks_hebrew', 'english', 'remarks_english',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                            id               hebrew  \
# 13   0e6f780dab3bfb2dd5ed7edf04e273652f0d3e3d            אֲנָשִׁים
# 573  749ee1c5c12824382eb98f78a22ba60f89d6cb58  לְעוֹלָם עַד־עוֹלָם
# 510  0039e31ec9e931e8f24bb23da262975708414c6a                מָדַד
# 18   e46d704e21775ed9fe9d72bde3279a443fd8f38b               הֵיכָל
# 334  c7844b401955e48441580eff76fad473c53e5d53         שְׁבוּעַֿיִם
# 299  860e415d92a01a0b8e6f0cd24176ec826a656668                  יָד
# 276  21dad3f52ea11d1b619aefb96be82d345ae11f4b             חֲיָלִים
# 457  392815863b1f024fa134e7bf32ea77347d94f625                קָרַב
# 406  c919575801146b0c23796938b6321c39be743ab6            בֶּאֱרוֹת
# 190  7be6a00ac9c7342452c6aba2c53263b46c585032                אֹיֵב
#
#     remarks_hebrew                          english          remarks_english  \
# 13             NaN                              men               irreg. pl.
# 573            NaN                          forever                      NaN
# 510          יָמֹד                       to measure                      NaN
# 18             NaN                   palace, temple                      NaN
# 334            NaN                      (two) weeks                      NaN
# 299            NaN         hand, side; (fig.) force              f., pl. -ôṯ
# 276            NaN                        strengths  from חַֿיִל, irreg. pl.
# 457        יִקְרַב  to be near, draw near, approach           + אֶל ,לְ ,בְּ
# 406            NaN                    wells (cstr.)         irreg. cstr. pl.
# 190            NaN                            enemy                  pl. -îm
#
#     part_of_speech  lesson last_updated_on
# 13            noun       2      2022-08-21
# 573         phrase      38      2022-08-21
# 510           verb      33      2022-08-21
# 18            noun       2      2022-08-21
# 334           noun      22      2022-08-21
# 299           noun      21      2022-08-21
# 276           noun      20      2022-08-21
# 457           verb      30      2022-08-21
# 406           noun      27      2022-08-21
# 190           noun      15      2022-08-21

# %%
df_grammar.columns
# Out:
# Index(['prompt', 'remarks_prompt', 'answer', 'remarks_answer', 'paragraph',
#        'topic', 'id', 'last_updated_on'],
#       dtype='object')

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'paragraph', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                             id  \
# 1489  fec89a7c82a58b1ee65b093980e77fe6a92c7cd3
# 1372  6c9bf885276b62281421e55d0aac1d99fabc0612
# 135   9d21172d94dd04a7b223b62a9d130d3d207e856b
# 1141  9e1ca8ca6371e07d91cc545ee02b89b47bbeed1d
# 107   8153dd5da2d37553b4f6fcb3aa264aedcfdf5620
# 607   35130f1a90832f0edfb53d9daa0ab98cb6870dad
# 732   34af0e17ea3231e016b46be09daaae806364620a
# 373   77b45c8455bec48261de8ead9c0b728ea03f2053
# 999   da4938719b12ba376174b7c05da47f8d390dff4a
# 1541  4767611b869c6332f6073921413098261f00183c
#
#                                                  prompt remarks_prompt  \
# 1489                                    and he led down            ירד
# 1372  (is) being magnified (f. sg., form with ultima...            גדל
# 135                                            and Edom          אֱדֹם
# 1141                            they (m. pl.) are still           עוֹד
# 107                       them (f. pl.), longer version            אֵת
# 607                                        and we wrote            כתב
# 732                                       she will love            אהב
# 373                                   blessings (cstr.)      בְּרָכוֹת
# 999                                     place! (m. pl.)           שׂים
# 1541                         you (f. sg.) will increase            רבה
#
#            answer remarks_answer  paragraph  \
# 1489   וַיּֿוֹרֶד            NaN        163
# 1372   מְגֻדָּלָה            NaN        154
# 135       וֶאֱדֹם            NaN         46
# 1141       עוֹדָם            NaN        137
# 107       אֶתְהֶן            NaN         38
# 607   וַנִּכְתֹּב            NaN         98
# 732      תֶּאֱהַב            NaN        108
# 373     בִּרְכוֹת            NaN         79
# 999      שִֿׂימוּ            NaN        124
# 1541    תַּרְבִּי            NaN        166
#
#                                                  topic last_updated_on
# 1489  hiphil conjugation of roots I-י (originally I-ו)      2022-08-21
# 1372                             basic pual participle      2022-08-21
# 135                 וְ before guttural + reduced vowel      2022-08-21
# 1141                     עוֹד with pronominal suffixes      2022-08-21
# 107             object marker with pronominal suffixes      2022-08-21
# 607       ו-conversive in perfect + imperfect sequence      2022-08-21
# 732          imperfect of verbs I-א with peculiarities      2022-08-21
# 373                   construct of plural nouns in -ôṯ      2022-08-21
# 999   imperfect and related forms of hollow verbs II-י      2022-08-21
# 1541                 hiphil conjugation of roots III-ה      2022-08-21

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 884

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 2047
