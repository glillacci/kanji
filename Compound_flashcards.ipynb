# %% [markdown]
# # Create compound flashcards

# %%
import datetime as dt
import hashlib
import random
import re
import string
import warnings

from gensim.models import KeyedVectors
import numpy as np
import pandas as pd
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import DBSCAN
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics.pairwise import cosine_similarity

# %%
DATA_PATH = '/Users/glillacci/OneDrive - Tesco/Personal/Data/kanjidata'

# %% [markdown]
# ## Select flashcard set to produce based on max grade of kanji used and frequency
# - General idea: start with top 7% for each grade, then move to top 15%, then to top 25%.
#     - For grade 1 go directly with 25%, because there are not so many words.

# %%
GRADE_FREQ_SETTINGS = {
    1.0: [1, 25],
    2.0: [2, 7],
    3.0: [3, 7],
    4.0: [4, 7],
    5.0: [5, 7],
    6.0: [6, 10],
    2.1: [2, 15],
    8.1: [8.1, 10],
    8.2: [8.2, 15],
    8.3: [8.3, 25],
    8.4: [8.4, 25],
    8.31: [8.3, 12],
    8.41: [8.4, 15]
}

SET_NUMBER = 8.41

MAX_GRADE = GRADE_FREQ_SETTINGS[SET_NUMBER][0]
MAX_QUANTILE = GRADE_FREQ_SETTINGS[SET_NUMBER][1]

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Word frequencies from Wikipedia (2015)

# %%
freqs = pd.read_csv(f'{DATA_PATH}/wikipedia-20150422-lemmas.tsv', delimiter='\t',
                    header=None, names=['rank', 'frequency', 'main_spelling'])
freqs.head()
# Out:
#    rank  frequency main_spelling
# 0     1   34943515             の
# 1     2   19609102             に
# 2     3   17575121            する
# 3     4   16805949             は
# 4     5   16443314             を

# %% [markdown]
# ### Kanjidic

# %%
kanji = pd.read_parquet(f'{DATA_PATH}/kanjidic.parquet')
kanji = kanji.rename({'frequency': 'kanji_frequency'}, axis=1)
kanji.sample(n=5)
# Out:
#       kanji   jis208   jis212 jis213 unicode  radical radical_name  \
# 10337     虣     None  1-58-35   None    8663      141         None
# 7487      帇     None   1-28-5   None    5E07       50         None
# 287       界   1-19-6     None   None    754C      102         None
# 1057      燦  1-27-24     None   None    71E6       86         None
# 622       緊  1-22-59     None   None    7DCA      120         None
#
#        stroke_count grade kanji_frequency  ... skip_code         onyomi  \
# 10337            16  None            None  ...     1-8-8           [ホウ]
# 7487              6  None            None  ...     4-6-3  [デン, ニョウ, ロウ]
# 287               9     3            None  ...     2-5-4           [カイ]
# 1057             17     9            None  ...    1-4-13           [サン]
# 622              15     8            None  ...     2-9-6           [キン]
#
#                             kunyomi nanori  \
# 10337                       [しいたげる]   None
# 7487                     [てわざがすばやい]   None
# 287                            None   None
# 1057   [さん.たる, あき.らか, きらめ.く, きら.めく]   None
# 622                    [し.める, し.まる]   None
#
#                                     meanings n_onyomi n_nanori n_kunyomi  \
# 10337           [cruel, violent, passionate]        1        0         1
# 7487                                    None        3        0         1
# 287                        [world, boundary]        1        0         0
# 1057                             [brilliant]        1        0         4
# 622    [tense, solid, hard, reliable, tight]        1        0         2
#
#       n_kunyomi_distinct jis_level
# 10337                  1         0
# 7487                   1         0
# 287                    0         1
# 1057                   4         1
# 622                    1         1
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Kanji by Kanken level

# %%
kanken = pd.read_csv(f'{DATA_PATH}/kanji_by_kanken_level.csv')
kanken.sample(n=5)
# Out:
#      kanji  kanken_level
# 5607     鉄           8.0
# 147      作           9.0
# 2493     楼           3.0
# 569      厚           6.0
# 639      听           1.0

# %% [markdown]
# ### JMdict

# %%
jmdict = pd.read_parquet(f'{DATA_PATH}/jmdict.parquet')

jmdict = jmdict[['main_spelling', 'main_reading', 'sense_no', 'meaning', 'part_of_speech', 'remarks']]

jmdict['sense_to_remove'] = jmdict['remarks'].apply(lambda x: np.sum(
    [r in x for r in ['obscure term', 'archaism', 'dated term',
                      'obsolete term', 'historical term']]) if x else 0)

# %%
jmdict = jmdict.loc[jmdict['sense_to_remove'] == 0].groupby(['main_spelling', 'main_reading']).agg({
    'meaning': lambda x: list(x),
    'part_of_speech': lambda x: list(x),
    'remarks': lambda x: list(x),
    'sense_no': 'count'
}).reset_index()

# %%
jmdict.loc[jmdict['sense_no'] > 1].sample(n=5)
# Out:
#        main_spelling main_reading  \
# 47965           外部結合      がいぶけつごう
# 90391            済ます          すます
# 33854             力作         りきさく
# 137105            重み          おもみ
# 66148             情報        じょうほう
#
#                                                   meaning  \
# 47965   [outer join (e.g. in relational database), lef...
# 90391   [to finish, to get it over with, to conclude, ...
# 33854   [painstaking piece of work, work of great effo...
# 137105  [weight, weight (e.g. of someone's words), bur...
# 66148   [information, news, intelligence, advices, inf...
#
#                                            part_of_speech  \
# 47965   [noun (common) (futsuumeishi), noun (common) (...
# 90391   [Godan verb with 'su' ending; transitive verb,...
# 33854   [noun (common) (futsuumeishi), noun (common) (...
# 137105  [noun (common) (futsuumeishi), noun (common) (...
# 66148   [noun (common) (futsuumeishi), noun (common) (...
#
#                                 remarks  sense_no
# 47965                      [None, None]         2
# 90391                [None, None, None]         3
# 33854   [None, formal or literary term]         2
# 137105               [None, None, None]         3
# 66148                      [None, None]         2

# %% [markdown]
# ### Example sentences

# %%
sentences = pd.read_parquet(f'{DATA_PATH}/example_sentences_processed.parquet')
sentences['sense'] = sentences['sense'].fillna(0).astype(int)
sentences = (
    sentences.loc[sentences['sense'].isin([0, 1]), ['jpn_sentence', 'eng_sentence', 'lemma', 'reading']]
             .rename({'lemma': 'kanji'}, axis=1)
)
sentences.sample(n=10)
# Out:
#                       jpn_sentence  \
# 503939             社会は個人からなりたっている。
# 992503                    そう思いますよ。
# 570091      私は君が今もっている辞書と同じ辞書がほしい。
# 89031              父はめったにたばこを吸わない。
# 573158           私は学科では美術と音楽が好きです。
# 612524    私の部屋は南向きなので、冬でもそんなに寒くない。
# 608261  私は鳩たちがその箱の上によじ登った褒美に餌を与えた。
# 863616      ブルーのコートを着ている女の子は私の娘です。
# 296014  彼はとても不注意なので間違った列車に乗ってしまった。
# 848595       メアリーがピアノを弾いているのが見えます。
#
#                                              eng_sentence kanji reading
# 503939                Society is composed of individuals.  成り立つ    None
# 992503                                      I suppose so.    思う    None
# 570091            I want the same dictionary as you have.    同じ    None
# 89031                            My father seldom smokes.     父    None
# 573158     I like art and music among my school subjects.    美術    None
# 612524  As my room faces south, it is not so cold even...     私     わたし
# 608261  I rewarded my pigeons with food for climbing o...     上      うえ
# 863616            The girl in a blue coat is my daughter.     娘     むすめ
# 296014  He was careless enough to get on the wrong train.   不注意    None
# 848595                      I see Mary playing the piano.    弾く      ひく

# %% [markdown]
# ## Get most frequent compounds from JMdict

# %%
df = jmdict.merge(freqs, on='main_spelling', how='inner')

# %%
df = df.loc[df['main_spelling'].str.len() > 1].sort_values('rank').copy()

# %%
rank_quantiles = list(df['rank'].quantile(np.arange(0, 1, 0.01)).values)

# %%
df['rank_quantile'] = pd.cut(df['rank'], [0] + rank_quantiles + [np.Inf], labels=range(0, 101))

# %% [markdown]
# ## Extract the kanji for each compound

# %%
kanji_block = r'[㐀-䶵一-鿋豈-頻]'
df['kanji'] = df['main_spelling'].apply(lambda x: re.findall(kanji_block, x))

df = df.explode('kanji', ignore_index=True)

# %%
df.sample(n=10)
# Out:
#       main_spelling main_reading  \
# 71709            溺水         できすい
# 88673            慨然         がいぜん
# 71754         御都合主義      ごつごうしゅぎ
# 57516            痴人          ちじん
# 65231          物悲しい       ものがなしい
# 84937           磨き粉         みがきこ
# 17853            粘着        ねんちゃく
# 90617           大乗的      だいじょうてき
# 42488           申し分        もうしぶん
# 33783            典侍          てんじ
#
#                                                  meaning  \
# 71709                                         [drowning]
# 88673      [indignant, sorrowful, steadfast, determined]
# 71754  [opportunism, double standards, timeserving, e...
# 57516                               [dunce, fool, idiot]
# 65231                                  [sad, melancholy]
# 84937                                 [polishing powder]
# 17853                               [cohesion, adhesion]
# 90617                                     [broad, great]
# 42488                          [objection, shortcomings]
# 33783   [maid of honor, maid of honour, lady-in-waiting]
#
#                                           part_of_speech       remarks  \
# 71709                     [noun (common) (futsuumeishi)]        [None]
# 88673  ['taru' adjective; adverb taking the 'to' part...  [None, None]
# 71754                     [noun (common) (futsuumeishi)]        [None]
# 57516                     [noun (common) (futsuumeishi)]        [None]
# 65231                            [adjective (keiyoushi)]        [None]
# 84937                     [noun (common) (futsuumeishi)]        [None]
# 17853  [noun (common) (futsuumeishi); noun or partici...        [None]
# 90617  [adjectival nouns or quasi-adjectives (keiyodo...        [None]
# 42488  [noun (common) (futsuumeishi); noun or partici...        [None]
# 33783                     [noun (common) (futsuumeishi)]        [None]
#
#        sense_no    rank  frequency rank_quantile kanji
# 71709         1  146359         51            76     水
# 88673         2  441367          7            93     然
# 71754         1  146474         51            76     主
# 57516         1   83588        154            61     人
# 65231         1  111350         87            69     物
# 84937         1  323749         12            89     粉
# 17853         1   17088       2534            20     着
# 90617         1  532932          5            95     大
# 42488         1   49879        416            46     分
# 33783         1   36138        736            37     侍

# %% [markdown]
# ## Find compounds by kanji, grade and frequency

# %% [markdown]
# ### Augment grades with Kanken levels

# %%
kanji = kanji.merge(kanken, on='kanji', how='left')

# %%
def augment_grade(row):
    if row['grade'] == 8:
        mapping = {
            2.0: 8.4,
            2.5: 8.3,
            3.0: 8.2,
            4.0: 8.1
        }
        return mapping[row['kanken_level']]
    return row['grade']

# %%
kanji['grade'] = kanji['grade'].fillna(11).astype(int)
kanji['grade'] = kanji[['grade', 'kanken_level']].apply(augment_grade, axis=1)

# %%
kanji['grade'].value_counts().sort_index()
# Out:
# 1.0        80
# 2.0       160
# 3.0       200
# 4.0       202
# 5.0       193
# 6.0       191
# 8.1       313
# 8.2       284
# 8.3       328
# 8.4       185
# 9.0       651
# 10.0      212
# 11.0    10109
# Name: grade, dtype: int64

# %% [markdown]
# ### Merge most frequent words to kanji

# %%
kanji = kanji.merge(df, on='kanji', how='inner')

# %%
compounds = (
    kanji.groupby(['main_spelling', 'main_reading'])
         .agg({
             'grade': 'max',
             'rank_quantile': 'first',
             'meaning': 'first',
             'sense_no': 'first',
             'part_of_speech': 'first',
             'remarks': 'first'})
         .rename({'grade': 'max_grade'}, axis=1)
         .reset_index()
)

# %% [markdown]
# ## Create the desired set of flashcards

# %%
v = compounds.loc[compounds['rank_quantile'] <= MAX_QUANTILE, 'max_grade'].value_counts().sort_index()
v
# Out:
# 1.0      277
# 2.0      896
# 3.0     1171
# 4.0     1055
# 5.0     1145
# 6.0      778
# 8.1      814
# 8.2      465
# 8.3      319
# 8.4       69
# 9.0       88
# 11.0      34
# Name: max_grade, dtype: int64

# %%
v.loc[[1, 2, 3, 4, 5, 6, 8.1, 8.2, 8.3, 8.4]].sum()
# Out:
# 6989

# %%
selection = (
    compounds.loc[(compounds['max_grade'] <= MAX_GRADE)
                  & (compounds['rank_quantile'] <= MAX_QUANTILE)]
             .sort_values('rank_quantile')
             .rename({'main_spelling': 'kanji', 'main_reading': 'reading',
                      'meaning': 'raw_meanings'}, axis=1)
).copy()

# %%
selection.sample(frac=0.01)
# Out:
#       kanji reading  max_grade  rank_quantile  \
# 17629    形状   けいじょう        5.0              3
# 19257    感謝    かんしゃ        5.0              6
# 11715    城壁   じょうへき        8.1             15
# 16704    年度     ねんど        3.0              1
# 20401    拍子    ひょうし        8.1             11
# ...     ...     ...        ...            ...
# 19117    意義      いぎ        5.0             10
# 36830    艦載    かんさい        8.3             12
# 17722    往来    おうらい        5.0             14
# 42396    進級   しんきゅう        3.0             15
# 13108    天気     てんき        1.0              5
#
#                                             raw_meanings  sense_no  \
# 17629                                      [shape, form]         1
# 19257                                [thanks, gratitude]         1
# 11715                            [rampart, castle walls]         1
# 16704  [fiscal year (usu. April 1 to March 31 in Japa...         3
# 20401  [(musical) time, tempo, beat, rhythm, the mome...         2
# ...                                                  ...       ...
# 19117                            [meaning, significance]         1
# 36830                        [carrying aboard a warship]         1
# 17722  [coming and going, traffic, road, street, asso...         5
# 42396               [promotion (school, military, etc.)]         1
# 13108  [weather, the elements, fair weather, fine wea...         2
#
#                                           part_of_speech  \
# 17629                     [noun (common) (futsuumeishi)]
# 19257  [noun (common) (futsuumeishi); noun or partici...
# 11715  [noun (common) (futsuumeishi); nouns which may...
# 16704  [noun (common) (futsuumeishi); noun, used as a...
# 20401  [noun (common) (futsuumeishi), noun (common) (...
# ...                                                  ...
# 19117                     [noun (common) (futsuumeishi)]
# 36830  [noun (common) (futsuumeishi); noun or partici...
# 17722  [noun (common) (futsuumeishi); noun or partici...
# 42396  [noun (common) (futsuumeishi); noun or partici...
# 13108  [noun (common) (futsuumeishi), noun (common) (...
#
#                               remarks
# 17629                          [None]
# 19257                          [None]
# 11715                          [None]
# 16704              [None, None, None]
# 20401                    [None, None]
# ...                               ...
# 19117                          [None]
# 36830                          [None]
# 17722  [None, None, None, None, None]
# 42396                          [None]
# 13108                    [None, None]
#
# [70 rows x 8 columns]

# %%
len(selection)
# Out:
# 6989

# %% [markdown]
# ### Add the example senteces
# Note for the merging. If no reading is provided in the example sentences (`reading_y` is `None`), then a match on the kanji spelling alone is ok. However if a reading is provided in the example senteces, that usually means that some disambiguation is needed: therefore the reading in the example sentences and the reading in the dictionary has to match.

# %%
subset = selection.merge(sentences, on='kanji', how='left')

subset.loc[(subset['reading_y'].notnull()) & (subset['reading_x'] != subset['reading_y']), 'jpn_sentence'] = None
subset.loc[(subset['reading_y'].notnull()) & (subset['reading_x'] != subset['reading_y']), 'eng_sentence'] = None

subset = (
    subset.drop('reading_y', axis=1)
          .rename({'reading_x': 'reading'}, axis=1)
)

# %%
subset = (
    subset.groupby(['kanji', 'reading'])
          .agg({
              'part_of_speech': 'first',
              'raw_meanings': 'first',
              'max_grade': 'first',
              'rank_quantile': 'first',
              'remarks': 'first',
              'jpn_sentence': lambda x: list(x),
              'eng_sentence': lambda x: list(x)
          })
          .reset_index()
)

# %%
len(subset)
# Out:
# 6989

# %%
def get_sentence_indices(x):
    if len(x) == 1:
        indices = [0, None, None]
    elif len(x) == 2:
        indices = [0, 1, None]
    elif len(x) == 3:
        indices = [0, 1, 2]
    else:
        indices = random.sample(range(len(x)), 3)
    return indices


def extract_sentence(row, sentence_col, index):
    if row['sentence_indices'][index] is not None:
        return row[sentence_col][row['sentence_indices'][index]]
    else:
        return None

# %%
subset['sentence_indices'] = subset['jpn_sentence'].apply(get_sentence_indices)

subset['jpn_sentence_1'] = subset.apply(lambda row: extract_sentence(row, 'jpn_sentence', 0), axis=1)
subset['eng_sentence_1'] = subset.apply(lambda row: extract_sentence(row, 'eng_sentence', 0), axis=1)

subset['jpn_sentence_2'] = subset.apply(lambda row: extract_sentence(row, 'jpn_sentence', 1), axis=1)
subset['eng_sentence_2'] = subset.apply(lambda row: extract_sentence(row, 'eng_sentence', 1), axis=1)

subset['jpn_sentence_3'] = subset.apply(lambda row: extract_sentence(row, 'jpn_sentence', 2), axis=1)
subset['eng_sentence_3'] = subset.apply(lambda row: extract_sentence(row, 'eng_sentence', 2), axis=1)

# %%
subset = subset.drop(['jpn_sentence', 'eng_sentence', 'sentence_indices'], axis=1)

# %% [markdown]
# ### Use Google News embeddings and clustering to pick out representative meanings

# %%
word2vec = KeyedVectors.load_word2vec_format(f'{DATA_PATH}/GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
def change_commas_in_parentheses(input_string: str) -> str:
    output_string = ''
    change_comma = True
    for char in input_string:
        if char == '(':
            change_comma = False
        if char == ',' and change_comma:
            output_string += ';'
            continue
        if char == ')':
            change_comma = True
        output_string += char
    return output_string

# %%
def remove_punctuation(input_string: str) -> str:
    return input_string.lower().translate(str.maketrans('', '', string.punctuation))

# %%
def find_representative_meanings(subgroup):
    meanings = [meaning
                for meaning_list in subgroup['raw_meanings'].values[0]
                for meaning in change_commas_in_parentheses(meaning_list).split('; ')]

    phrases = [remove_punctuation(m) for m in meanings]
    
    split_phrases = [words.split(' ') for words in phrases]
    split_phrases = [[w for w in phrase if word2vec.has_index_for(w)]
                     for phrase in split_phrases]
    split_phrases = [phrase for phrase in split_phrases if phrase]
    
    if len(split_phrases) <= 1:
        subgroup['clusters'] = str(meanings)
        subgroup['english'] = ', '.join(meanings)
        return subgroup
    
    vectors = [np.sum([word2vec.get_vector(w) for w in words], axis=0)
               for words in split_phrases]
    
    with warnings.catch_warnings():
        warnings.simplefilter('error', ConvergenceWarning)
        warnings.simplefilter('error', UserWarning)
        
        try:
            clustering_method = 'affinity'
            clustering = (
                AffinityPropagation(affinity='precomputed', random_state=2)
                .fit(cosine_similarity(vectors))
            )
            centers = clustering.cluster_centers_indices_
        
        except (ConvergenceWarning, UserWarning):
            print(f"Affinity propagation failed for {subgroup['kanji'].values[0]}"
                  ", switching to DBSCAN")
            
            clustering_method = 'dbscan'
            clustering = DBSCAN(eps=0.65, metric='cosine').fit(vectors)
            centers = []
    
    labels = clustering.labels_
    clusters = {c: [meanings[i] for i in range(len(split_phrases)) if labels[i] == c]
                for c in range(max(labels) + 1)}
    
    subgroup['clusters'] = f'{clustering_method} - {str(clusters)}'
    if len(centers):
        subgroup['english'] = ', '.join([meanings[c] for c in centers])
    elif max(labels) > -1:
        subgroup['english'] = ', '.join([c[0] for c in clusters.values()])
    else:
        subgroup['english'] = ', '.join(subgroup['raw_meanings'].values[0])
    
    return subgroup

# %%
# subgroup = subset.loc[subset['kanji'] == '図る']
# subgroup

# %%
# find_representative_meanings(subgroup)

# %%
subset = subset.groupby(['kanji', 'reading']).apply(find_representative_meanings)
# Out:
# Affinity propagation failed for ある程度, switching to DBSCAN
# Affinity propagation failed for お互い, switching to DBSCAN
# Affinity propagation failed for お前, switching to DBSCAN
# Affinity propagation failed for お知らせ, switching to DBSCAN
# Affinity propagation failed for その間, switching to DBSCAN
# Affinity propagation failed for っ子, switching to DBSCAN
# Affinity propagation failed for に当たって, switching to DBSCAN
# Affinity propagation failed for に従い, switching to DBSCAN
# Affinity propagation failed for に際して, switching to DBSCAN
# Affinity propagation failed for もう一度, switching to DBSCAN
# Affinity propagation failed for を以て, switching to DBSCAN
# Affinity propagation failed for アメリカ大陸, switching to DBSCAN
# Affinity propagation failed for 一味, switching to DBSCAN
# Affinity propagation failed for 一員, switching to DBSCAN
# Affinity propagation failed for 一大, switching to DBSCAN
# Affinity propagation failed for 一斉, switching to DBSCAN
# Affinity propagation failed for 一樹, switching to DBSCAN
# Affinity propagation failed for 一環, switching to DBSCAN
# Affinity propagation failed for 一行, switching to DBSCAN
# Affinity propagation failed for 一説, switching to DBSCAN
# Affinity propagation failed for 丁目, switching to DBSCAN
# Affinity propagation failed for 万博, switching to DBSCAN
# Affinity propagation failed for 三つ, switching to DBSCAN
# Affinity propagation failed for 三国志, switching to DBSCAN
# Affinity propagation failed for 三男, switching to DBSCAN
# Affinity propagation failed for 三角, switching to DBSCAN
# Affinity propagation failed for 三郎, switching to DBSCAN
# Affinity propagation failed for 上げ, switching to DBSCAN
# Affinity propagation failed for 上人, switching to DBSCAN
# Affinity propagation failed for 上田, switching to DBSCAN
# Affinity propagation failed for 上記, switching to DBSCAN
# Affinity propagation failed for 上越, switching to DBSCAN
# Affinity propagation failed for 上部, switching to DBSCAN
# Affinity propagation failed for 下旬, switching to DBSCAN
# Affinity propagation failed for 下町, switching to DBSCAN
# Affinity propagation failed for 下院, switching to DBSCAN
# Affinity propagation failed for 不参加, switching to DBSCAN
# Affinity propagation failed for 不可欠, switching to DBSCAN
# Affinity propagation failed for 不祥事, switching to DBSCAN
# Affinity propagation failed for 不要, switching to DBSCAN
# Affinity propagation failed for 世にも, switching to DBSCAN
# Affinity propagation failed for 世界中, switching to DBSCAN
# Affinity propagation failed for 世襲, switching to DBSCAN
# Affinity propagation failed for 両国, switching to DBSCAN
# Affinity propagation failed for 両親, switching to DBSCAN
# Affinity propagation failed for 並木, switching to DBSCAN
# Affinity propagation failed for 中佐, switching to DBSCAN
# Affinity propagation failed for 中学生, switching to DBSCAN
# Affinity propagation failed for 中尉, switching to DBSCAN
# Affinity propagation failed for 中期, switching to DBSCAN
# Affinity propagation failed for 中毒, switching to DBSCAN
# Affinity propagation failed for 中華民国, switching to DBSCAN
# Affinity propagation failed for 中間, switching to DBSCAN
# Affinity propagation failed for 中高, switching to DBSCAN
# Affinity propagation failed for 主体, switching to DBSCAN
# Affinity propagation failed for 主君, switching to DBSCAN
# Affinity propagation failed for 主審, switching to DBSCAN
# Affinity propagation failed for 主将, switching to DBSCAN
# Affinity propagation failed for 主演, switching to DBSCAN
# Affinity propagation failed for 主砲, switching to DBSCAN
# Affinity propagation failed for 主要, switching to DBSCAN
# Affinity propagation failed for 乗用車, switching to DBSCAN
# Affinity propagation failed for 乗車, switching to DBSCAN
# Affinity propagation failed for 乗降, switching to DBSCAN
# Affinity propagation failed for 予報, switching to DBSCAN
# Affinity propagation failed for 予測, switching to DBSCAN
# Affinity propagation failed for 予算, switching to DBSCAN
# Affinity propagation failed for 事物, switching to DBSCAN
# Affinity propagation failed for 互い, switching to DBSCAN
# Affinity propagation failed for 互いに, switching to DBSCAN
# Affinity propagation failed for 五輪, switching to DBSCAN
# Affinity propagation failed for 交差点, switching to DBSCAN
# Affinity propagation failed for 交易, switching to DBSCAN
# Affinity propagation failed for 人事, switching to DBSCAN
# Affinity propagation failed for 人体, switching to DBSCAN
# Affinity propagation failed for 人口, switching to DBSCAN
# Affinity propagation failed for 人員, switching to DBSCAN
# Affinity propagation failed for 人妻, switching to DBSCAN
# Affinity propagation failed for 人権, switching to DBSCAN
# Affinity propagation failed for 人気, switching to DBSCAN
# Affinity propagation failed for 人的, switching to DBSCAN
# Affinity propagation failed for 人種, switching to DBSCAN
# Affinity propagation failed for 人類, switching to DBSCAN
# Affinity propagation failed for 人魚, switching to DBSCAN
# Affinity propagation failed for 今回, switching to DBSCAN
# Affinity propagation failed for 今夜, switching to DBSCAN
# Affinity propagation failed for 今後, switching to DBSCAN
# Affinity propagation failed for 他社, switching to DBSCAN
# Affinity propagation failed for 他者, switching to DBSCAN
# Affinity propagation failed for 付録, switching to DBSCAN
# Affinity propagation failed for 代数, switching to DBSCAN
# Affinity propagation failed for 以北, switching to DBSCAN
# Affinity propagation failed for 以南, switching to DBSCAN
# Affinity propagation failed for 以外, switching to DBSCAN
# Affinity propagation failed for 以来, switching to DBSCAN
# Affinity propagation failed for 以西, switching to DBSCAN
# Affinity propagation failed for 仮名, switching to DBSCAN
# Affinity propagation failed for 仮称, switching to DBSCAN
# Affinity propagation failed for 仲介, switching to DBSCAN
# Affinity propagation failed for 任す, switching to DBSCAN
# Affinity propagation failed for 企画, switching to DBSCAN
# Affinity propagation failed for 休日, switching to DBSCAN
# Affinity propagation failed for 会員, switching to DBSCAN
# Affinity propagation failed for 会長, switching to DBSCAN
# Affinity propagation failed for 会館, switching to DBSCAN
# Affinity propagation failed for 伝導, switching to DBSCAN
# Affinity propagation failed for 伝統, switching to DBSCAN
# Affinity propagation failed for 伝記, switching to DBSCAN
# Affinity propagation failed for 伯爵, switching to DBSCAN
# Affinity propagation failed for 佐渡, switching to DBSCAN
# Affinity propagation failed for 体格, switching to DBSCAN
# Affinity propagation failed for 体積, switching to DBSCAN
# Affinity propagation failed for 体調, switching to DBSCAN
# Affinity propagation failed for 体長, switching to DBSCAN
# Affinity propagation failed for 何者, switching to DBSCAN
# Affinity propagation failed for 作曲, switching to DBSCAN
# Affinity propagation failed for 作用, switching to DBSCAN
# Affinity propagation failed for 作風, switching to DBSCAN
# Affinity propagation failed for 併用, switching to DBSCAN
# Affinity propagation failed for 使徒, switching to DBSCAN
# Affinity propagation failed for 例祭, switching to DBSCAN
# Affinity propagation failed for 供給, switching to DBSCAN
# Affinity propagation failed for 供養, switching to DBSCAN
# Affinity propagation failed for 依存, switching to DBSCAN
# Affinity propagation failed for 侯爵, switching to DBSCAN
# Affinity propagation failed for 保安, switching to DBSCAN
# Affinity propagation failed for 保険, switching to DBSCAN
# Affinity propagation failed for 信託, switching to DBSCAN
# Affinity propagation failed for 修道, switching to DBSCAN
# Affinity propagation failed for 個体, switching to DBSCAN
# Affinity propagation failed for 倫理, switching to DBSCAN
# Affinity propagation failed for 停留, switching to DBSCAN
# Affinity propagation failed for 停車, switching to DBSCAN
# Affinity propagation failed for 側近, switching to DBSCAN
# Affinity propagation failed for 偵察, switching to DBSCAN
# Affinity propagation failed for 債権, switching to DBSCAN
# Affinity propagation failed for 儀礼, switching to DBSCAN
# Affinity propagation failed for 優勝, switching to DBSCAN
# Affinity propagation failed for 元号, switching to DBSCAN
# Affinity propagation failed for 元和, switching to DBSCAN
# Affinity propagation failed for 元年, switching to DBSCAN
# Affinity propagation failed for 充てる, switching to DBSCAN
# Affinity propagation failed for 充電, switching to DBSCAN
# Affinity propagation failed for 先述, switching to DBSCAN
# Affinity propagation failed for 光線, switching to DBSCAN
# Affinity propagation failed for 児童, switching to DBSCAN
# Affinity propagation failed for 入会, switching to DBSCAN
# Affinity propagation failed for 入力, switching to DBSCAN
# Affinity propagation failed for 入団, switching to DBSCAN
# Affinity propagation failed for 入植, switching to DBSCAN
# Affinity propagation failed for 全力, switching to DBSCAN
# Affinity propagation failed for 全日本, switching to DBSCAN
# Affinity propagation failed for 全曲, switching to DBSCAN
# Affinity propagation failed for 全権, switching to DBSCAN
# Affinity propagation failed for 全編, switching to DBSCAN
# Affinity propagation failed for 全長, switching to DBSCAN
# Affinity propagation failed for 全面, switching to DBSCAN
# Affinity propagation failed for 全高, switching to DBSCAN
# Affinity propagation failed for 公共, switching to DBSCAN
# Affinity propagation failed for 公司, switching to DBSCAN
# Affinity propagation failed for 公団, switching to DBSCAN
# Affinity propagation failed for 公安, switching to DBSCAN
# Affinity propagation failed for 公文書, switching to DBSCAN
# Affinity propagation failed for 公演, switching to DBSCAN
# Affinity propagation failed for 公爵, switching to DBSCAN
# Affinity propagation failed for 公的, switching to DBSCAN
# Affinity propagation failed for 公示, switching to DBSCAN
# Affinity propagation failed for 公衆, switching to DBSCAN
# Affinity propagation failed for 公表, switching to DBSCAN
# Affinity propagation failed for 公言, switching to DBSCAN
# Affinity propagation failed for 共和, switching to DBSCAN
# Affinity propagation failed for 共演, switching to DBSCAN
# Affinity propagation failed for 共産, switching to DBSCAN
# Affinity propagation failed for 共闘, switching to DBSCAN
# Affinity propagation failed for 共鳴, switching to DBSCAN
# Affinity propagation failed for 兵員, switching to DBSCAN
# Affinity propagation failed for 兵隊, switching to DBSCAN
# Affinity propagation failed for 兼任, switching to DBSCAN
# Affinity propagation failed for 内親王, switching to DBSCAN
# Affinity propagation failed for 内野, switching to DBSCAN
# Affinity propagation failed for 内閣, switching to DBSCAN
# Affinity propagation failed for 再婚, switching to DBSCAN
# Affinity propagation failed for 再編, switching to DBSCAN
# Affinity propagation failed for 冷却, switching to DBSCAN
# Affinity propagation failed for 冷房, switching to DBSCAN
# Affinity propagation failed for 処女, switching to DBSCAN
# Affinity propagation failed for 処罰, switching to DBSCAN
# Affinity propagation failed for 出典, switching to DBSCAN
# Affinity propagation failed for 出展, switching to DBSCAN
# Affinity propagation failed for 出張, switching to DBSCAN
# Affinity propagation failed for 出張所, switching to DBSCAN
# Affinity propagation failed for 出演, switching to DBSCAN
# Affinity propagation failed for 出陣, switching to DBSCAN
# Affinity propagation failed for 出題, switching to DBSCAN
# Affinity propagation failed for 分化, switching to DBSCAN
# Affinity propagation failed for 分布, switching to DBSCAN
# Affinity propagation failed for 切手, switching to DBSCAN
# Affinity propagation failed for 刊行, switching to DBSCAN
# Affinity propagation failed for 刑事, switching to DBSCAN
# Affinity propagation failed for 刑務所, switching to DBSCAN
# Affinity propagation failed for 刑法, switching to DBSCAN
# Affinity propagation failed for 列島, switching to DBSCAN
# Affinity propagation failed for 列車, switching to DBSCAN
# Affinity propagation failed for 初代, switching to DBSCAN
# Affinity propagation failed for 初年度, switching to DBSCAN
# Affinity propagation failed for 初恋, switching to DBSCAN
# Affinity propagation failed for 初日, switching to DBSCAN
# Affinity propagation failed for 初等, switching to DBSCAN
# Affinity propagation failed for 判事, switching to DBSCAN
# Affinity propagation failed for 別々, switching to DBSCAN
# Affinity propagation failed for 制裁, switching to DBSCAN
# Affinity propagation failed for 刺客, switching to DBSCAN
# Affinity propagation failed for 前方, switching to DBSCAN
# Affinity propagation failed for 前述, switching to DBSCAN
# Affinity propagation failed for 剣客, switching to DBSCAN
# Affinity propagation failed for 剣術, switching to DBSCAN
# Affinity propagation failed for 副作用, switching to DBSCAN
# Affinity propagation failed for 副官, switching to DBSCAN
# Affinity propagation failed for 副審, switching to DBSCAN
# Affinity propagation failed for 副題, switching to DBSCAN
# Affinity propagation failed for 創刊, switching to DBSCAN
# Affinity propagation failed for 創建, switching to DBSCAN
# Affinity propagation failed for 創業, switching to DBSCAN
# Affinity propagation failed for 劇団, switching to DBSCAN
# Affinity propagation failed for 劇場, switching to DBSCAN
# Affinity propagation failed for 力学, switching to DBSCAN
# Affinity propagation failed for 功労, switching to DBSCAN
# Affinity propagation failed for 加熱, switching to DBSCAN
# Affinity propagation failed for 加速, switching to DBSCAN
# Affinity propagation failed for 助教授, switching to DBSCAN
# Affinity propagation failed for 助演, switching to DBSCAN
# Affinity propagation failed for 動態, switching to DBSCAN
# Affinity propagation failed for 勝ち, switching to DBSCAN
# Affinity propagation failed for 勝つ, switching to DBSCAN
# Affinity propagation failed for 勝者, switching to DBSCAN
# Affinity propagation failed for 北京, switching to DBSCAN
# Affinity propagation failed for 北側, switching to DBSCAN
# Affinity propagation failed for 北極, switching to DBSCAN
# Affinity propagation failed for 北欧, switching to DBSCAN
# Affinity propagation failed for 北海, switching to DBSCAN
# Affinity propagation failed for 北部, switching to DBSCAN
# Affinity propagation failed for 区役所, switching to DBSCAN
# Affinity propagation failed for 医学, switching to DBSCAN
# Affinity propagation failed for 医師, switching to DBSCAN
# Affinity propagation failed for 医療, switching to DBSCAN
# Affinity propagation failed for 医科, switching to DBSCAN
# Affinity propagation failed for 医者, switching to DBSCAN
# Affinity propagation failed for 十字架, switching to DBSCAN
# Affinity propagation failed for 十字軍, switching to DBSCAN
# Affinity propagation failed for 千秋, switching to DBSCAN
# Affinity propagation failed for 千里, switching to DBSCAN
# Affinity propagation failed for 午前, switching to DBSCAN
# Affinity propagation failed for 午後, switching to DBSCAN
# Affinity propagation failed for 半島, switching to DBSCAN
# Affinity propagation failed for 半年, switching to DBSCAN
# Affinity propagation failed for 半数, switching to DBSCAN
# Affinity propagation failed for 半田, switching to DBSCAN
# Affinity propagation failed for 卒業生, switching to DBSCAN
# Affinity propagation failed for 卓球, switching to DBSCAN
# Affinity propagation failed for 協力, switching to DBSCAN
# Affinity propagation failed for 南部, switching to DBSCAN
# Affinity propagation failed for 単式, switching to DBSCAN
# Affinity propagation failed for 単行, switching to DBSCAN
# Affinity propagation failed for 博覧, switching to DBSCAN
# Affinity propagation failed for 占い, switching to DBSCAN
# Affinity propagation failed for 占拠, switching to DBSCAN
# Affinity propagation failed for 即位, switching to DBSCAN
# Affinity propagation failed for 却下, switching to DBSCAN
# Affinity propagation failed for 卸売, switching to DBSCAN
# Affinity propagation failed for 原子力, switching to DBSCAN
# Affinity propagation failed for 原産, switching to DBSCAN
# Affinity propagation failed for 原語, switching to DBSCAN
# Affinity propagation failed for 参拝, switching to DBSCAN
# Affinity propagation failed for 参画, switching to DBSCAN
# Affinity propagation failed for 参考, switching to DBSCAN
# Affinity propagation failed for 又は, switching to DBSCAN
# Affinity propagation failed for 友達, switching to DBSCAN
# Affinity propagation failed for 双子, switching to DBSCAN
# Affinity propagation failed for 双方, switching to DBSCAN
# Affinity propagation failed for 反応, switching to DBSCAN
# Affinity propagation failed for 収蔵, switching to DBSCAN
# Affinity propagation failed for 取り, switching to DBSCAN
# Affinity propagation failed for 取り戻す, switching to DBSCAN
# Affinity propagation failed for 取締役, switching to DBSCAN
# Affinity propagation failed for 受け取る, switching to DBSCAN
# Affinity propagation failed for 受信, switching to DBSCAN
# Affinity propagation failed for 受章, switching to DBSCAN
# Affinity propagation failed for 受託, switching to DBSCAN
# Affinity propagation failed for 口調, switching to DBSCAN
# Affinity propagation failed for 古典, switching to DBSCAN
# Affinity propagation failed for 古来, switching to DBSCAN
# Affinity propagation failed for 可動, switching to DBSCAN
# Affinity propagation failed for 台場, switching to DBSCAN
# Affinity propagation failed for 台風, switching to DBSCAN
# Affinity propagation failed for 右側, switching to DBSCAN
# Affinity propagation failed for 右足, switching to DBSCAN
# Affinity propagation failed for 各地, switching to DBSCAN
# Affinity propagation failed for 各所, switching to DBSCAN
# Affinity propagation failed for 各社, switching to DBSCAN
# Affinity propagation failed for 各種, switching to DBSCAN
# Affinity propagation failed for 合作, switching to DBSCAN
# Affinity propagation failed for 合唱, switching to DBSCAN
# Affinity propagation failed for 合弁, switching to DBSCAN
# Affinity propagation failed for 合衆国, switching to DBSCAN
# Affinity propagation failed for 合計, switching to DBSCAN
# Affinity propagation failed for 同名, switching to DBSCAN
# Affinity propagation failed for 同地, switching to DBSCAN
# Affinity propagation failed for 同局, switching to DBSCAN
# Affinity propagation failed for 同居, switching to DBSCAN
# Affinity propagation failed for 同行, switching to DBSCAN
# Affinity propagation failed for 名人, switching to DBSCAN
# Affinity propagation failed for 名称, switching to DBSCAN
# Affinity propagation failed for 名跡, switching to DBSCAN
# Affinity propagation failed for 名鑑, switching to DBSCAN
# Affinity propagation failed for 向ける, switching to DBSCAN
# Affinity propagation failed for 吸血鬼, switching to DBSCAN
# Affinity propagation failed for 吹奏楽, switching to DBSCAN
# Affinity propagation failed for 吹雪, switching to DBSCAN
# Affinity propagation failed for 告知, switching to DBSCAN
# Affinity propagation failed for 告示, switching to DBSCAN
# Affinity propagation failed for 周期, switching to DBSCAN
# Affinity propagation failed for 命中, switching to DBSCAN
# Affinity propagation failed for 命名, switching to DBSCAN
# Affinity propagation failed for 和書, switching to DBSCAN
# Affinity propagation failed for 哺乳類, switching to DBSCAN
# Affinity propagation failed for 商会, switching to DBSCAN
# Affinity propagation failed for 商号, switching to DBSCAN
# Affinity propagation failed for 喜劇, switching to DBSCAN
# Affinity propagation failed for 喪失, switching to DBSCAN
# Affinity propagation failed for 営利, switching to DBSCAN
# Affinity propagation failed for 噴火, switching to DBSCAN
# Affinity propagation failed for 四天王, switching to DBSCAN
# Affinity propagation failed for 回答, switching to DBSCAN
# Affinity propagation failed for 回線, switching to DBSCAN
# Affinity propagation failed for 回路, switching to DBSCAN
# Affinity propagation failed for 回避, switching to DBSCAN
# Affinity propagation failed for 因む, switching to DBSCAN
# Affinity propagation failed for 団体, switching to DBSCAN
# Affinity propagation failed for 団地, switching to DBSCAN
# Affinity propagation failed for 囲碁, switching to DBSCAN
# Affinity propagation failed for 図る, switching to DBSCAN
# Affinity propagation failed for 図柄, switching to DBSCAN
# Affinity propagation failed for 固体, switching to DBSCAN
# Affinity propagation failed for 国会図書館, switching to DBSCAN
# Affinity propagation failed for 国体, switching to DBSCAN
# Affinity propagation failed for 国内, switching to DBSCAN
# Affinity propagation failed for 国内外, switching to DBSCAN
# Affinity propagation failed for 国史, switching to DBSCAN
# Affinity propagation failed for 国営, switching to DBSCAN
# Affinity propagation failed for 国境, switching to DBSCAN
# Affinity propagation failed for 国外, switching to DBSCAN
# Affinity propagation failed for 国民党, switching to DBSCAN
# Affinity propagation failed for 国産, switching to DBSCAN
# Affinity propagation failed for 国連, switching to DBSCAN
# Affinity propagation failed for 国防, switching to DBSCAN
# Affinity propagation failed for 園芸, switching to DBSCAN
# Affinity propagation failed for 土器, switching to DBSCAN
# Affinity propagation failed for 土日, switching to DBSCAN
# Affinity propagation failed for 在位, switching to DBSCAN
# Affinity propagation failed for 地下鉄, switching to DBSCAN
# Affinity propagation failed for 地中, switching to DBSCAN
# Affinity propagation failed for 地中海, switching to DBSCAN
# Affinity propagation failed for 地位, switching to DBSCAN
# Affinity propagation failed for 地域, switching to DBSCAN
# Affinity propagation failed for 地方裁判所, switching to DBSCAN
# Affinity propagation failed for 地球, switching to DBSCAN
# Affinity propagation failed for 地表, switching to DBSCAN
# Affinity propagation failed for 地質, switching to DBSCAN
# Affinity propagation failed for 地面, switching to DBSCAN
# Affinity propagation failed for 均一, switching to DBSCAN
# Affinity propagation failed for 均衡, switching to DBSCAN
# Affinity propagation failed for 垂直, switching to DBSCAN
# Affinity propagation failed for 型式, switching to DBSCAN
# Affinity propagation failed for 城下, switching to DBSCAN
# Affinity propagation failed for 城下町, switching to DBSCAN
# Affinity propagation failed for 城内, switching to DBSCAN
# Affinity propagation failed for 城壁, switching to DBSCAN
# Affinity propagation failed for 城跡, switching to DBSCAN
# Affinity propagation failed for 基板, switching to DBSCAN
# Affinity propagation failed for 基礎, switching to DBSCAN
# Affinity propagation failed for 基部, switching to DBSCAN
# Affinity propagation failed for 基金, switching to DBSCAN
# Affinity propagation failed for 報じる, switching to DBSCAN
# Affinity propagation failed for 報告, switching to DBSCAN
# Affinity propagation failed for 場合, switching to DBSCAN
# Affinity propagation failed for 塗装, switching to DBSCAN
# Affinity propagation failed for 墓地, switching to DBSCAN
# Affinity propagation failed for 増える, switching to DBSCAN
# Affinity propagation failed for 増す, switching to DBSCAN
# Affinity propagation failed for 増刊, switching to DBSCAN
# Affinity propagation failed for 増大, switching to DBSCAN
# Affinity propagation failed for 増発, switching to DBSCAN
# Affinity propagation failed for 墜落, switching to DBSCAN
# Affinity propagation failed for 声明, switching to DBSCAN
# Affinity propagation failed for 壱岐, switching to DBSCAN
# Affinity propagation failed for 変動, switching to DBSCAN
# Affinity propagation failed for 変異, switching to DBSCAN
# Affinity propagation failed for 変装, switching to DBSCAN
# Affinity propagation failed for 変速, switching to DBSCAN
# Affinity propagation failed for 夏休み, switching to DBSCAN
# Affinity propagation failed for 夕方, switching to DBSCAN
# Affinity propagation failed for 外山, switching to DBSCAN
# Affinity propagation failed for 外科, switching to DBSCAN
# Affinity propagation failed for 多岐, switching to DBSCAN
# Affinity propagation failed for 多様, switching to DBSCAN
# Affinity propagation failed for 多重, switching to DBSCAN
# Affinity propagation failed for 夜明け, switching to DBSCAN
# Affinity propagation failed for 夜間, switching to DBSCAN
# Affinity propagation failed for 大人, switching to DBSCAN
# Affinity propagation failed for 大佐, switching to DBSCAN
# Affinity propagation failed for 大同, switching to DBSCAN
# Affinity propagation failed for 大和, switching to DBSCAN
# Affinity propagation failed for 大夫, switching to DBSCAN
# Affinity propagation failed for 大字, switching to DBSCAN
# Affinity propagation failed for 大学生, switching to DBSCAN
# Affinity propagation failed for 大帝, switching to DBSCAN
# Affinity propagation failed for 大正, switching to DBSCAN
# Affinity propagation failed for 大河ドラマ, switching to DBSCAN
# Affinity propagation failed for 大破, switching to DBSCAN
# Affinity propagation failed for 大衆, switching to DBSCAN
# Affinity propagation failed for 大賞, switching to DBSCAN
# Affinity propagation failed for 大都市, switching to DBSCAN
# Affinity propagation failed for 大震災, switching to DBSCAN
# Affinity propagation failed for 天平, switching to DBSCAN
# Affinity propagation failed for 天然記念物, switching to DBSCAN
# Affinity propagation failed for 天王, switching to DBSCAN
# Affinity propagation failed for 天理, switching to DBSCAN
# Affinity propagation failed for 太子, switching to DBSCAN
# Affinity propagation failed for 太字, switching to DBSCAN
# Affinity propagation failed for 太平, switching to DBSCAN
# Affinity propagation failed for 夫妻, switching to DBSCAN
# Affinity propagation failed for 奏者, switching to DBSCAN
# Affinity propagation failed for 奮闘, switching to DBSCAN
# Affinity propagation failed for 女子, switching to DBSCAN
# Affinity propagation failed for 女子大, switching to DBSCAN
# Affinity propagation failed for 女王, switching to DBSCAN
# Affinity propagation failed for 女神, switching to DBSCAN
# Affinity propagation failed for 好む, switching to DBSCAN
# Affinity propagation failed for 好物, switching to DBSCAN
# Affinity propagation failed for 妄想, switching to DBSCAN
# Affinity propagation failed for 妊娠, switching to DBSCAN
# Affinity propagation failed for 始まり, switching to DBSCAN
# Affinity propagation failed for 始動, switching to DBSCAN
# Affinity propagation failed for 娯楽, switching to DBSCAN
# Affinity propagation failed for 婚姻, switching to DBSCAN
# Affinity propagation failed for 婚約, switching to DBSCAN
# Affinity propagation failed for 媒体, switching to DBSCAN
# Affinity propagation failed for 嫉妬, switching to DBSCAN
# Affinity propagation failed for 嫡男, switching to DBSCAN
# Affinity propagation failed for 子役, switching to DBSCAN
# Affinity propagation failed for 子葉, switching to DBSCAN
# Affinity propagation failed for 字幕, switching to DBSCAN
# Affinity propagation failed for 存在, switching to DBSCAN
# Affinity propagation failed for 季節, switching to DBSCAN
# Affinity propagation failed for 孤児, switching to DBSCAN
# Affinity propagation failed for 学区, switching to DBSCAN
# Affinity propagation failed for 学期, switching to DBSCAN
# Affinity propagation failed for 学派, switching to DBSCAN
# Affinity propagation failed for 学芸, switching to DBSCAN
# Affinity propagation failed for 学部, switching to DBSCAN
# Affinity propagation failed for 学院, switching to DBSCAN
# Affinity propagation failed for 宅地, switching to DBSCAN
# Affinity propagation failed for 安全, switching to DBSCAN
# Affinity propagation failed for 安心, switching to DBSCAN
# Affinity propagation failed for 安置, switching to DBSCAN
# Affinity propagation failed for 完了, switching to DBSCAN
# Affinity propagation failed for 完全, switching to DBSCAN
# Affinity propagation failed for 完結, switching to DBSCAN
# Affinity propagation failed for 宗家, switching to DBSCAN
# Affinity propagation failed for 官位, switching to DBSCAN
# Affinity propagation failed for 官報, switching to DBSCAN
# Affinity propagation failed for 定か, switching to DBSCAN
# Affinity propagation failed for 定住, switching to DBSCAN
# Affinity propagation failed for 定時, switching to DBSCAN
# Affinity propagation failed for 定理, switching to DBSCAN
# Affinity propagation failed for 実子, switching to DBSCAN
# Affinity propagation failed for 実業, switching to DBSCAN
# Affinity propagation failed for 実用, switching to DBSCAN
# Affinity propagation failed for 室内, switching to DBSCAN
# Affinity propagation failed for 宮内, switching to DBSCAN
# Affinity propagation failed for 宮廷, switching to DBSCAN
# Affinity propagation failed for 家屋, switching to DBSCAN
# Affinity propagation failed for 家族, switching to DBSCAN
# Affinity propagation failed for 家老, switching to DBSCAN
# Affinity propagation failed for 家臣, switching to DBSCAN
# Affinity propagation failed for 家電, switching to DBSCAN
# Affinity propagation failed for 容姿, switching to DBSCAN
# Affinity propagation failed for 容疑, switching to DBSCAN
# Affinity propagation failed for 宿泊, switching to DBSCAN
# Affinity propagation failed for 寄与, switching to DBSCAN
# Affinity propagation failed for 寄付, switching to DBSCAN
# Affinity propagation failed for 寄進, switching to DBSCAN
# Affinity propagation failed for 富士山, switching to DBSCAN
# Affinity propagation failed for 寝台, switching to DBSCAN
# Affinity propagation failed for 対処, switching to DBSCAN
# Affinity propagation failed for 対外, switching to DBSCAN
# Affinity propagation failed for 対決, switching to DBSCAN
# Affinity propagation failed for 対称, switching to DBSCAN
# Affinity propagation failed for 対空, switching to DBSCAN
# Affinity propagation failed for 対馬, switching to DBSCAN
# Affinity propagation failed for 寿司, switching to DBSCAN
# Affinity propagation failed for 専攻, switching to DBSCAN
# Affinity propagation failed for 専用, switching to DBSCAN
# Affinity propagation failed for 将来, switching to DBSCAN
# Affinity propagation failed for 将棋, switching to DBSCAN
# Affinity propagation failed for 将軍, switching to DBSCAN
# Affinity propagation failed for 尋常, switching to DBSCAN
# Affinity propagation failed for 小児, switching to DBSCAN
# Affinity propagation failed for 小山, switching to DBSCAN
# Affinity propagation failed for 小島, switching to DBSCAN
# Affinity propagation failed for 小松, switching to DBSCAN
# Affinity propagation failed for 小説, switching to DBSCAN
# Affinity propagation failed for 小路, switching to DBSCAN
# Affinity propagation failed for 小銃, switching to DBSCAN
# Affinity propagation failed for 少々, switching to DBSCAN
# Affinity propagation failed for 少尉, switching to DBSCAN
# Affinity propagation failed for 就役, switching to DBSCAN
# Affinity propagation failed for 就職, switching to DBSCAN
# Affinity propagation failed for 局長, switching to DBSCAN
# Affinity propagation failed for 居酒屋, switching to DBSCAN
# Affinity propagation failed for 屋外, switching to DBSCAN
# Affinity propagation failed for 展示, switching to DBSCAN
# Affinity propagation failed for 展覧, switching to DBSCAN
# Affinity propagation failed for 属す, switching to DBSCAN
# Affinity propagation failed for 山下, switching to DBSCAN
# Affinity propagation failed for 山中, switching to DBSCAN
# Affinity propagation failed for 山内, switching to DBSCAN
# Affinity propagation failed for 山川, switching to DBSCAN
# Affinity propagation failed for 山手, switching to DBSCAN
# Affinity propagation failed for 山系, switching to DBSCAN
# Affinity propagation failed for 山脈, switching to DBSCAN
# Affinity propagation failed for 山野, switching to DBSCAN
# Affinity propagation failed for 山陽, switching to DBSCAN
# Affinity propagation failed for 山麓, switching to DBSCAN
# Affinity propagation failed for 崩御, switching to DBSCAN
# Affinity propagation failed for 川上, switching to DBSCAN
# Affinity propagation failed for 川辺, switching to DBSCAN
# Affinity propagation failed for 州立, switching to DBSCAN
# Affinity propagation failed for 巡礼, switching to DBSCAN
# Affinity propagation failed for 巡航, switching to DBSCAN
# Affinity propagation failed for 工兵, switching to DBSCAN
# Affinity propagation failed for 工具, switching to DBSCAN
# Affinity propagation failed for 工学部, switching to DBSCAN
# Affinity propagation failed for 工芸, switching to DBSCAN
# Affinity propagation failed for 左側, switching to DBSCAN
# Affinity propagation failed for 左腕, switching to DBSCAN
# Affinity propagation failed for 市内, switching to DBSCAN
# Affinity propagation failed for 市営, switching to DBSCAN
# Affinity propagation failed for 市外, switching to DBSCAN
# Affinity propagation failed for 市立, switching to DBSCAN
# Affinity propagation failed for 市道, switching to DBSCAN
# Affinity propagation failed for 布袋, switching to DBSCAN
# Affinity propagation failed for 希少, switching to DBSCAN
# Affinity propagation failed for 帝国, switching to DBSCAN
# Affinity propagation failed for 帰郷, switching to DBSCAN
# Affinity propagation failed for 常に, switching to DBSCAN
# Affinity propagation failed for 常用, switching to DBSCAN
# Affinity propagation failed for 常設, switching to DBSCAN
# Affinity propagation failed for 帽子, switching to DBSCAN
# Affinity propagation failed for 幅員, switching to DBSCAN
# Affinity propagation failed for 幕下, switching to DBSCAN
# Affinity propagation failed for 幕僚, switching to DBSCAN
# Affinity propagation failed for 幕末, switching to DBSCAN
# Affinity propagation failed for 干支, switching to DBSCAN
# Affinity propagation failed for 平和, switching to DBSCAN
# Affinity propagation failed for 平家, switching to DBSCAN
# Affinity propagation failed for 平家, switching to DBSCAN
# Affinity propagation failed for 平方メートル, switching to DBSCAN
# Affinity propagation failed for 平野, switching to DBSCAN
# Affinity propagation failed for 平面, switching to DBSCAN
# Affinity propagation failed for 年上, switching to DBSCAN
# Affinity propagation failed for 年下, switching to DBSCAN
# Affinity propagation failed for 年末年始, switching to DBSCAN
# Affinity propagation failed for 年生, switching to DBSCAN
# Affinity propagation failed for 年金, switching to DBSCAN
# Affinity propagation failed for 年間, switching to DBSCAN
# Affinity propagation failed for 年限, switching to DBSCAN
# Affinity propagation failed for 年齢, switching to DBSCAN
# Affinity propagation failed for 幹線, switching to DBSCAN
# Affinity propagation failed for 幼年, switching to DBSCAN
# Affinity propagation failed for 幾つ, switching to DBSCAN
# Affinity propagation failed for 幾度, switching to DBSCAN
# Affinity propagation failed for 広まる, switching to DBSCAN
# Affinity propagation failed for 広州, switching to DBSCAN
# Affinity propagation failed for 広東, switching to DBSCAN
# Affinity propagation failed for 広義, switching to DBSCAN
# Affinity propagation failed for 序曲, switching to DBSCAN
# Affinity propagation failed for 店内, switching to DBSCAN
# Affinity propagation failed for 店舗, switching to DBSCAN
# Affinity propagation failed for 府立, switching to DBSCAN
# Affinity propagation failed for 座標, switching to DBSCAN
# Affinity propagation failed for 庭園, switching to DBSCAN
# Affinity propagation failed for 廃校, switching to DBSCAN
# Affinity propagation failed for 廃止, switching to DBSCAN
# Affinity propagation failed for 廉価, switching to DBSCAN
# Affinity propagation failed for 建つ, switching to DBSCAN
# Affinity propagation failed for 建て, switching to DBSCAN
# Affinity propagation failed for 建てる, switching to DBSCAN
# Affinity propagation failed for 建立, switching to DBSCAN
# Affinity propagation failed for 建築, switching to DBSCAN
# Affinity propagation failed for 建設, switching to DBSCAN
# Affinity propagation failed for 建造, switching to DBSCAN
# Affinity propagation failed for 弁当, switching to DBSCAN
# Affinity propagation failed for 弁護士, switching to DBSCAN
# Affinity propagation failed for 式典, switching to DBSCAN
# Affinity propagation failed for 引き分け, switching to DBSCAN
# Affinity propagation failed for 引き換え, switching to DBSCAN
# Affinity propagation failed for 引き継ぐ, switching to DBSCAN
# Affinity propagation failed for 引っ越す, switching to DBSCAN
# Affinity propagation failed for 弥生, switching to DBSCAN
# Affinity propagation failed for 弦楽, switching to DBSCAN
# Affinity propagation failed for 弦楽器, switching to DBSCAN
# Affinity propagation failed for 張る, switching to DBSCAN
# Affinity propagation failed for 強める, switching to DBSCAN
# Affinity propagation failed for 強力, switching to DBSCAN
# Affinity propagation failed for 強大, switching to DBSCAN
# Affinity propagation failed for 強行, switching to DBSCAN
# Affinity propagation failed for 弾薬, switching to DBSCAN
# Affinity propagation failed for 当地, switching to DBSCAN
# Affinity propagation failed for 当時, switching to DBSCAN
# Affinity propagation failed for 形状, switching to DBSCAN
# Affinity propagation failed for 役所, switching to DBSCAN
# Affinity propagation failed for 彼ら, switching to DBSCAN
# Affinity propagation failed for 待つ, switching to DBSCAN
# Affinity propagation failed for 後半, switching to DBSCAN
# Affinity propagation failed for 後年, switching to DBSCAN
# Affinity propagation failed for 後援, switching to DBSCAN
# Affinity propagation failed for 後継, switching to DBSCAN
# Affinity propagation failed for 後述, switching to DBSCAN
# Affinity propagation failed for 後部, switching to DBSCAN
# Affinity propagation failed for 徒歩, switching to DBSCAN
# Affinity propagation failed for 従属, switching to DBSCAN
# Affinity propagation failed for 得票, switching to DBSCAN
# Affinity propagation failed for 御殿, switching to DBSCAN
# Affinity propagation failed for 微生物, switching to DBSCAN
# Affinity propagation failed for 徴収, switching to DBSCAN
# Affinity propagation failed for 心配, switching to DBSCAN
# Affinity propagation failed for 忍者, switching to DBSCAN
# Affinity propagation failed for 思える, switching to DBSCAN
# Affinity propagation failed for 怪我, switching to DBSCAN
# Affinity propagation failed for 怪盗, switching to DBSCAN
# Affinity propagation failed for 恋する, switching to DBSCAN
# Affinity propagation failed for 恐れる, switching to DBSCAN
# Affinity propagation failed for 恒例, switching to DBSCAN
# Affinity propagation failed for 息子, switching to DBSCAN
# Affinity propagation failed for 悩む, switching to DBSCAN
# Affinity propagation failed for 悪夢, switching to DBSCAN
# Affinity propagation failed for 想像, switching to DBSCAN
# Affinity propagation failed for 意外, switching to DBSCAN
# Affinity propagation failed for 意思, switching to DBSCAN
# Affinity propagation failed for 意義, switching to DBSCAN
# Affinity propagation failed for 愛人, switching to DBSCAN
# Affinity propagation failed for 愛国, switching to DBSCAN
# Affinity propagation failed for 愛好, switching to DBSCAN
# Affinity propagation failed for 愛情, switching to DBSCAN
# Affinity propagation failed for 愛用, switching to DBSCAN
# Affinity propagation failed for 感謝, switching to DBSCAN
# Affinity propagation failed for 慰安, switching to DBSCAN
# Affinity propagation failed for 懲役, switching to DBSCAN
# Affinity propagation failed for 成功, switching to DBSCAN
# Affinity propagation failed for 成熟, switching to DBSCAN
# Affinity propagation failed for 成績, switching to DBSCAN
# Affinity propagation failed for 戦前, switching to DBSCAN
# Affinity propagation failed for 戦功, switching to DBSCAN
# Affinity propagation failed for 戦史, switching to DBSCAN
# Affinity propagation failed for 戦場, switching to DBSCAN
# Affinity propagation failed for 戦後, switching to DBSCAN
# Affinity propagation failed for 戦歴, switching to DBSCAN
# Affinity propagation failed for 戦法, switching to DBSCAN
# Affinity propagation failed for 戦略, switching to DBSCAN
# Affinity propagation failed for 戦車, switching to DBSCAN
# Affinity propagation failed for 戴冠, switching to DBSCAN
# Affinity propagation failed for 戸籍, switching to DBSCAN
# Affinity propagation failed for 所在地, switching to DBSCAN
# Affinity propagation failed for 所得, switching to DBSCAN
# Affinity propagation failed for 所持, switching to DBSCAN
# Affinity propagation failed for 所有, switching to DBSCAN
# Affinity propagation failed for 所長, switching to DBSCAN
# Affinity propagation failed for 手法, switching to DBSCAN
# Affinity propagation failed for 才能, switching to DBSCAN
# Affinity propagation failed for 打席, switching to DBSCAN
# Affinity propagation failed for 扱い, switching to DBSCAN
# Affinity propagation failed for 技師, switching to DBSCAN
# Affinity propagation failed for 投票, switching to DBSCAN
# Affinity propagation failed for 抗争, switching to DBSCAN
# Affinity propagation failed for 抗議, switching to DBSCAN
# Affinity propagation failed for 担当, switching to DBSCAN
# Affinity propagation failed for 拒絶, switching to DBSCAN
# Affinity propagation failed for 括弧, switching to DBSCAN
# Affinity propagation failed for 指揮, switching to DBSCAN
# Affinity propagation failed for 指摘, switching to DBSCAN
# Affinity propagation failed for 振り回す, switching to DBSCAN
# Affinity propagation failed for 振興, switching to DBSCAN
# Affinity propagation failed for 挿入, switching to DBSCAN
# Affinity propagation failed for 挿絵, switching to DBSCAN
# Affinity propagation failed for 捕獲, switching to DBSCAN
# Affinity propagation failed for 掃海, switching to DBSCAN
# Affinity propagation failed for 掘削, switching to DBSCAN
# Affinity propagation failed for 採集, switching to DBSCAN
# Affinity propagation failed for 探検, switching to DBSCAN
# Affinity propagation failed for 接触, switching to DBSCAN
# Affinity propagation failed for 控訴, switching to DBSCAN
# Affinity propagation failed for 推奨, switching to DBSCAN
# Affinity propagation failed for 推測, switching to DBSCAN
# Affinity propagation failed for 推計, switching to DBSCAN
# Affinity propagation failed for 提唱, switching to DBSCAN
# Affinity propagation failed for 提督, switching to DBSCAN
# Affinity propagation failed for 損傷, switching to DBSCAN
# Affinity propagation failed for 搭乗, switching to DBSCAN
# Affinity propagation failed for 摂る, switching to DBSCAN
# Affinity propagation failed for 摂政, switching to DBSCAN
# Affinity propagation failed for 擁する, switching to DBSCAN
# Affinity propagation failed for 操業, switching to DBSCAN
# Affinity propagation failed for 支店, switching to DBSCAN
# Affinity propagation failed for 支流, switching to DBSCAN
# Affinity propagation failed for 支部, switching to DBSCAN
# Affinity propagation failed for 支配人, switching to DBSCAN
# Affinity propagation failed for 改修, switching to DBSCAN
# Affinity propagation failed for 改称, switching to DBSCAN
# Affinity propagation failed for 改組, switching to DBSCAN
# Affinity propagation failed for 改良, switching to DBSCAN
# Affinity propagation failed for 改装, switching to DBSCAN
# Affinity propagation failed for 攻勢, switching to DBSCAN
# Affinity propagation failed for 放射, switching to DBSCAN
# Affinity propagation failed for 放火, switching to DBSCAN
# Affinity propagation failed for 放送, switching to DBSCAN
# Affinity propagation failed for 政令, switching to DBSCAN
# Affinity propagation failed for 政府, switching to DBSCAN
# Affinity propagation failed for 政権, switching to DBSCAN
# Affinity propagation failed for 政治, switching to DBSCAN
# Affinity propagation failed for 政策, switching to DBSCAN
# Affinity propagation failed for 故に, switching to DBSCAN
# Affinity propagation failed for 故人, switching to DBSCAN
# Affinity propagation failed for 救援, switching to DBSCAN
# Affinity propagation failed for 敗北, switching to DBSCAN
# Affinity propagation failed for 敗退, switching to DBSCAN
# Affinity propagation failed for 教会, switching to DBSCAN
# Affinity propagation failed for 教団, switching to DBSCAN
# Affinity propagation failed for 教徒, switching to DBSCAN
# Affinity propagation failed for 教科, switching to DBSCAN
# Affinity propagation failed for 教職員, switching to DBSCAN
# Affinity propagation failed for 散歩, switching to DBSCAN
# Affinity propagation failed for 数える, switching to DBSCAN
# Affinity propagation failed for 数多い, switching to DBSCAN
# Affinity propagation failed for 数学, switching to DBSCAN
# Affinity propagation failed for 敷設, switching to DBSCAN
# Affinity propagation failed for 文化財, switching to DBSCAN
# Affinity propagation failed for 文字通り, switching to DBSCAN
# Affinity propagation failed for 文政, switching to DBSCAN
# Affinity propagation failed for 文芸, switching to DBSCAN
# Affinity propagation failed for 文部, switching to DBSCAN
# Affinity propagation failed for 文部省, switching to DBSCAN
# Affinity propagation failed for 断念, switching to DBSCAN
# Affinity propagation failed for 新作, switching to DBSCAN
# Affinity propagation failed for 新幹線, switching to DBSCAN
# Affinity propagation failed for 新旧, switching to DBSCAN
# Affinity propagation failed for 新書, switching to DBSCAN
# Affinity propagation failed for 新築, switching to DBSCAN
# Affinity propagation failed for 新選, switching to DBSCAN
# Affinity propagation failed for 方言, switching to DBSCAN
# Affinity propagation failed for 施策, switching to DBSCAN
# Affinity propagation failed for 旅立ち, switching to DBSCAN
# Affinity propagation failed for 旋律, switching to DBSCAN
# Affinity propagation failed for 旗揚げ, switching to DBSCAN
# Affinity propagation failed for 旗本, switching to DBSCAN
# Affinity propagation failed for 既に, switching to DBSCAN
# Affinity propagation failed for 日付, switching to DBSCAN
# Affinity propagation failed for 日刊, switching to DBSCAN
# Affinity propagation failed for 日向, switching to DBSCAN
# Affinity propagation failed for 日向, switching to DBSCAN
# Affinity propagation failed for 日本一, switching to DBSCAN
# Affinity propagation failed for 日本人, switching to DBSCAN
# Affinity propagation failed for 日本書紀, switching to DBSCAN
# Affinity propagation failed for 日産, switching to DBSCAN
# Affinity propagation failed for 日記, switching to DBSCAN
# Affinity propagation failed for 日誌, switching to DBSCAN
# Affinity propagation failed for 旧制, switching to DBSCAN
# Affinity propagation failed for 旧名, switching to DBSCAN
# Affinity propagation failed for 旧姓, switching to DBSCAN
# Affinity propagation failed for 旧称, switching to DBSCAN
# Affinity propagation failed for 早乙女, switching to DBSCAN
# Affinity propagation failed for 昆虫, switching to DBSCAN
# Affinity propagation failed for 昇格, switching to DBSCAN
# Affinity propagation failed for 明日, switching to DBSCAN
# Affinity propagation failed for 明記, switching to DBSCAN
# Affinity propagation failed for 映画, switching to DBSCAN
# Affinity propagation failed for 春日, switching to DBSCAN
# Affinity propagation failed for 時には, switching to DBSCAN
# Affinity propagation failed for 時事, switching to DBSCAN
# Affinity propagation failed for 時点, switching to DBSCAN
# Affinity propagation failed for 晩年, switching to DBSCAN
# Affinity propagation failed for 暴力, switching to DBSCAN
# Affinity propagation failed for 曲名, switching to DBSCAN
# Affinity propagation failed for 書店, switching to DBSCAN
# Affinity propagation failed for 書物, switching to DBSCAN
# Affinity propagation failed for 書籍, switching to DBSCAN
# Affinity propagation failed for 書類, switching to DBSCAN
# Affinity propagation failed for 最も, switching to DBSCAN
# Affinity propagation failed for 最前線, switching to DBSCAN
# Affinity propagation failed for 最多, switching to DBSCAN
# Affinity propagation failed for 最寄り, switching to DBSCAN
# Affinity propagation failed for 最長, switching to DBSCAN
# Affinity propagation failed for 月光, switching to DBSCAN
# Affinity propagation failed for 月刊, switching to DBSCAN
# Affinity propagation failed for 月日, switching to DBSCAN
# Affinity propagation failed for 月間, switching to DBSCAN
# Affinity propagation failed for 有名, switching to DBSCAN
# Affinity propagation failed for 有害, switching to DBSCAN
# Affinity propagation failed for 有用, switching to DBSCAN
# Affinity propagation failed for 有罪, switching to DBSCAN
# Affinity propagation failed for 有限, switching to DBSCAN
# Affinity propagation failed for 服装, switching to DBSCAN
# Affinity propagation failed for 朗読, switching to DBSCAN
# Affinity propagation failed for 木製, switching to DBSCAN
# Affinity propagation failed for 未成年, switching to DBSCAN
# Affinity propagation failed for 末期, switching to DBSCAN
# Affinity propagation failed for 本堂, switching to DBSCAN
# Affinity propagation failed for 本山, switching to DBSCAN
# Affinity propagation failed for 本島, switching to DBSCAN
# Affinity propagation failed for 本庁, switching to DBSCAN
# Affinity propagation failed for 本当に, switching to DBSCAN
# Affinity propagation failed for 本殿, switching to DBSCAN
# Affinity propagation failed for 本線, switching to DBSCAN
# Affinity propagation failed for 本間, switching to DBSCAN
# Affinity propagation failed for 村長, switching to DBSCAN
# Affinity propagation failed for 来日, switching to DBSCAN
# Affinity propagation failed for 来歴, switching to DBSCAN
# Affinity propagation failed for 東ドイツ, switching to DBSCAN
# Affinity propagation failed for 東亜, switching to DBSCAN
# Affinity propagation failed for 東側, switching to DBSCAN
# Affinity propagation failed for 東北, switching to DBSCAN
# Affinity propagation failed for 東端, switching to DBSCAN
# Affinity propagation failed for 東部, switching to DBSCAN
# Affinity propagation failed for 林家, switching to DBSCAN
# Affinity propagation failed for 枚数, switching to DBSCAN
# Affinity propagation failed for 栄える, switching to DBSCAN
# Affinity propagation failed for 栄養, switching to DBSCAN
# Affinity propagation failed for 校区, switching to DBSCAN
# Affinity propagation failed for 校舎, switching to DBSCAN
# Affinity propagation failed for 校長, switching to DBSCAN
# Affinity propagation failed for 株主, switching to DBSCAN
# Affinity propagation failed for 株式, switching to DBSCAN
# Affinity propagation failed for 棋士, switching to DBSCAN
# Affinity propagation failed for 森林, switching to DBSCAN
# Affinity propagation failed for 植物, switching to DBSCAN
# Affinity propagation failed for 検出, switching to DBSCAN
# Affinity propagation failed for 検証, switching to DBSCAN
# Affinity propagation failed for 極端, switching to DBSCAN
# Affinity propagation failed for 楽団, switching to DBSCAN
# Affinity propagation failed for 楽園, switching to DBSCAN
# Affinity propagation failed for 楽曲, switching to DBSCAN
# Affinity propagation failed for 楽譜, switching to DBSCAN
# Affinity propagation failed for 概説, switching to DBSCAN
# Affinity propagation failed for 標高, switching to DBSCAN
# ...
# Affinity propagation failed for 要因, switching to DBSCAN
# Affinity propagation failed for 要望, switching to DBSCAN
# Affinity propagation failed for 見せる, switching to DBSCAN
# Affinity propagation failed for 見つかる, switching to DBSCAN
# Affinity propagation failed for 見守る, switching to DBSCAN
# Affinity propagation failed for 見解, switching to DBSCAN
# Affinity propagation failed for 規則, switching to DBSCAN
# Affinity propagation failed for 規格, switching to DBSCAN
# Affinity propagation failed for 視察, switching to DBSCAN
# Affinity propagation failed for 視覚, switching to DBSCAN
# Affinity propagation failed for 親しむ, switching to DBSCAN
# Affinity propagation failed for 親族, switching to DBSCAN
# Affinity propagation failed for 親王, switching to DBSCAN
# Affinity propagation failed for 観光, switching to DBSCAN
# Affinity propagation failed for 観音, switching to DBSCAN
# Affinity propagation failed for 解答, switching to DBSCAN
# Affinity propagation failed for 解読, switching to DBSCAN
# Affinity propagation failed for 解釈, switching to DBSCAN
# Affinity propagation failed for 解雇, switching to DBSCAN
# Affinity propagation failed for 言える, switching to DBSCAN
# Affinity propagation failed for 言動, switching to DBSCAN
# Affinity propagation failed for 言及, switching to DBSCAN
# Affinity propagation failed for 計測, switching to DBSCAN
# Affinity propagation failed for 討論, switching to DBSCAN
# Affinity propagation failed for 記者, switching to DBSCAN
# Affinity propagation failed for 記述, switching to DBSCAN
# Affinity propagation failed for 訪問, switching to DBSCAN
# Affinity propagation failed for 訳す, switching to DBSCAN
# Affinity propagation failed for 訴訟, switching to DBSCAN
# Affinity propagation failed for 診断, switching to DBSCAN
# Affinity propagation failed for 診療, switching to DBSCAN
# Affinity propagation failed for 証拠, switching to DBSCAN
# Affinity propagation failed for 証言, switching to DBSCAN
# Affinity propagation failed for 評論, switching to DBSCAN
# Affinity propagation failed for 評議, switching to DBSCAN
# Affinity propagation failed for 話題, switching to DBSCAN
# Affinity propagation failed for 誓う, switching to DBSCAN
# Affinity propagation failed for 語学, switching to DBSCAN
# Affinity propagation failed for 語尾, switching to DBSCAN
# Affinity propagation failed for 説明, switching to DBSCAN
# Affinity propagation failed for 課程, switching to DBSCAN
# Affinity propagation failed for 課長, switching to DBSCAN
# Affinity propagation failed for 調教, switching to DBSCAN
# Affinity propagation failed for 調理, switching to DBSCAN
# Affinity propagation failed for 論理, switching to DBSCAN
# Affinity propagation failed for 諸侯, switching to DBSCAN
# Affinity propagation failed for 諸島, switching to DBSCAN
# Affinity propagation failed for 講和, switching to DBSCAN
# Affinity propagation failed for 講堂, switching to DBSCAN
# Affinity propagation failed for 講座, switching to DBSCAN
# Affinity propagation failed for 講習, switching to DBSCAN
# Affinity propagation failed for 警告, switching to DBSCAN
# Affinity propagation failed for 警報, switching to DBSCAN
# Affinity propagation failed for 警護, switching to DBSCAN
# Affinity propagation failed for 豪族, switching to DBSCAN
# Affinity propagation failed for 負債, switching to DBSCAN
# Affinity propagation failed for 負傷, switching to DBSCAN
# Affinity propagation failed for 負荷, switching to DBSCAN
# Affinity propagation failed for 貢献, switching to DBSCAN
# Affinity propagation failed for 貨車, switching to DBSCAN
# Affinity propagation failed for 貯蔵, switching to DBSCAN
# Affinity propagation failed for 貴重, switching to DBSCAN
# Affinity propagation failed for 買い物, switching to DBSCAN
# Affinity propagation failed for 費用, switching to DBSCAN
# Affinity propagation failed for 資本, switching to DBSCAN
# Affinity propagation failed for 資金, switching to DBSCAN
# Affinity propagation failed for 賛同, switching to DBSCAN
# Affinity propagation failed for 賢者, switching to DBSCAN
# Affinity propagation failed for 質問, switching to DBSCAN
# Affinity propagation failed for 購入, switching to DBSCAN
# Affinity propagation failed for 赤ちゃん, switching to DBSCAN
# Affinity propagation failed for 赤外線, switching to DBSCAN
# Affinity propagation failed for 赤軍, switching to DBSCAN
# Affinity propagation failed for 赤道, switching to DBSCAN
# Affinity propagation failed for 走者, switching to DBSCAN
# Affinity propagation failed for 赴任, switching to DBSCAN
# Affinity propagation failed for 起こる, switching to DBSCAN
# Affinity propagation failed for 起因, switching to DBSCAN
# Affinity propagation failed for 起点, switching to DBSCAN
# Affinity propagation failed for 起訴, switching to DBSCAN
# Affinity propagation failed for 超過, switching to DBSCAN
# Affinity propagation failed for 距離, switching to DBSCAN
# Affinity propagation failed for 跡地, switching to DBSCAN
# Affinity propagation failed for 身長, switching to DBSCAN
# Affinity propagation failed for 車体, switching to DBSCAN
# Affinity propagation failed for 車椅子, switching to DBSCAN
# Affinity propagation failed for 車線, switching to DBSCAN
# Affinity propagation failed for 軍人, switching to DBSCAN
# Affinity propagation failed for 軍団, switching to DBSCAN
# Affinity propagation failed for 軍艦, switching to DBSCAN
# Affinity propagation failed for 軍需, switching to DBSCAN
# Affinity propagation failed for 転生, switching to DBSCAN
# Affinity propagation failed for 転用, switching to DBSCAN
# Affinity propagation failed for 軽減, switching to DBSCAN
# Affinity propagation failed for 輩出, switching to DBSCAN
# Affinity propagation failed for 輸送, switching to DBSCAN
# Affinity propagation failed for 辛い, switching to DBSCAN
# Affinity propagation failed for 辞典, switching to DBSCAN
# Affinity propagation failed for 辞書, switching to DBSCAN
# Affinity propagation failed for 農地, switching to DBSCAN
# Affinity propagation failed for 農民, switching to DBSCAN
# Affinity propagation failed for 近似, switching to DBSCAN
# Affinity propagation failed for 近日, switching to DBSCAN
# Affinity propagation failed for 近海, switching to DBSCAN
# Affinity propagation failed for 近辺, switching to DBSCAN
# Affinity propagation failed for 近隣, switching to DBSCAN
# Affinity propagation failed for 返還, switching to DBSCAN
# Affinity propagation failed for 迫害, switching to DBSCAN
# Affinity propagation failed for 追い出す, switching to DBSCAN
# Affinity propagation failed for 追悼, switching to DBSCAN
# Affinity propagation failed for 追撃, switching to DBSCAN
# Affinity propagation failed for 退る, switching to DBSCAN
# Affinity propagation failed for 退職, switching to DBSCAN
# Affinity propagation failed for 送信, switching to DBSCAN
# Affinity propagation failed for 逃げる, switching to DBSCAN
# Affinity propagation failed for 透明, switching to DBSCAN
# Affinity propagation failed for 通告, switching to DBSCAN
# Affinity propagation failed for 通商, switching to DBSCAN
# Affinity propagation failed for 通学, switching to DBSCAN
# Affinity propagation failed for 通訳, switching to DBSCAN
# Affinity propagation failed for 逝去, switching to DBSCAN
# Affinity propagation failed for 造園, switching to DBSCAN
# Affinity propagation failed for 連勝, switching to DBSCAN
# Affinity propagation failed for 連敗, switching to DBSCAN
# Affinity propagation failed for 連発, switching to DBSCAN
# Affinity propagation failed for 連行, switching to DBSCAN
# Affinity propagation failed for 連装, switching to DBSCAN
# Affinity propagation failed for 連載, switching to DBSCAN
# Affinity propagation failed for 進化, switching to DBSCAN
# Affinity propagation failed for 進学, switching to DBSCAN
# Affinity propagation failed for 進展, switching to DBSCAN
# Affinity propagation failed for 進撃, switching to DBSCAN
# Affinity propagation failed for 進軍, switching to DBSCAN
# Affinity propagation failed for 遂行, switching to DBSCAN
# Affinity propagation failed for 遅延, switching to DBSCAN
# Affinity propagation failed for 遊び, switching to DBSCAN
# Affinity propagation failed for 遊園, switching to DBSCAN
# Affinity propagation failed for 遊撃手, switching to DBSCAN
# Affinity propagation failed for 運動会, switching to DBSCAN
# Affinity propagation failed for 運河, switching to DBSCAN
# Affinity propagation failed for 過激, switching to DBSCAN
# Affinity propagation failed for 道路, switching to DBSCAN
# Affinity propagation failed for 達す, switching to DBSCAN
# Affinity propagation failed for 達人, switching to DBSCAN
# Affinity propagation failed for 遠距離, switching to DBSCAN
# Affinity propagation failed for 適す, switching to DBSCAN
# Affinity propagation failed for 適正, switching to DBSCAN
# Affinity propagation failed for 適用, switching to DBSCAN
# Affinity propagation failed for 選ぶ, switching to DBSCAN
# Affinity propagation failed for 選手権, switching to DBSCAN
# Affinity propagation failed for 選曲, switching to DBSCAN
# Affinity propagation failed for 選書, switching to DBSCAN
# Affinity propagation failed for 選考, switching to DBSCAN
# Affinity propagation failed for 遺す, switching to DBSCAN
# Affinity propagation failed for 遺伝, switching to DBSCAN
# Affinity propagation failed for 遺伝子, switching to DBSCAN
# Affinity propagation failed for 遺体, switching to DBSCAN
# Affinity propagation failed for 遺跡, switching to DBSCAN
# Affinity propagation failed for 邸宅, switching to DBSCAN
# Affinity propagation failed for 部員, switching to DBSCAN
# Affinity propagation failed for 部数, switching to DBSCAN
# Affinity propagation failed for 都会, switching to DBSCAN
# Affinity propagation failed for 都立, switching to DBSCAN
# Affinity propagation failed for 配分, switching to DBSCAN
# Affinity propagation failed for 配属, switching to DBSCAN
# Affinity propagation failed for 酸化, switching to DBSCAN
# Affinity propagation failed for 重傷, switching to DBSCAN
# Affinity propagation failed for 重用, switching to DBSCAN
# Affinity propagation failed for 重臣, switching to DBSCAN
# Affinity propagation failed for 重量, switching to DBSCAN
# Affinity propagation failed for 野望, switching to DBSCAN
# Affinity propagation failed for 金利, switching to DBSCAN
# Affinity propagation failed for 金子, switching to DBSCAN
# Affinity propagation failed for 金星, switching to DBSCAN
# Affinity propagation failed for 金銭, switching to DBSCAN
# Affinity propagation failed for 金額, switching to DBSCAN
# Affinity propagation failed for 鉄人, switching to DBSCAN
# Affinity propagation failed for 鉄路, switching to DBSCAN
# Affinity propagation failed for 銀座, switching to DBSCAN
# Affinity propagation failed for 銀河, switching to DBSCAN
# Affinity propagation failed for 銀行, switching to DBSCAN
# Affinity propagation failed for 銃撃, switching to DBSCAN
# Affinity propagation failed for 鎮圧, switching to DBSCAN
# Affinity propagation failed for 鎮守, switching to DBSCAN
# Affinity propagation failed for 長らく, switching to DBSCAN
# Affinity propagation failed for 長女, switching to DBSCAN
# Affinity propagation failed for 長寿, switching to DBSCAN
# Affinity propagation failed for 長年, switching to DBSCAN
# Affinity propagation failed for 長男, switching to DBSCAN
# Affinity propagation failed for 長距離, switching to DBSCAN
# Affinity propagation failed for 長身, switching to DBSCAN
# Affinity propagation failed for 門前, switching to DBSCAN
# Affinity propagation failed for 門前, switching to DBSCAN
# Affinity propagation failed for 閉じる, switching to DBSCAN
# Affinity propagation failed for 開場, switching to DBSCAN
# Affinity propagation failed for 開始, switching to DBSCAN
# Affinity propagation failed for 開局, switching to DBSCAN
# Affinity propagation failed for 開店, switching to DBSCAN
# Affinity propagation failed for 開戦, switching to DBSCAN
# Affinity propagation failed for 開業, switching to DBSCAN
# Affinity propagation failed for 開発, switching to DBSCAN
# Affinity propagation failed for 開閉, switching to DBSCAN
# Affinity propagation failed for 間接, switching to DBSCAN
# Affinity propagation failed for 関わり, switching to DBSCAN
# Affinity propagation failed for 関心, switching to DBSCAN
# Affinity propagation failed for 関数, switching to DBSCAN
# Affinity propagation failed for 関東, switching to DBSCAN
# Affinity propagation failed for 防止, switching to DBSCAN
# Affinity propagation failed for 防波堤, switching to DBSCAN
# Affinity propagation failed for 防空, switching to DBSCAN
# Affinity propagation failed for 防衛, switching to DBSCAN
# Affinity propagation failed for 阻害, switching to DBSCAN
# Affinity propagation failed for 降水, switching to DBSCAN
# Affinity propagation failed for 限定, switching to DBSCAN
# Affinity propagation failed for 限度, switching to DBSCAN
# Affinity propagation failed for 限界, switching to DBSCAN
# Affinity propagation failed for 陣地, switching to DBSCAN
# Affinity propagation failed for 除去, switching to DBSCAN
# Affinity propagation failed for 除外, switching to DBSCAN
# Affinity propagation failed for 陸海, switching to DBSCAN
# Affinity propagation failed for 隔週, switching to DBSCAN
# Affinity propagation failed for 隠す, switching to DBSCAN
# Affinity propagation failed for 隷下, switching to DBSCAN
# Affinity propagation failed for 集団, switching to DBSCAN
# Affinity propagation failed for 集結, switching to DBSCAN
# Affinity propagation failed for 雇用, switching to DBSCAN
# Affinity propagation failed for 難い, switching to DBSCAN
# Affinity propagation failed for 難い, switching to DBSCAN
# Affinity propagation failed for 難易, switching to DBSCAN
# Affinity propagation failed for 雷撃, switching to DBSCAN
# Affinity propagation failed for 電子, switching to DBSCAN
# Affinity propagation failed for 電機, switching to DBSCAN
# Affinity propagation failed for 電気, switching to DBSCAN
# Affinity propagation failed for 電池, switching to DBSCAN
# Affinity propagation failed for 電脳, switching to DBSCAN
# Affinity propagation failed for 電車, switching to DBSCAN
# Affinity propagation failed for 需要, switching to DBSCAN
# Affinity propagation failed for 震災, switching to DBSCAN
# Affinity propagation failed for 青少年, switching to DBSCAN
# Affinity propagation failed for 青年, switching to DBSCAN
# Affinity propagation failed for 非公式, switching to DBSCAN
# Affinity propagation failed for 革命, switching to DBSCAN
# Affinity propagation failed for 革新, switching to DBSCAN
# Affinity propagation failed for 預金, switching to DBSCAN
# Affinity propagation failed for 領内, switching to DBSCAN
# Affinity propagation failed for 頭取, switching to DBSCAN
# Affinity propagation failed for 頻繁, switching to DBSCAN
# Affinity propagation failed for 題材, switching to DBSCAN
# Affinity propagation failed for 風貌, switching to DBSCAN
# Affinity propagation failed for 風雲, switching to DBSCAN
# Affinity propagation failed for 飛行場, switching to DBSCAN
# Affinity propagation failed for 飛行機, switching to DBSCAN
# Affinity propagation failed for 食い, switching to DBSCAN
# Affinity propagation failed for 食材, switching to DBSCAN
# Affinity propagation failed for 食物, switching to DBSCAN
# Affinity propagation failed for 食用, switching to DBSCAN
# Affinity propagation failed for 飲料, switching to DBSCAN
# Affinity propagation failed for 飲酒, switching to DBSCAN
# Affinity propagation failed for 飲食, switching to DBSCAN
# Affinity propagation failed for 飾る, switching to DBSCAN
# Affinity propagation failed for 養女, switching to DBSCAN
# Affinity propagation failed for 養父, switching to DBSCAN
# Affinity propagation failed for 養護, switching to DBSCAN
# Affinity propagation failed for 首都, switching to DBSCAN
# Affinity propagation failed for 馬主, switching to DBSCAN
# Affinity propagation failed for 駐屯, switching to DBSCAN
# Affinity propagation failed for 駐留, switching to DBSCAN
# Affinity propagation failed for 騎乗, switching to DBSCAN
# Affinity propagation failed for 騎士, switching to DBSCAN
# Affinity propagation failed for 騒ぎ, switching to DBSCAN
# Affinity propagation failed for 騒音, switching to DBSCAN
# Affinity propagation failed for 驚く, switching to DBSCAN
# Affinity propagation failed for 高原, switching to DBSCAN
# Affinity propagation failed for 高圧, switching to DBSCAN
# Affinity propagation failed for 高性能, switching to DBSCAN
# Affinity propagation failed for 高架, switching to DBSCAN
# Affinity propagation failed for 高校, switching to DBSCAN
# Affinity propagation failed for 高等, switching to DBSCAN
# Affinity propagation failed for 高齢, switching to DBSCAN
# Affinity propagation failed for 魔界, switching to DBSCAN
# Affinity propagation failed for 魚類, switching to DBSCAN
# Affinity propagation failed for 鳥居, switching to DBSCAN
# Affinity propagation failed for 鹿毛, switching to DBSCAN
# Affinity propagation failed for 黄色, switching to DBSCAN
# Affinity propagation failed for 黙示録, switching to DBSCAN

# %% [markdown]
# ### Consolidate part of speech and remarks

# %%
subset['remarks'] = subset['remarks'].apply(lambda x: ', '.join([str(s) for s in set(x)]))

# %%
subset['part_of_speech'] = subset['part_of_speech'].apply(lambda x: ', '.join([str(s) for s in set(x)]))

# %%
subset.sample(n=5)
# Out:
#      kanji reading                                     part_of_speech  \
# 2802  引き換え    ひきかえ                       noun (common) (futsuumeishi)
# 6303    連携    れんけい  noun (common) (futsuumeishi); noun or particip...
# 2871    役所   やくどころ                       noun (common) (futsuumeishi)
# 2678    幕府     ばくふ                       noun (common) (futsuumeishi)
# 1510    古今     ここん  noun (common) (futsuumeishi); nouns which may ...
#
#                                            raw_meanings  max_grade  \
# 2802                             [exchange, conversion]        8.2
# 6303                  [cooperation, coordination, link]        8.2
# 2871  [assigned role, duty, position, suitable role,...        3.0
# 2678                                [bakufu, shogunate]        6.0
# 1510  [ancient and modern times, all ages, past and ...        2.0
#
#       rank_quantile remarks               jpn_sentence_1  \
# 2802             15    None  彼はケーキ１切れと引き換えにオレンジ１個を私にくれた。
# 6303              4    None                          NaN
# 2871             10    None                         None
# 2678              2    None          徳川幕府は１８６８年に終わりを告げた。
# 1510             11    None           古今を通して彼は又とない勇敢な男だ。
#
#                                          eng_sentence_1     jpn_sentence_2  \
# 2802  He gave me an orange in exchange for a piece o...  彼はお金と引換に切符を受け取った。
# 6303                                                NaN               None
# 2871                                               None               None
# 2678     The Tokugawa Shogunate came to an end in 1868.               None
# 1510             He is as brave a man as ever breathed.        彼は古今最上の詩人だ。
#
#                                      eng_sentence_2 jpn_sentence_3  \
# 2802  He received a ticket in return for the money.           None
# 6303                                           None           None
# 2871                                           None           None
# 2678                                           None           None
# 1510           He is as great a poet as ever lived.      古今無双の勇士だ。
#
#                                   eng_sentence_3  \
# 2802                                        None
# 6303                                        None
# 2871                                        None
# 2678                                        None
# 1510  He is the bravest soldier that ever lived.
#
#                                                clusters  \
# 2802                                        dbscan - {}
# 6303  affinity - {0: ['cooperation', 'coordination']...
# 2871  affinity - {0: ['duty'], 1: ['position', 'best...
# 2678                            ['bakufu', 'shogunate']
# 1510  affinity - {0: ['ancient and modern times', 'p...
#
#                                  english
# 2802                exchange, conversion
# 6303                   cooperation, link
# 2871       duty, position, suitable role
# 2678                   bakufu, shogunate
# 1510  ancient and modern times, all ages

# %% [markdown]
# ## Add hints for duplicate kanji spellings

# %%
def create_reading_hints(subgroup):
    if len(subgroup) == 1:
        subgroup['hint'] = None
    else:
        for i in subgroup.index:
            hint = ', '.join(['not ' + subgroup.at[j, 'reading'] for j in subgroup.index if j!=i])
            subgroup.at[i, 'hint'] = hint
    return subgroup

# %%
subset = subset.groupby('kanji').apply(create_reading_hints)

# %% [markdown]
# ## Add unique id

# %%
def create_compound_id(row):
    key = f"{row['kanji']} [{row['reading']}]"
    return hashlib.sha1(key.encode('utf-8')).hexdigest()

# %%
subset['id'] = subset.apply(create_compound_id, axis=1)

# %% [markdown]
# ## Add tags

# %%
subset['quantile_bin'] = pd.cut(subset['rank_quantile'],
                                bins=[-1, 7, 15, 25, 100],
                                labels=['top_7', 'top_15', 'top_25', 'rest'])

# %%
def process_tags(row):
    if int(row['max_grade']) == row['max_grade']:
        max_grade_tag = str(int(row['max_grade']))
    else:
        max_grade_tag = str(row['max_grade']).replace('.', '_')
    return f'max_grade_{max_grade_tag} ' + row['quantile_bin']
    
    
subset['tags'] = subset.apply(process_tags, axis=1)

# %% [markdown]
# ## Export final results

# %%
subset['last_updated_on'] = str(dt.date.today())

subset = subset[['id', 'kanji', 'hint', 'reading', 'part_of_speech', 'english',
                 'remarks', 'max_grade', 'rank_quantile', 'jpn_sentence_1', 'eng_sentence_1',
                 'jpn_sentence_2', 'eng_sentence_2', 'jpn_sentence_3', 'eng_sentence_3', 'raw_meanings', 'clusters',
                 'last_updated_on', 'tags']].copy()

# %%
assert np.sum(subset['id'].duplicated()) == 0
assert len(selection) == len(subset)

# %%
subset.sample(n=5)
# Out:
#                                             id kanji  hint reading  \
# 4019  eac15a4cb72e1b4f74cd5d86877640fdeccca02e    権限  None    けんげん
# 2070  579c51e5e704826f683000db70be3c941d21d9df    大正  None   たいしょう
# 224   cabde55fa9630fce5102a86e08e28df1ec2a6a98    与る  None    あずかる
# 2218  e243f825822e676306bbfbfb2938fba4b044666a    姿勢  None     しせい
# 1464  49db6e3b9b91b47a95ee843e386ba762f7f1121e    収益  None   しゅうえき
#
#                                       part_of_speech  \
# 4019                    noun (common) (futsuumeishi)
# 2070                    noun (common) (futsuumeishi)
# 224   Godan verb with 'ru' ending; intransitive verb
# 2218                    noun (common) (futsuumeishi)
# 1464                    noun (common) (futsuumeishi)
#
#                                             english  \
# 4019                               power, authority
# 2070  Taishō era (1912.7.30-1926.12.25), Taisho era
# 224           to take part in, to receive, to enjoy
# 2218           pose, carriage (of the body), stance
# 1464                               returns, revenue
#
#                                     remarks  max_grade  rank_quantile  \
# 4019                                   None        6.0              6
# 2070                                   None        1.0              1
# 224   word usually written using kana alone        8.1             10
# 2218                                   None        6.0              5
# 1464                                   None        6.0             10
#
#                                     jpn_sentence_1  \
# 4019                                彼らを解雇する権限をくれた。
# 2070                                           NaN
# 224            クラブの今日の発展にはこれらの人々の努力があずかって大いに力があった。
# 2218                               聴衆は謹聴の姿勢で立っていた。
# 1464  経営陣は収益の短期的改善に気を取られすぎて、長期的な将来計画に気が回らない傾向があった。
#
#                                          eng_sentence_1  \
# 4019                 He gave me authority to fire them.
# 2070                                                NaN
# 224   What this club is today is largely due to the ...
# 2218      The listeners stood in an attentive attitude.
# 1464  The management tended to be too concerned abou...
#
#                                      jpn_sentence_2  \
# 4019  民衆の熱狂的な彼への支持は、首相の座にとどまりながらも大統領の権限の発揮を可能にしそうだ。
# 2070                                           None
# 224                                            None
# 2218                あまりに長く１つの姿勢で座っていた為に彼の筋肉はずきずきした。
# 1464                                会社の収益は飛躍的に増加した。
#
#                                          eng_sentence_2  \
# 4019  Having reached the rank of prime minister, and...
# 2070                                               None
# 224                                                None
# 2218  His muscles ached from sitting too long in one...
# 1464                      The company's profits soared.
#
#                             jpn_sentence_3  \
# 4019                          彼らは権限を剥奪された。
# 2070                                  None
# 224                                   None
# 2218  熊が眠ったり横になるとき、その姿勢は熱を逃したいのか保ちたいのかによる。
# 1464                         旅行会社の収益が急増した。
#
#                                          eng_sentence_3  \
# 4019            The men have been shorn of their power.
# 2070                                               None
# 224                                                None
# 2218  When bears sleep or lie down, their postures d...
# 1464                   Travel agencies' profits soared.
#
#                                            raw_meanings  \
# 4019                   [power, authority, jurisdiction]
# 2070    [Taishō era (1912.7.30-1926.12.25), Taisho era]
# 224   [to participate in, to take part in, to play a...
# 2218  [posture, pose, position, stance, carriage (of...
# 1464             [earnings, proceeds, returns, revenue]
#
#                                                clusters last_updated_on  \
# 4019  affinity - {0: ['power'], 1: ['authority', 'ju...      2021-08-16
# 2070                                        dbscan - {}      2021-08-16
# 224   affinity - {0: ['to participate in', 'to take ...      2021-08-16
# 2218  affinity - {0: ['pose'], 1: ['carriage (of the...      2021-08-16
# 1464  affinity - {0: ['returns'], 1: ['earnings', 'p...      2021-08-16
#
#                       tags
# 4019     max_grade_6 top_7
# 2070     max_grade_1 top_7
# 224   max_grade_8_1 top_15
# 2218     max_grade_6 top_7
# 1464    max_grade_6 top_15

# %%
len(subset)
# Out:
# 6989

# %%
file_name = f'{DATA_PATH}/compound_flashcards_lt{MAX_GRADE}_top_{MAX_QUANTILE}_pct.csv'
subset.to_csv(file_name, index=False, header=False)

file_name
# Out:
# '/Users/glillacci/OneDrive - Tesco/Personal/Data/kanjidata/compound_flashcards_lt8.4_top_15_pct.csv'
