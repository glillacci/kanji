# %% [markdown]
# # Find kanji in White Rabbit Press flashcards

# %%
import numpy as np
import pandas as pd
import re

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Digitized White Rabbit Press (old edition) index

# %%
df_wro = pd.read_csv('./data/white_rabbit_old.csv')
df_wro['wr_old'] = df_wro['wr_old'].astype(int)

# %% [markdown]
# ### Kanji by new JLPT level

# %%
df_jlpt = pd.read_csv('./data/kanji_by_new_jlpt_level.csv')

# %% [markdown]
# ### Kanjidic with additional data

# %%
kanji = pd.read_parquet('./data/kanjidic_with_additional_data.parquet')
kanji = kanji[['kanji', 'grade', 'jlpt_level', 'stroke_count', 'onyomi', 'kunyomi', 'nanori',
               'core_meaning_1', 'core_meaning_2', 'core_meaning_3', 'original_grade']]

# %%
kanji['jlpt_level'] = kanji['jlpt_level'].fillna(0).astype(int)
kanji['original_grade'] = kanji['original_grade'].fillna(11).astype(int)

# %%
kanji
# Out:
#       kanji      grade  jlpt_level  stroke_count      onyomi  \
# 0         亜   常用ー漢検準２級           1             7         [ア]
# 1         唖  11.0(1.5)           0            10     [ア, アク]
# 2         娃   9.0(1.5)           0             9  [ア, アイ, ワ]
# 3         阿   9.0(1.5)           1             8      [ア, オ]
# 4         哀    常用ー漢検３級           1             9        [アイ]
# ...     ...        ...         ...           ...         ...
# 13103     辶  11.0(nan)           0             3        None
# 13104     逸  10.0(nan)           0            12        None
# 13105     難  10.0(nan)           0            19        [ナン]
# 13106     響  10.0(nan)           0            22       [キョウ]
# 13107     頻  11.0(nan)           0            16        [ヒン]
#
#                       kunyomi                    nanori  \
# 0                     [[つ.ぐ]]               [や, つぎ, つぐ]
# 1                        [おし]                      None
# 2                    [うつく.しい]                       [い]
# 3                 [おもね.る, くま]  [ほとり, あず, あわ, おか, きた, な]
# 4      [あわ.れ, あわ.れむ, [かな.しい]]                      None
# ...                       ...                       ...
# 13103                 [しんにょう]                      None
# 13104                 [しんにょう]                      None
# 13105            [かたい, むずかしい]                      None
# 13106                   [ひびく]                      None
# 13107                    None                      None
#
#                      core_meaning_1 core_meaning_2 core_meaning_3  \
# 0                              sub-   phonetic [a]           None
# 1                              None           None           None
# 2                         beautiful           None           None
# 3                      phonetic [a]           None           None
# 4                            sorrow           pity           None
# ...                             ...            ...            ...
# 13103  radical shinnyō (or shinnyū)           None           None
# 13104                      let slip           None           None
# 13105                     difficult       disaster           None
# 13106                   reverberate           None           None
# 13107                    frequently           None           None
#
#        original_grade
# 0                   8
# 1                  11
# 2                   9
# 3                   9
# 4                   8
# ...               ...
# 13103              11
# 13104              10
# 13105              10
# 13106              10
# 13107              11
#
# [13108 rows x 11 columns]

# %% [markdown]
# ### JMdict

# %%
jmdict = pd.read_parquet('./data/jmdict.parquet')
jmdict = jmdict.loc[jmdict['sense_no'] == 1,
                    ['main_spelling', 'main_reading', 'meaning', 'part_of_speech', 'remarks']]
jmdict.sample(frac=0.001)
# Out:
#           main_spelling       main_reading  \
# 157124             愛敬付く            あいぎょうづく
# 106078             研修旅行          けんしゅうりょこう
# 65552               逆作用             ぎゃくさよう
# 125032            割付け配列           わりつけはいれつ
# 75127              労働協約          ろうどうきょうやく
# 102537               同法               どうほう
# 47051              夫婦連れ              ふうふづれ
# 27654                細菌               さいきん
# 127662           著作権図書館        ちょさくけんとしょかん
# 129715              ホモ達               ホモだち
# 165293               寒蛩              かんきょう
# 17973               花冷え               はなびえ
# 26380                講評              こうひょう
# 163436              小三元            しょうさんげん
# 67441               対戦車             たいせんしゃ
# 168959            有意性検定          ゆういせいけんてい
# 120280             None          ケーブルマッチャー
# 32644                商船              しょうせん
# 120573             None           サーフィスモデル
# 128381              非圧縮             ひあっしゅく
# 83878          非難の目を向ける          ひなんのめをむける
# 9044               None                バッジ
# 64185                後出              こうしゅつ
# 13520              None              ロンパース
# 156055             船舶職員          せんぱくしょくいん
# 161619               遠行               えんこう
# 155933             None             ブールマニエ
# 161843             ナノ結晶            ナノけっしょう
# 163781               棒飴               ぼうあめ
# 59562                篆刻               てんこく
# 25193               後天的             こうてんてき
# 103187           石焼ビビンバ           いしやきビビンバ
# 174104             None             アーコロジー
# 159406               橙酢              だいだいず
# 7810               None              トラバーユ
# 187582              八割方             はちわりがた
# 48605                勉学               べんがく
# 57618                割符                わりふ
# 54101                緞帳              どんちょう
# 33538               情報源            じょうほうげん
# 126291             自己資源              じこしげん
# 114089               四胡                 しこ
# 185267           面子を立てる            メンツをたてる
# 123133             None       ブロードキャストアドレス
# 129856             リング状             リングじょう
# 4199               None         グラフィックデザイン
# 144021              ちん毛                ちんげ
# 55456                夜行                やこう
# 39302                 達                 たち
# 184449              縦巻き               たてまき
# 47755               分水嶺             ぶんすいれい
# 96206              厭戦気分            えんせんきぶん
# 76451               慣用語              かんようご
# 97483               耳年増              みみどしま
# 3079               None               オナニー
# 164858              海老芋               えびいも
# 32934               消極的           しょうきょくてき
# 167900             ムラッ気               ムラッけ
# 17336            何とはなしに            なんとはなしに
# 113658            面積グラフ            めんせきグラフ
# 18579              海岸通り            かいがんどおり
# 165945              直閃石            ちょくせんせき
# 109510             皿うどん              さらうどん
# 77496                本色              ほんしょく
# 22663             九死に一生         きゅうしにいっしょう
# 101674               星人               せいじん
# 123172      プラスチック光ファイバ      プラスチックひかりファイバ
# 33458               冗長度            じょうちょうど
# 24820               古筆家               こひつか
# 95311              万物流転            ばんぶつるてん
# 168627               一山               いっさん
# 76913               時代物              じだいもの
# 65457                頭蓋                ずがい
# 59591                緑虫              みどりむし
# 158700             鉤頭動物           こうとうどうぶつ
# 40023                中外              ちゅうがい
# 2696               None              エレガンス
# 79567               嘘泣き               うそなき
# 448                  颯と                さっと
# 101108            お百姓さん          おひゃくしょうさん
# 135612             旅人の木             たびびとのき
# 68841              封切り館             ふうきりかん
# 121957             None            トラックパッド
# 188660             None                 バス
# 15863               運動量            うんどうりょう
# 66683               遅進児               ちしんじ
# 96072              相碁井目            あいごせいもく
# 104254             口に運ぶ             くちにはこぶ
# 160048             わら細工              わらざいく
# 5407               None            シーロスタット
# 178356               福豆               ふくまめ
# 49949             万里の長城         ばんりのちょうじょう
# 37413                狙撃                そげき
# 5960               None            ジャンクション
# 62080                結願               けちがん
# 2440               None              エアポート
# 56004                兼々               かねがね
# 28473             蚕糸試験所           さんししけんじょ
# 15135                一得               いっとく
# 175228             None                ハヌカ
# 41796              伝記作者            でんきさくしゃ
# 96186              永字八法            えいじはっぽう
# 145226              Ｃ言語              シーげんご
# 16915              下がり松              さがりまつ
# 137294              蛸の木               たこのき
# 182914             None            パルミジャーノ
# 157226             None               タラーリ
# 130881             口承文芸          こうしょうぶんげい
# 10201              None             フランシウム
# 25319             語呂合わせ              ごろあわせ
# 29623                時価                 じか
# 654               だらし無い              だらしない
# 186836               貧生               ひんせい
# 154302               干潮              かんちょう
# 24389               原子雲              げんしぐも
# 79861              言い置く               いいおく
# 126821       条件付きエントロピー      じょうけんつきエントロピー
# 116077             視覚効果             しかくこうか
# 186708            買い物好き             かいものずき
# 5977               None           ジュークボックス
# 167                 お歯黒               おはぐろ
# 115710             None          ショルダーベーコン
# 11382              None                ボルト
# 28070                三育               さんいく
# 106711           一本建て為替          いっぽんだてかわせ
# 183994              至らぬ               いたらぬ
# 95136              弧影悄然           こえいしょうぜん
# 148142            釣りに行く              つりにいく
# 174896               台屋                だいや
# 77907               濃度計              のうどけい
# 129301             連邦赤字            れんぽうあかじ
# 143524              結び状             むすびじょう
# 46282              標準誤差           ひょうじゅんごさ
# 90251              外部寄生             がいぶきせい
# 107872              歩行虫               おさむし
# 102192             None              やさぐれる
# 56886                夏向               なつむき
# 79223                白星               しろぼし
# 154210               春期               しゅんき
# 158607             大足尖鼠         おおあしとがりねずみ
# 65157                排雪               はいせつ
# 46155                必見               ひっけん
# 104811             世界有数            せかいゆうすう
# 99564              数え直す             かぞえなおす
# 159362              現代風             げんだいふう
# 78799               角隠し              つのかくし
# 152580            面接受験者         めんせつじゅけんしゃ
# 32202                 初                 はつ
# 174006             重力定数         じゅうりょくていすう
# 115733               娩出              べんしゅつ
# 7764               None               トフィー
# 154044            連結売上高         れんけつうりあげだか
# 20502                帰社                きしゃ
# 32987               こげ茶               こげちゃ
# 40327               酎ハイ              ちゅうハイ
# 88787           カルヴァン主義           カルヴァンしゅぎ
# 17404               何度か               なんどか
# 183538             一万円札           いちまんえんさつ
# 46798                不党                ふとう
# 81491             記録を破る            きろくをやぶる
# 119276             None      インラインディスカッション
# 77053                色物               いろもの
# 170440             建設残土            けんせつざんど
# 163109              刺繍枠             ししゅうわく
# 60156                仁慈                じんじ
# 100994             None                こりゃ
# 23991               建設者             けんせつしゃ
# 75840              担子菌類            たんしきんるい
# 141454          鎌首をもたげる          かまくびをもたげる
# 157636              海松茶               みるちゃ
# 166076               真榊               まさかき
# 48687               保険証             ほけんしょう
# 29670               次いで                ついで
# 82654             寿司を握る             すしをにぎる
# 181583           特別養子縁組        とくべつようしえんぐみ
# 144308             None             スジクロハギ
# 18766                外す                はずす
# 51525              予行演習           よこうえんしゅう
# 180080             None             バルクセール
# 108469               亙古                こうこ
# 136274              競り手                せりて
# 111762             と言うか               というか
# 174640           パリ講和会議           パリこうわかいぎ
# 115359             パーリ語               パーリご
# 156459              脱分極            だつぶんきょく
# 122318  ハイパーテキスト転送プロトコル  ハイパーテキストてんそうプロトコル
# 73993                折線               せっせん
# 30929                首脳               しゅのう
# 62787               帳付け              ちょうつけ
#
#                                                   meaning  \
# 157124  to have a charming face, voice, personality, e...
# 106078                                         study tour
# 65552                            reaction, adverse effect
# 125032                                  allocatable array
# 75127                   labor agreement, labour agreement
# 102537                              same law, same method
# 47051    husband and wife travelling together (traveling)
# 27654                           bacterium, bacteria, germ
# 127662                                  copyright library
# 129715                                  homosexual friend
# 165293                chirping of crickets in late autumn
# 17973                               chilly spring weather
# 26380   criticism (by a teacher or coach, with comment...
# 163436  little three dragons, winning hand that contai...
# 67441                                           anti-tank
# 168959            test of significance, significance test
# 120280                                      cable matcher
# 32644                                       merchant ship
# 120573                                      surface model
# 128381                                      noncompressed
# 83878   to regard someone with odium, to look at someo...
# 9044                                                badge
# 64185                                    later, following
# 13520                                             rompers
# 156055                  ship's personnel, ship's officers
# 161619                                         going afar
# 155933                                       beurre manié
# 161843                                        nanocrystal
# 163781  candy stick, stick candy, candy on a stick (e....
# 59562                                      seal engraving
# 25193                              a posteriori, acquired
# 103187  stone-roasted bibimbap, Korean style rice (bib...
# 174104              arcology (from architectural ecology)
# 159406  bitter orange juice, used in cooking as a vinegar
# 7810                     job change, change of occupation
# 187582                about 80%, almost certainly, mostly
# 48605                         study, pursuit of knowledge
# 57618   tally, check, piece of wood or paper split in ...
# 54101                         thick curtain, drop curtain
# 33538          source of information, intelligence source
# 126291                                     local resource
# 114089  sihu (4-stringed Chinese musical instrument pl...
# 185267                                       to save face
# 123133                                  broadcast address
# 129856                            ring (shaped), circular
# 4199                                       graphic design
# 144021                             pubic hair (on a male)
# 55456               walking around at night, night travel
# 39302   pluralizing suffix (esp. for people and animal...
# 184449          longitudinal winding, curling (e.g. hair)
# 47755                                   watershed, divide
# 96206                            feeling of war-weariness
# 76451                                               idiom
# 97483   young woman with a lot of superficial knowledg...
# 3079                                         masturbation
# 164858                         shrimp-shaped taro variety
# 32934        negative, passive, half-hearted, unmotivated
# 167900                       capricious, moody, whimsical
# 17336   for no particular reason, for some reason or o...
# 113658                                         area graph
# 18579                                    sea-front street
# 165945                                      anthophyllite
# 109510     Nagasaki dish of noodles with various toppings
# 77496                                one's real character
# 22663                            narrow escape from death
# 101674                        person from (the planet of)
# 123172                              plastic optical fiber
# 33458                     redundancy (information theory)
# 24820                               expert in old writing
# 95311   all things are in a state of flux, everything ...
# 168627  whole temple complex, all the temples on a mou...
# 76913                          antique, historical object
# 65457                                      cranium, skull
# 59591                     euglena (freshwater flagellate)
# 158700  acanthocephales, thorny-headed worms, spiny-he...
# 40023               home and abroad, domestic and foreign
# 2696                                             elegance
# 79567                      faking crying, crocodile tears
# 448                                quickly (esp. actions)
# 101108                                             farmer
# 135612  traveller's tree (Ravenala madagascariensis), ...
# 68841                first-run theater, first-run theatre
# 121957                                          track pod
# 188660                                               bath
# 15863                                            momentum
# 66683                                        slow learner
# 96072   In every game or play, differences in skill be...
# 104254                      to put into the mouth, to eat
# 160048                            straw work, straw craft
# 5407                                            coelostat
# 178356                parched beans scattered on Setsubun
# 49949                                 Great Wall of China
# 37413                                   shooting, sniping
# 5960      junction, system interchange (between highways)
# 62080                         expiration of term of a vow
# 2440                                              airport
# 56004   since long ago, already, for quite a while, fo...
# 28473                             silk experiment station
# 15135                                one advantage, merit
# 175228             Hanukkah, Chanukah, Festival of Lights
# 41796                                          biographer
# 96186   Eight Principles of Yong, principles for writi...
# 145226                             C programming language
# 16915                                       drooping pine
# 137294        Pandanus boninensis (species of screw pine)
# 182914             Parmesan (cheese), Parmigiano-Reggiano
# 157226  taralli (Italian snack food resembling a bread...
# 130881                          oral literature, folklore
# 10201                                       francium (Fr)
# 25319                    rhyming game, play on words, pun
# 29623                  current value, price, market value
# 654     slovenly (appearance, work, etc.), sloppy, unt...
# 186836                 impoverished student, poor student
# 154302                           low tide, low water, ebb
# 24389                                        atomic cloud
# 79861                   to leave word, to leave a message
# 126821  conditional entropy, mean conditional informat...
# 116077                  visual effect(s) (e.g. in a film)
# 186708       shopaholic, compulsive buying, shopaholicism
# 5977                                             juke-box
# 167                                      tooth blackening
# 115710                                     shoulder bacon
# 11382                                                volt
# 28070            education of the head and hand and heart
# 106711                                        single rate
# 183994       imperfect, incompetent, inadequate, careless
# 95136   lonely and crestfallen, a lonely and heavy-hea...
# 148142                                      to go fishing
# 174896                    caterer in a red-light district
# 77907                                        densitometer
# 129301                           federal (budget) deficit
# 143524                                     knotted letter
# 46282                                  standard error, SE
# 90251                                      ectoparasitism
# 107872  ground beetle, carabid (esp. of subfamily Cara...
# 102192                             to sulk, to be peevish
# 56886                                          for summer
# 79223                            white circle, white star
# 154210           spring term (e.g. school), spring period
# 158607             long-clawed shrew (Sorex unguiculatus)
# 65157                                     removal of snow
# 46155                  must-see, not to be missed, a must
# 104811                                      world-leading
# 99564                                      to count again
# 159362                           modern style, modernness
# 78799                                  bride's head-dress
# 152580                                        interviewee
# 32202                                          first, new
# 174006                             gravitational constant
# 115733                             giving birth, delivery
# 7764                                        toffee, toffy
# 154044         consolidated sales, consolidated net sales
# 20502                                    return to office
# 32987                             dark brown, olive brown
# 40327   shōchū highball, cocktail of shōchū with tonic...
# 88787                                           Calvinism
# 17404                        several times, once or twice
# 183538                                    10,000 yen bill
# 46798                                    nonparticipation
# 81491              to break the record, to break a record
# 119276                                  inline discussion
# 77053   colored thing (clothing, fabric, paper, etc.) ...
# 170440   construction waste soil, surplus excavation soil
# 163109  embroidery frame, embroidery hoop, tabouret, t...
# 60156                           kind-hearted, benevolence
# 100994                         hey there, I say, see here
# 23991                                           architect
# 75840                                      basidiomycetes
# 141454              to raise one's head (esp. of a snake)
# 157636                      brown tinged with olive green
# 166076   evergreen (esp. one planted or used at a shrine)
# 48687                                      insurance card
# 29670                        next, secondly, subsequently
# 82654                           to make hand-rolled sushi
# 181583  special adoption, plenary adoption, adoption i...
# 144308  whitebar surgeonfish (Acanthurus leucopareius,...
# 18766   to remove, to take off, to detach, to unfasten...
# 51525                                  dry run, rehearsal
# 180080                                          bulk sale
# 108469             from long ago up until the present day
# 136274                        bidder (e.g. in an auction)
# 111762  or perhaps I should say, or more precisely, or...
# 174640  Paris Peace Conference (1919), Versailles Peac...
# 115359                                    Pali (language)
# 156459                     depolarization, depolarisation
# 122318                  HyperText Transfer Protocol, HTTP
# 73993                                         broken line
# 30929                                   head, leader, top
# 62787                             bookkeeping, bookkeeper
#
#                                            part_of_speech  \
# 157124                        Godan verb with `ku' ending
# 106078                       noun (common) (futsuumeishi)
# 65552                        noun (common) (futsuumeishi)
# 125032                       noun (common) (futsuumeishi)
# 75127                        noun (common) (futsuumeishi)
# 102537                       noun (common) (futsuumeishi)
# 47051                        noun (common) (futsuumeishi)
# 27654                        noun (common) (futsuumeishi)
# 127662                       noun (common) (futsuumeishi)
# 129715                       noun (common) (futsuumeishi)
# 165293                       noun (common) (futsuumeishi)
# 17973                        noun (common) (futsuumeishi)
# 26380   noun (common) (futsuumeishi); noun or particip...
# 163436                       noun (common) (futsuumeishi)
# 67441   nouns which may take the genitive case particl...
# 168959                       noun (common) (futsuumeishi)
# 120280                       noun (common) (futsuumeishi)
# 32644                        noun (common) (futsuumeishi)
# 120573                       noun (common) (futsuumeishi)
# 128381                       noun (common) (futsuumeishi)
# 83878   expressions (phrases, clauses, etc.); Ichidan ...
# 9044                         noun (common) (futsuumeishi)
# 64185   noun (common) (futsuumeishi); noun or particip...
# 13520                        noun (common) (futsuumeishi)
# 156055                       noun (common) (futsuumeishi)
# 161619  noun (common) (futsuumeishi); noun or particip...
# 155933                       noun (common) (futsuumeishi)
# 161843  noun (common) (futsuumeishi); nouns which may ...
# 163781                       noun (common) (futsuumeishi)
# 59562   noun (common) (futsuumeishi); noun or particip...
# 25193   adjectival nouns or quasi-adjectives (keiyodoshi)
# 103187                       noun (common) (futsuumeishi)
# 174104                       noun (common) (futsuumeishi)
# 159406                       noun (common) (futsuumeishi)
# 7810    noun (common) (futsuumeishi); noun or particip...
# 187582                                   adverb (fukushi)
# 48605   noun (common) (futsuumeishi); noun or particip...
# 57618                        noun (common) (futsuumeishi)
# 54101                        noun (common) (futsuumeishi)
# 33538                        noun (common) (futsuumeishi)
# 126291                       noun (common) (futsuumeishi)
# 114089                       noun (common) (futsuumeishi)
# 185267  expressions (phrases, clauses, etc.); Ichidan ...
# 123133                       noun (common) (futsuumeishi)
# 129856  noun (common) (futsuumeishi); nouns which may ...
# 4199                         noun (common) (futsuumeishi)
# 144021                       noun (common) (futsuumeishi)
# 55456   noun (common) (futsuumeishi); noun or particip...
# 39302                                              suffix
# 184449                       noun (common) (futsuumeishi)
# 47755                        noun (common) (futsuumeishi)
# 96206                        noun (common) (futsuumeishi)
# 76451                        noun (common) (futsuumeishi)
# 97483                        noun (common) (futsuumeishi)
# 3079                         noun (common) (futsuumeishi)
# 164858                       noun (common) (futsuumeishi)
# 32934   adjectival nouns or quasi-adjectives (keiyodoshi)
# 167900  adjectival nouns or quasi-adjectives (keiyodos...
# 17336                                    adverb (fukushi)
# 113658                       noun (common) (futsuumeishi)
# 18579                        noun (common) (futsuumeishi)
# 165945                       noun (common) (futsuumeishi)
# 109510                       noun (common) (futsuumeishi)
# 77496                        noun (common) (futsuumeishi)
# 22663   expressions (phrases, clauses, etc.); noun (co...
# 101674                                             suffix
# 123172                       noun (common) (futsuumeishi)
# 33458                        noun (common) (futsuumeishi)
# 24820                        noun (common) (futsuumeishi)
# 95311                expressions (phrases, clauses, etc.)
# 168627                       noun (common) (futsuumeishi)
# 76913                        noun (common) (futsuumeishi)
# 65457                        noun (common) (futsuumeishi)
# 59591                        noun (common) (futsuumeishi)
# 158700                       noun (common) (futsuumeishi)
# 40023                        noun (common) (futsuumeishi)
# 2696                         noun (common) (futsuumeishi)
# 79567   noun (common) (futsuumeishi); noun or particip...
# 448                                      adverb (fukushi)
# 101108                       noun (common) (futsuumeishi)
# 135612                       noun (common) (futsuumeishi)
# 68841                        noun (common) (futsuumeishi)
# 121957                       noun (common) (futsuumeishi)
# 188660                       noun (common) (futsuumeishi)
# 15863                        noun (common) (futsuumeishi)
# 66683                        noun (common) (futsuumeishi)
# 96072                expressions (phrases, clauses, etc.)
# 104254  expressions (phrases, clauses, etc.); Godan ve...
# 160048                       noun (common) (futsuumeishi)
# 5407                         noun (common) (futsuumeishi)
# 178356                       noun (common) (futsuumeishi)
# 49949                        noun (common) (futsuumeishi)
# 37413   noun (common) (futsuumeishi); noun or particip...
# 5960                         noun (common) (futsuumeishi)
# 62080                        noun (common) (futsuumeishi)
# 2440                         noun (common) (futsuumeishi)
# 56004                                    adverb (fukushi)
# 28473                        noun (common) (futsuumeishi)
# 15135                        noun (common) (futsuumeishi)
# 175228                       noun (common) (futsuumeishi)
# 41796                        noun (common) (futsuumeishi)
# 96186                        noun (common) (futsuumeishi)
# 145226                       noun (common) (futsuumeishi)
# 16915                        noun (common) (futsuumeishi)
# 137294                       noun (common) (futsuumeishi)
# 182914                       noun (common) (futsuumeishi)
# 157226                       noun (common) (futsuumeishi)
# 130881                       noun (common) (futsuumeishi)
# 10201                        noun (common) (futsuumeishi)
# 25319                        noun (common) (futsuumeishi)
# 29623   noun (common) (futsuumeishi); nouns which may ...
# 654                                 adjective (keiyoushi)
# 186836                       noun (common) (futsuumeishi)
# 154302                       noun (common) (futsuumeishi)
# 24389                        noun (common) (futsuumeishi)
# 79861        Godan verb with `ku' ending; transitive verb
# 126821                       noun (common) (futsuumeishi)
# 116077                       noun (common) (futsuumeishi)
# 186708                       noun (common) (futsuumeishi)
# 5977                         noun (common) (futsuumeishi)
# 167                          noun (common) (futsuumeishi)
# 115710                       noun (common) (futsuumeishi)
# 11382                        noun (common) (futsuumeishi)
# 28070                        noun (common) (futsuumeishi)
# 106711                       noun (common) (futsuumeishi)
# 183994                   noun or verb acting prenominally
# 95136   `taru' adjective; adverb taking the `to' particle
# 148142  expressions (phrases, clauses, etc.); Godan ve...
# 174896                       noun (common) (futsuumeishi)
# 77907                        noun (common) (futsuumeishi)
# 129301                       noun (common) (futsuumeishi)
# 143524                       noun (common) (futsuumeishi)
# 46282                        noun (common) (futsuumeishi)
# 90251   noun (common) (futsuumeishi); nouns which may ...
# 107872                       noun (common) (futsuumeishi)
# 102192                    Ichidan verb; intransitive verb
# 56886                        noun (common) (futsuumeishi)
# 79223                        noun (common) (futsuumeishi)
# 154210  noun (common) (futsuumeishi); nouns which may ...
# 158607                       noun (common) (futsuumeishi)
# 65157   noun (common) (futsuumeishi); noun or particip...
# 46155   nouns which may take the genitive case particl...
# 104811  noun (common) (futsuumeishi); nouns which may ...
# 99564                         Godan verb with `su' ending
# 159362  noun (common) (futsuumeishi); nouns which may ...
# 78799                        noun (common) (futsuumeishi)
# 152580                       noun (common) (futsuumeishi)
# 32202   nouns which may take the genitive case particl...
# 174006                       noun (common) (futsuumeishi)
# 115733  noun (common) (futsuumeishi); noun or particip...
# 7764                         noun (common) (futsuumeishi)
# 154044                       noun (common) (futsuumeishi)
# 20502   noun (common) (futsuumeishi); noun or particip...
# 32987                        noun (common) (futsuumeishi)
# 40327                        noun (common) (futsuumeishi)
# 88787                        noun (common) (futsuumeishi)
# 17404                                    adverb (fukushi)
# 183538                       noun (common) (futsuumeishi)
# 46798                        noun (common) (futsuumeishi)
# 81491   expressions (phrases, clauses, etc.); Godan ve...
# 119276                       noun (common) (futsuumeishi)
# 77053                        noun (common) (futsuumeishi)
# 170440                       noun (common) (futsuumeishi)
# 163109                       noun (common) (futsuumeishi)
# 60156                        noun (common) (futsuumeishi)
# 100994                           interjection (kandoushi)
# 23991                        noun (common) (futsuumeishi)
# 75840                        noun (common) (futsuumeishi)
# 141454  expressions (phrases, clauses, etc.); Ichidan ...
# 157636                       noun (common) (futsuumeishi)
# 166076                       noun (common) (futsuumeishi)
# 48687                        noun (common) (futsuumeishi)
# 29670                       adverb (fukushi); conjunction
# 82654   expressions (phrases, clauses, etc.); Godan ve...
# 181583                       noun (common) (futsuumeishi)
# 144308                       noun (common) (futsuumeishi)
# 18766        Godan verb with `su' ending; transitive verb
# 51525   noun (common) (futsuumeishi); noun or particip...
# 180080                       noun (common) (futsuumeishi)
# 108469                       noun (common) (futsuumeishi)
# 136274                       noun (common) (futsuumeishi)
# 111762  expressions (phrases, clauses, etc.); adverb (...
# 174640                       noun (common) (futsuumeishi)
# 115359                       noun (common) (futsuumeishi)
# 156459  noun (common) (futsuumeishi); noun or particip...
# 122318                       noun (common) (futsuumeishi)
# 73993                        noun (common) (futsuumeishi)
# 30929                        noun (common) (futsuumeishi)
# 62787   noun (common) (futsuumeishi); noun or particip...
#
#                                                   remarks
# 157124                                               None
# 106078                                               None
# 65552                                                None
# 125032                                               None
# 75127                                                None
# 102537                                               None
# 47051                                                None
# 27654                                                None
# 127662                                               None
# 129715                      slang, jocular, humorous term
# 165293                                      poetical term
# 17973                                                None
# 26380                                                None
# 163436                                               None
# 67441                                                None
# 168959                                               None
# 120280                                               None
# 32644                                                None
# 120573                                               None
# 128381                                               None
# 83878                                                None
# 9044                                                 None
# 64185                                                None
# 13520                                                None
# 156055                                               None
# 161619                                               None
# 155933                                               None
# 161843                                               None
# 163781                                               None
# 59562                                                None
# 25193                                                None
# 103187                                               None
# 174104                                               None
# 159406                                               None
# 7810                                                 None
# 187582                                               None
# 48605                                                None
# 57618                                                None
# 54101                                                None
# 33538                                                None
# 126291                                               None
# 114089                                               None
# 185267                                               None
# 123133                                               None
# 129856                                               None
# 4199                                                 None
# 144021  vulgar expression or word, slang, word usually...
# 55456                                                None
# 39302               word usually written using kana alone
# 184449                                               None
# 47755                                                None
# 96206                                          yojijukugo
# 76451                                                None
# 97483                                                None
# 3079                                                 None
# 164858              word usually written using kana alone
# 32934                                                None
# 167900                                      colloquialism
# 17336                                                None
# 113658                                               None
# 18579                                                None
# 165945                                               None
# 109510                                               None
# 77496                                                None
# 22663                                idiomatic expression
# 101674                                               None
# 123172                                               None
# 33458                                                None
# 24820                                                None
# 95311                                          yojijukugo
# 168627                                               None
# 76913                                                None
# 65457                                                None
# 59591               word usually written using kana alone
# 158700                                               None
# 40023                                                None
# 2696                                                 None
# 79567                                                None
# 448                 word usually written using kana alone
# 101108                                               None
# 135612              word usually written using kana alone
# 68841                                                None
# 121957                                               None
# 188660                                               None
# 15863                                                None
# 66683                                                None
# 96072                                          yojijukugo
# 104254                                               None
# 160048                                               None
# 5407                                                 None
# 178356                                               None
# 49949                                                None
# 37413                                                None
# 5960                                                 None
# 62080                                                None
# 2440                                                 None
# 56004               word usually written using kana alone
# 28473                                                None
# 15135                                                None
# 175228                                               None
# 41796                                                None
# 96186                                                None
# 145226                                               None
# 16915                                                None
# 137294              word usually written using kana alone
# 182914                                               None
# 157226                                               None
# 130881                                               None
# 10201                                                None
# 25319                                                None
# 29623                                                None
# 654                 word usually written using kana alone
# 186836                                           archaism
# 154302                                               None
# 24389                                                None
# 79861                                                None
# 126821                                               None
# 116077                                               None
# 186708                                               None
# 5977                                                 None
# 167                                                  None
# 115710                                               None
# 11382                                                None
# 28070                                                None
# 106711                                               None
# 183994                                               None
# 95136                                          yojijukugo
# 148142                                               None
# 174896                                           archaism
# 77907                                                None
# 129301                                               None
# 143524                                           archaism
# 46282                                                None
# 90251                                                None
# 107872              word usually written using kana alone
# 102192                                      colloquialism
# 56886                                                None
# 79223                                                None
# 154210                                               None
# 158607              word usually written using kana alone
# 65157                                                None
# 46155                                                None
# 104811                                               None
# 99564                                                None
# 159362                                               None
# 78799                                                None
# 152580                                               None
# 32202                                                None
# 174006                                               None
# 115733                                               None
# 7764                                                 None
# 154044                                               None
# 20502                                                None
# 32987                                                None
# 40327   word usually written using kana alone, abbrevi...
# 88787                                                None
# 17404                                                None
# 183538                                               None
# 46798                                                None
# 81491                                                None
# 119276                                               None
# 77053                                                None
# 170440                                               None
# 163109                                               None
# 60156                                                None
# 100994                                               None
# 23991                                                None
# 75840                                                None
# 141454                                               None
# 157636                                               None
# 166076                                               None
# 48687                                                None
# 29670                                                None
# 82654                                                None
# 181583                                               None
# 144308                                               None
# 18766                                                None
# 51525                                                None
# 180080                                               None
# 108469                             archaism, obscure term
# 136274                                               None
# 111762              word usually written using kana alone
# 174640                                               None
# 115359                                               None
# 156459                                               None
# 122318                                               None
# 73993                                                None
# 30929                                                None
# 62787                                                None

# %% [markdown]
# ### Word frequencies from Wikipedia (2015)

# %%
freqs = pd.read_csv('./data/wikipedia-20150422-lemmas.tsv', delimiter='\t',
                    header=None, names=['rank', 'frequency', 'main_spelling'])
freqs.head()
# Out:
#    rank  frequency main_spelling
# 0     1   34943515             の
# 1     2   19609102             に
# 2     3   17575121            する
# 3     4   16805949             は
# 4     5   16443314             を

# %% [markdown]
# ## Data checks on `df_wro`

# %% [markdown]
# ### Check for duplicates

# %%
df_wro[df_wro.duplicated(subset='kanji')]
# Out:
# Empty DataFrame
# Columns: [kanji, wr_old, strokes]
# Index: []

# %% [markdown]
# ### Detect missing numbers

# %%
for i in range(max(df_wro['wr_old'])+1):
    if i not in df_wro['wr_old'].values:
        print(i)
# Out:
# 0

# %% [markdown]
# ## Find kanji to study for the JLPT N1
# I will assume that one needs all the current jouyou kanji (2136) plus the jinmeyou kanji that were needed for the old level 1 (251).

# %%
sum(kanji['original_grade'].isin([1, 2, 3, 4, 5, 6, 8]))
# Out:
# 2136

# %%
sum(kanji['jlpt_level'].isin([1, 2, 3, 4]) & ~kanji['original_grade'].isin([1, 2, 3, 4, 5, 6, 8]))
# Out:
# 251

# %%
selection = (
    (kanji['original_grade'].isin([1, 2, 3, 4, 5, 6, 8])) |
    (
        (kanji['jlpt_level'].isin([1, 2, 3, 4]) &
         ~kanji['original_grade'].isin([1, 2, 3, 4, 5, 6, 8]))
    )
)

sum(selection)
# Out:
# 2387

# %%
kanji = kanji.loc[selection]

# %%
kanji['grade'].value_counts()
# Out:
# 常用ー漢検準２級    328
# 常用ー漢検４級     313
# 常用ー漢検３級     284
# 9.0(1.5)    206
# ４年生         202
# ３年生         200
# ５年生         193
# ６年生         191
# 常用ー漢検２級     185
# ２年生         160
# １年生          80
# 9.0(1.0)     40
# 9.0(nan)      5
# Name: grade, dtype: int64

# %% [markdown]
# ## Join the lists to obtain a cross-reference dataframe
# The following df can be used as a cross-reference between Japanese school grade and the old White Rabbit Press Kanji flashcards.

# %%
df = kanji.merge(df_jlpt, how='left', on='kanji')
df = df.merge(df_wro, how='left', on='kanji')

# %%
df['wr_old'] = df['wr_old'].fillna(0).astype(int)
df['strokes'] = df['strokes'].fillna(df['stroke_count']).astype(int)

# %% [markdown]
# ## Detect missing kanji in the WRP flashcards

# %%
sum(df['wr_old'] == 0)
# Out:
# 461

# %%
df.loc[df['wr_old'] == 0, 'grade'].value_counts()
# Out:
# 9.0(1.5)    206
# 常用ー漢検２級     185
# 9.0(1.0)     40
# ４年生          11
# 常用ー漢検準２級     10
# 9.0(nan)      5
# 常用ー漢検４級       3
# 常用ー漢検３級       1
# Name: grade, dtype: int64

# %% [markdown]
# <hr>

# %% [markdown]
# ## Find WRP flashcard by grade

# %%
# key = df.loc[(df['grade'] == '４年生')].sort_values('wr_old')
# filename = 'words_4nensei'

# key = df.loc[(df['grade'].isin(['常用ー漢検４級', '常用ー漢検３級', '常用ー漢検準２級']))].sort_values('wr_old')
# filename = 'words_8_123'

key = df.loc[(df['grade'] == '常用ー漢検２級')].sort_values('wr_old')
filename = 'words_8_4'

key
# Out:
#      kanji    grade  jlpt_level  stroke_count                         onyomi  \
# 4        挨  常用ー漢検２級           0            10                           [アイ]
# 1757     剥  常用ー漢検２級           0            10                     [ハク, [ホク]]
# 1770     箸  常用ー漢検２級           0            15                  [[チョ], [チャク]]
# 1790     斑  常用ー漢検２級           0            12                           [ハン]
# 1792     氾  常用ー漢検２級           0             5                           [ハン]
# 1793     汎  常用ー漢検２級           0             6    [ハン, [ブ], [フウ], [ホウ], [ホン]]
# 1836     眉  常用ー漢検２級           1             9                         [ビ, ミ]
# 1842     膝  常用ー漢検２級           0            15                         [[シツ]]
# 1843     肘  常用ー漢検２級           0             7                        [[チュウ]]
# 1932     蔽  常用ー漢検２級           0            15               [ヘイ, [ヘツ], [フツ]]
# 1940     蔑  常用ー漢検２級           0            14                           [ベツ]
# 1984     蜂  常用ー漢検２級           0            13                           [ホウ]
# 2011     貌  常用ー漢検２級           0            14                     [ボウ, [バク]]
# 2020     睦  常用ー漢検２級           1            13                     [ボク, [モク]]
# 2021     勃  常用ー漢検２級           0             9                     [ボツ, [ホツ]]
# 2035     昧  常用ー漢検２級           0             9                     [マイ, [バイ]]
# 2041     枕  常用ー漢検２級           0             8                   [[チン], [シン]]
# 2059     蜜  常用ー漢検２級           0            14                     [ミツ, [ビツ]]
# 2073     冥  常用ー漢検２級           0            10                      [メイ, ミョウ]
# 2085     麺  常用ー漢検２級           0            16                     [メン, [ベン]]
# 1735     罵  常用ー漢検２級           0            15                            [バ]
# 2098     餅  常用ー漢検２級           0            14                    [ヘイ, [ヒョウ]]
# 1717     捻  常用ー漢検２級           0            11                    [ネン, [ジョウ]]
# 1700     匂  常用ー漢検２級           0             4                           None
# 1447     綻  常用ー漢検２級           0            14                           [タン]
# 1491     酎  常用ー漢検２級           0            10                    [チュウ, [チュ]]
# 1523     捗  常用ー漢検２級           0            10                     [チョク, [ホ]]
# 1533     椎  常用ー漢検２級           1            12                     [ツイ, [スイ]]
# 1542     潰  常用ー漢検２級           0            15                      [カイ, [エ]]
# 1545     爪  常用ー漢検２級           0             4                         [[ソウ]]
# 1547     鶴  常用ー漢検２級           1            21                         [[カク]]
# 1570     諦  常用ー漢検２級           0            16                     [テイ, [タイ]]
# 1580     溺  常用ー漢検２級           0            13             [デキ, [ジョウ], [ニョウ]]
# 1591     貼  常用ー漢検２級           0            12                    [チョウ, [テン]]
# 1600     妬  常用ー漢検２級           0             8                       [ト, [ツ]]
# 1606     賭  常用ー漢検２級           0            15                            [ト]
# 1639     藤  常用ー漢検２級           1            18                     [トウ, [ドウ]]
# 1655     憧  常用ー漢検２級           1            15              [ショウ, [トウ], [ドウ]]
# 1657     瞳  常用ー漢検２級           1            17                     [ドウ, [トウ]]
# 1682     頓  常用ー漢検２級           0            13                     [トン, [トツ]]
# 1686     那  常用ー漢検２級           1             7                       [ナ, [ダ]]
# 1689     謎  常用ー漢検２級           0            16                   [[メイ], [ベイ]]
# 1691     鍋  常用ー漢検２級           0            17                          [[カ]]
# 1702     虹  常用ー漢検２級           1             9                         [[コウ]]
# 2105     冶  常用ー漢検２級           1             7                            [ヤ]
# 2109     弥  常用ー漢検２級           1             8                     [[ミ], [ビ]]
# 2135     湧  常用ー漢検２級           1            12                [ユウ, [ヨウ], [ユ]]
# 2331     慄  常用ー漢検２級           0            13                           [リツ]
# 2332     憬  常用ー漢検２級           0            15                           [ケイ]
# 2333     拉  常用ー漢検２級           0             8                [ラ, [ラツ], [ロウ]]
# 2334     摯  常用ー漢検２級           0            15                            [シ]
# 2340     曖  常用ー漢検２級           0            17                           [アイ]
# 2342     楷  常用ー漢検２級           0            13                           [カイ]
# 2344     鬱  常用ー漢検２級           0            29                           [ウツ]
# 2354     璧  常用ー漢検２級           0            18                           [ヘキ]
# 2355     瘍  常用ー漢検２級           0            14                           [ヨウ]
# 2359     箋  常用ー漢検２級           0            14                           [セン]
# 2360     籠  常用ー漢検２級           0            22                      [ロウ, [ル]]
# 2363     緻  常用ー漢検２級           0            16                            [チ]
# 2364     羞  常用ー漢検２級           0            11                          [シュウ]
# 2370     訃  常用ー漢検２級           0             9                            [フ]
# 2373     諧  常用ー漢検２級           0            16                           [カイ]
# 2374     貪  常用ー漢検２級           0            11               [ドン, [タン], [トン]]
# 2376     踪  常用ー漢検２級           0            15                    [ソウ, [ショウ]]
# 2377     辣  常用ー漢検２級           0            14                           [ラツ]
# 2379     錮  常用ー漢検２級           0            16                            [コ]
# 2330     惧  常用ー漢検２級           0            11                       [グ, [ク]]
# 2329     恣  常用ー漢検２級           0            10                            [シ]
# 2328     彙  常用ー漢検２級           0            13                            [イ]
# 2324     毀  常用ー漢検２級           0            13                            [キ]
# 2153     妖  常用ー漢検２級           0             7                           [ヨウ]
# 2178     沃  常用ー漢検２級           0             7               [ヨク, [ヨウ], [オク]]
# 2192     嵐  常用ー漢検２級           1            12                         [[ラン]]
# 2195     藍  常用ー漢検２級           1            18                           [ラン]
# 2204     璃  常用ー漢検２級           1            15                            [リ]
# 2221     侶  常用ー漢検２級           0             9                      [リョ, [ロ]]
# 2235     瞭  常用ー漢検２級           1            17                          [リョウ]
# 2254     瑠  常用ー漢検２級           1            14                     [ル, [リュウ]]
# 2286     呂  常用ー漢検２級           1             7                      [ロ, [リョ]]
# 1442     旦  常用ー漢検２級           1             5                       [タン, ダン]
# 2288     賂  常用ー漢検２級           0            13                            [ロ]
# 2301     麓  常用ー漢検２級           0            19                           [ロク]
# 2309     脇  常用ー漢検２級           0            10                        [[キョウ]]
# 2315     丼  常用ー漢検２級           0             5      [[トン], [タン], [ショウ], [セイ]]
# 2317     傲  常用ー漢検２級           0            13                           [ゴウ]
# 2318     刹  常用ー漢検２級           0             8                 [セツ, サツ, [セチ]]
# 2320     哺  常用ー漢検２級           0            10                            [ホ]
# 2321     喩  常用ー漢検２級           0            12                            [ユ]
# 2322     嗅  常用ー漢検２級           0            13                          [キュウ]
# 2323     嘲  常用ー漢検２級           0            15                    [チョウ, [トウ]]
# 2293     弄  常用ー漢検２級           0             7                      [ロウ, [ル]]
# 2385     塡  常用ー漢検２級           0            13                       [テン, チン]
# 1436     誰  常用ー漢検２級           0            15                         [[スイ]]
# 1390     堆  常用ー漢検２級           0            11                     [タイ, [ツイ]]
# 269      釜  常用ー漢検２級           0            10                          [[フ]]
# 270      鎌  常用ー漢検２級           1            18                   [[レン], [ケン]]
# 273      瓦  常用ー漢検２級           0             5                            [ガ]
# 319      韓  常用ー漢検２級           0            18                           [カン]
# 325      玩  常用ー漢検２級           0             8                           [ガン]
# 332      伎  常用ー漢検２級           1             6                       [キ, [ギ]]
# 356      畿  常用ー漢検２級           0            15                            [キ]
# 370      亀  常用ー漢検２級           1            11               [キ, [キュウ], [キン]]
# 465      僅  常用ー漢検２級           0            12                     [キン, [ゴン]]
# 468      巾  常用ー漢検２級           0             3                     [キン, [フク]]
# 469      錦  常用ー漢検２級           1            16                           [キン]
# 493      駒  常用ー漢検２級           1            15                          [[ク]]
# 501      串  常用ー漢検２級           0             7             [[カン], [ケン], [セン]]
# 504      窟  常用ー漢検２級           0            13                     [クツ, [コツ]]
# 538      稽  常用ー漢検２級           0            15                           [ケイ]
# 545      詣  常用ー漢検２級           0            13                     [ケイ, [ゲイ]]
# 555      隙  常用ー漢検２級           0            13              [ゲキ, [キャク], [ケキ]]
# 556      桁  常用ー漢検２級           0            10                         [[コウ]]
# 577      拳  常用ー漢検２級           1            10                     [ケン, [ゲン]]
# 262      葛  常用ー漢検２級           0            11                     [カツ, [カチ]]
# 591      鍵  常用ー漢検２級           0            17                           [ケン]
# 253      顎  常用ー漢検２級           0            18                           [ガク]
# 229      骸  常用ー漢検２級           0            16                     [ガイ, [カイ]]
# 14       宛  常用ー漢検２級           0             8                         [[エン]]
# 21       闇  常用ー漢検２級           0            17                   [[アン], [オン]]
# 36       椅  常用ー漢検２級           0            12                            [イ]
# 38       畏  常用ー漢検２級           0             9                            [イ]
# 44       萎  常用ー漢検２級           0            11                            [イ]
# 63       咽  常用ー漢検２級           0             9               [イン, [エン], [エツ]]
# 69       淫  常用ー漢検２級           0            11                           [イン]
# 81       臼  常用ー漢検２級           0             6                     [キュウ, [グ]]
# 83       唄  常用ー漢検２級           1            10                         [[バイ]]
# 87       餌  常用ー漢検２級           0            14                       [ジ, [ニ]]
# 112      怨  常用ー漢検２級           0             9                 [エン, オン, [ウン]]
# 120      艶  常用ー漢検２級           1            19                           [エン]
# 133      旺  常用ー漢検２級           1             8              [オウ, [キョウ], [ゴウ]]
# 145      臆  常用ー漢検２級           0            17                     [オク, [ヨク]]
# 147      俺  常用ー漢検２級           0            10                         [[エン]]
# 178      苛  常用ー漢検２級           0             8                            [カ]
# 189      牙  常用ー漢検２級           0             5                         [ガ, ゲ]
# 222      崖  常用ー漢検２級           0            11                 [ガイ, [ゲ], [ギ]]
# 226      蓋  常用ー漢検２級           0            13               [ガイ, [カイ], [コウ]]
# 232      柿  常用ー漢検２級           0             9                          [[シ]]
# 605      舷  常用ー漢検２級           0            11                           [ゲン]
# 620      股  常用ー漢検２級           0             8                            [コ]
# 622      虎  常用ー漢検２級           1             8                            [コ]
# 1201     凄  常用ー漢検２級           0            10                     [セイ, [サイ]]
# 1226     醒  常用ー漢検２級           0            16                           [セイ]
# 1234     戚  常用ー漢検２級           0            11                     [セキ, [ソク]]
# 1242     脊  常用ー漢検２級           0            10                           [セキ]
# 1274     煎  常用ー漢検２級           0            13                           [セン]
# 1278     羨  常用ー漢検２級           0            13                     [セン, [エン]]
# 1279     腺  常用ー漢検２級           0            13                           [セン]
# 1282     詮  常用ー漢検２級           0            13                           [セン]
# 1296     膳  常用ー漢検２級           0            16                     [ゼン, [セン]]
# 1299     曽  常用ー漢検２級           0            11                [ソウ, [ソ], [ゾウ]]
# 1300     狙  常用ー漢検２級           0             8                      [ソ, [ショ]]
# 1310     遡  常用ー漢検２級           0            13                      [ソ, [サク]]
# 1318     爽  常用ー漢検２級           1            11                           [ソウ]
# 1332     痩  常用ー漢検２級           0            12       [ソウ, [チュウ], [シュウ], [シュ]]
# 1361     捉  常用ー漢検２級           0            10                     [ソク, [サク]]
# 1372     袖  常用ー漢検２級           0            10                          [シュウ]
# 1378     遜  常用ー漢検２級           0            13                           [ソン]
# 1382     汰  常用ー漢検２級           1             7                      [タ, [タイ]]
# 1383     唾  常用ー漢検２級           0            11                       [ダ, [タ]]
# 1194     裾  常用ー漢検２級           0            13                    [[キョ], [コ]]
# 1168     須  常用ー漢検２級           1            12                      [ス, [シュ]]
# 1165     腎  常用ー漢検２級           0            13                           [ジン]
# 1150     芯  常用ー漢検２級           0             7                           [シン]
# 643      乞  常用ー漢検２級           0             3  [[コツ], [キツ], [キ], [キケ], [コチ]]
# 653      勾  常用ー漢検２級           0             4                      [コウ, [ク]]
# 658      喉  常用ー漢検２級           0            12                           [コウ]
# 680      梗  常用ー漢検２級           0            11                    [コウ, [キョウ]]
# 730      頃  常用ー漢検２級           0            11                  [[ケイ], [キョウ]]
# 740      痕  常用ー漢検２級           0            11                           [コン]
# 749      沙  常用ー漢検２級           1             7                      [サ, [シャ]]
# 756      挫  常用ー漢検２級           0            10                       [ザ, [サ]]
# 762      塞  常用ー漢検２級           0            13                       [ソク, サイ]
# 1397     戴  常用ー漢検２級           0            17                           [タイ]
# 772      采  常用ー漢検２級           1             8                           [サイ]
# 806      拶  常用ー漢検２級           0             9                           [サツ]
# 827      斬  常用ー漢検２級           0            11         [ザン, [サン], [セン], [ゼン]]
# 900      叱  常用ー漢検２級           0             5                     [シツ, [シチ]]
# 903      嫉  常用ー漢検２級           0            13                           [シツ]
# 945      腫  常用ー漢検２級           0            13                    [シュ, [ショウ]]
# 951      呪  常用ー漢検２級           0             8         [ジュ, [シュ], [シュウ], [ズ]]
# 974      蹴  常用ー漢検２級           0            19                   [シュウ, [シュク]]
# 1118     拭  常用ー漢検２級           0             9                    [ショク, [シキ]]
# 1127     尻  常用ー漢検２級           0             5                         [[コウ]]
# 797      柵  常用ー漢検２級           0             9                     [サク, [サン]]
# 2386     頰  常用ー漢検２級           0            16                          [キョウ]
#
#                                                 kunyomi  \
# 4                                              [[ひら.く]]
# 1757  [は.がれる, は.ぐ, は.げる, は.がす, [へ.ぐ], [へず.る], [む.く],...
# 1770                                               [はし]
# 1790                                       [[ふ], [まだら]]
# 1792                                          [[ひろ.がる]]
# 1793                                  [[ただよ.う], [ひろ.い]]
# 1836                                               [まゆ]
# 1842                                               [ひざ]
# 1843                                               [ひじ]
# 1932                                   [[おお.う], [おお.い]]
# 1940                   [さげす.む, [ないがしろ], [なみ.する], [くらい]]
# 1984                                               [はち]
# 2011                                    [[かたち], [かたどる]]
# 2020                         [[むつ.まじい], [むつ.む], [むつ.ぶ]]
# 2021                                   [[おこ.る], [にわかに]]
# 2035                                  [[くら.い], [むさぼ.る]]
# 2041                                              [まくら]
# 2059                                               None
# 2073                                           [[くら.い]]
# 2085                                            [[むぎこ]]
# 1735                                            [ののし.る]
# 2098                                        [もち, [もちい]]
# 1717                  [[ね.じる], [ねじ.る], [ひね.くる], [ひね.る]]
# 1700                           [にお.う, [にお.い], [にお.わせる]]
# 1447                                           [ほころ.びる]
# 1491                                           [[かも.す]]
# 1523                                          [[はかど.る]]
# 1533                                      [[つち], [う.つ]]
# 1542                             [つぶ.す, つぶ.れる, [つい.える]]
# 1545                                        [つめ, [つま-]]
# 1547                                               [つる]
# 1570                           [あきら.める, [つまびらか], [まこと]]
# 1580                                     [おぼ.れる, [いばり]]
# 1591                                       [は.る, [つ.く]]
# 1600                     [ねた.む, [そね.む], [つも.る], [ふさ.ぐ]]
# 1606                                       [か.ける, [かけ]]
# 1639                                               [ふじ]
# 1655                                           [あこが.れる]
# 1657                                              [ひとみ]
# 1682         [[にわか.に], [とん.と], [つまず.く], [とみ.に], [ぬかずく]]
# 1686                               [[なに], [なんぞ], [いかん]]
# 1689                                               [なぞ]
# 1691                                               [なべ]
# 1702                                               [にじ]
# 2105                                            [[い.る]]
# 2109                         [や, [いや], [いよ.いよ], [わた.る]]
# 2135                                              [わ.く]
# 2331                        [[ふる.える], [おそ.れる], [おのの.く]]
# 2332                                         [[あこが.れる]]
# 2333                          [[らっ.する], [ひし.ぐ], [くだ.く]]
# 2334                                           [[いた.る]]
# 2340                                           [[くら.い]]
# 2342                                               None
# 2344                          [[うっ.する], [ふさ.ぐ], [しげ.る]]
# 2354                                             [[たま]]
# 2355                                             [[かさ]]
# 2359                                             [[ふだ]]
# 2360                        [かご, [こ.める], [こも.る], [こ.む]]
# 2363                                          [[こまか.い]]
# 2364                        [[はじ.る], [すすめ.る], [は.ずかしい]]
# 2370                                            [[しらせ]]
# 2373                                  [[かな.う], [やわ.らぐ]]
# 2374                                            [むさぼ.る]
# 2376                                             [[あと]]
# 2377                                           [[から.い]]
# 2379                                           [[ふさ.ぐ]]
# 2330                                          [[おそ.れる]]
# 2329                                          [[ほしいまま]]
# 2328                                          [[はりねずみ]]
# 2324  [[こぼ.つ], [こわ.す], [こぼ.れる], [こわ.れる], [そし.る], [やぶ...
# 2153                          [あや.しい, [なま.めく], [わざわ.い]]
# 2178                                           [[そそ.ぐ]]
# 2192                                              [あらし]
# 2195                                               [あい]
# 2204                                               None
# 2221                                             [[とも]]
# 2235                                           [[あきらか]]
# 2254                                               None
# 2286                                            [[せぼね]]
# 1442               [[あき.らか], [あきら], [ただし], [あさ], [あした]]
# 2288                                 [[まいな.い], [まいな.う]]
# 2301                                              [ふもと]
# 2309                                         [わき, [わけ]]
# 2315                                             [どんぶり]
# 2317                                  [[おご.る], [あなど.る]]
# 2318                                               None
# 2320                                  [[はぐく.む], [ふく.む]]
# 2321                                  [[たと.える], [さと.す]]
# 2322                                              [か.ぐ]
# 2323                                            [あざけ.る]
# 2293  [もてあそ.ぶ, [いじく.る], [ろう.する], [いじ.る], [ひねく.る], [た...
# 2385                          [はま.る, うず.める, は.める, ふさ.ぐ]
# 1436                                    [だれ, [たれ], [た]]
# 1390                                         [[うずたか.い]]
# 269                                                [かま]
# 270                                                [かま]
# 273                                        [かわら, [ぐらむ]]
# 319                                       [[から], [いげた]]
# 325                                [[もちあそ.ぶ], [もてあそ.ぶ]]
# 332                                      [[わざ], [わざおぎ]]
# 356                                             [[みやこ]]
# 370                                                [かめ]
# 465                                              [わず.か]
# 468                               [[おお.い], [ちきり], [きれ]]
# 469                                               [にしき]
# 493                                                [こま]
# 501                                       [くし, [つらぬ.く]]
# 504                                [[いわや], [いはや], [あな]]
# 538                                 [[かんが.える], [とど.める]]
# 545                    [もう.でる, [けい.する], [まい.る], [いた.る]]
# 555                           [すき, [す.く], [す.かす], [ひま]]
# 556                                                [けた]
# 577                                               [こぶし]
# 262                                         [くず, [つづら]]
# 591                                                [かぎ]
# 253                                         [あご, [あぎと]]
# 229                                             [[むくろ]]
# 14                        [あ.てる, [-あて], [-づつ], [あたか.も]]
# 21                                         [やみ, [くら.い]]
# 36                                                 None
# 38                    [おそ.れる, [かしこま.る], [かしこ], [かしこ.し]]
# 44                [な.える, [な], [しお.れる], [しな.びる], [しぼ.む]]
# 63                        [[むせ.ぶ], [むせ.る], [のど], [の.む]]
# 69              [みだ.ら, [ひた.す], [ほしいまま], [みだ.れる], [みだり]]
# 81                                        [うす, [うすづ.く]]
# 83                                         [うた, [うた.う]]
# 87                                  [え, えさ, [えば], [もち]]
# 112                           [[うら.む], [うらみ], [うら.めしい]]
# 120          [つや, [なま.めかしい], [あで.やか], [つや.めく], [なま.めく]]
# 133                          [[かがや.き], [うつくし.い], [さかん]]
# 145                                      [[むね], [おくする]]
# 147                                          [おれ, [われ]]
# 178          [[いじ.める], [さいな.む], [いらだ.つ], [からい], [こまかい]]
# 189                                           [きば, [は]]
# 222                                    [がけ, [きし], [はて]]
# 226                   [ふた, [けだ.し], [おお.う], [かさ], [かこう]]
# 232                                                [かき]
# 605                                    [[ふなばた], [ふなべり]]
# 620                                          [また, [もも]]
# 622                                                [とら]
# 1201                         [[さむ.い], [すご.い], [すさ.まじい]]
# 1226                                   [[さ.ます], [さ.める]]
# 1234                           [[いた.む], [うれ.える], [みうち]]
# 1242                                        [[せ], [せい]]
# 1274                              [い.る, [せん.じる], [に.る]]
# 1278                                     [うらや.む, [あまり]]
# 1279                                               None
# 1282                           [[せん.ずる], [かい], [あき.らか]]
# 1296                          [[かしわ], [すす.める], [そな.える]]
# 1299                              [[かつ], [かつて], [すなわち]]
# 1300                                     [ねら.う, [ねら.い]]
# 1310                                           [さかのぼ.る]
# 1318                            [さわ.やか, [あき.らか], [たがう]]
# 1332                                             [や.せる]
# 1361                                            [とら.える]
# 1372                                               [そで]
# 1378                        [[したが.う], [へりくだ.る], [ゆず.る]]
# 1382                          [[おご.る], [にご.る], [よな.げる]]
# 1383                                        [つば, [つばき]]
# 1194                                               [すそ]
# 1168    [[すべから.く], [すべし], [ひげ], [まつ], [もち.いる], [もと.める]]
# 1165                                               None
# 1150                                               None
# 643                                               [こ.う]
# 653                                      [[かぎ], [ま.がる]]
# 658                                                [のど]
# 680                             [[ふさぐ], [やまにれ], [おおむね]]
# 730                                 [ころ, [ごろ], [しばら.く]]
# 740                                                [あと]
# 749                                      [[すな], [よなげる]]
# 756                                   [[くじ.く], [くじ.ける]]
# 762                               [ふさ.ぐ, [とりで], [み.ちる]]
# 1397                                          [[いただ.く]]
# 772                                     [[と.る], [いろどり]]
# 806                                            [[せま.る]]
# 827                                               [き.る]
# 900                                              [しか.る]
# 903                            [[そね.む], [ねた.む], [にく.む]]
# 945                         [は.れる, は.らす, [は.れ], [はれもの]]
# 951                    [のろ.う, [まじな.う], [のろ.い], [まじな.い]]
# 974                                               [け.る]
# 1118                                        [ぬぐ.う, ふ.く]
# 1127                                               [しり]
# 797                     [[しがら.む], [しがらみ], [とりで], [やらい]]
# 2386                                           [ほお, ほほ]
#
#                        nanori      core_meaning_1     core_meaning_2  \
# 4                        None                push               None
# 1757                     None            peel off               None
# 1770                     None          chopsticks               None
# 1790                      [い]                spot               None
# 1792                     None        spread about               None
# 1793            [ひろ, ひろし, みな]             overall               None
# 1836                     None             eyebrow               None
# 1842                     None                knee               None
# 1843                     None               elbow               None
# 1932                     None               cover               None
# 1940                     None             despise               None
# 1984                      [ほ]                 bee               None
# 2011                     None          appearance               None
# 2020  [むつ, ちか, よし, あつ, む, むね]            friendly               None
# 2021                     None            suddenly               None
# 2035                     None                dark               None
# 2041                     None              pillow               None
# 2059                     None               honey               None
# 2073                     None                dark  world of the dead
# 2085                     None             noodles               None
# 1735                     None               abuse               None
# 2098                     None           rice cake               None
# 1717                     None               twist               None
# 1700             [おり, こう, さぎ]               smell               None
# 1447                     None             unravel               None
# 1491                     None              shochu               None
# 1523                     None       make progress               None
# 1533                     [しい]               spine         chinquapin
# 1542                     None               crush               None
# 1545                     None                nail               None
# 1547         [たず, ず, か, つ, づ]               crane               None
# 1570                     None             give up               None
# 1580                     None               drown               None
# 1591                     None               stick               None
# 1600                     None          be jealous               None
# 1606                     None               wager               None
# 1639             [ぞう, と, ふじゅ]            wisteria               None
# 1655                     None         yearn after               None
# 1657                    [あきら]               pupil               None
# 1682                     None              sudden      stay in place
# 1686                 [とも, やす]       phonetic [na]               None
# 1689                     None              riddle               None
# 1691                     None                 pot               None
# 1702                     None             rainbow               None
# 2105                      [じ]         work metals               None
# 2109         [わたる, みつ, ひろ, よ]       phonetic [mi]               None
# 2135                 [わき, わく]             well up               None
# 2331                     None   tremble with fear               None
# 2332                     None         yearn after               None
# 2333                     None              abduct               None
# 2334                     None             serious               None
# 2340                     None               shady               None
# 2342                     None        square style               None
# 2344                     None               gloom               None
# 2354                     None   disk-shaped jewel               None
# 2355                     None            swelling               None
# 2359                     None      piece of paper               None
# 2360                 [ごめ, もり]              basket               None
# 2363                     None              minute               None
# 2364                     None                 shy               None
# 2370                     None       news of death               None
# 2373                     None          harmonious               None
# 2374                     None               covet               None
# 2376                     None          footprints               None
# 2377                     None             pungent             severe
# 2379                     None            imprison               None
# 2330                     None                fear               None
# 2329                     None      self-indulgent               None
# 2328                     None          assemblage               None
# 2324                     None             destroy               None
# 2153                     None          mysterious               None
# 2178                     None             fertile               None
# 2192                     [ぞれ]               storm               None
# 2195                     None              indigo               None
# 2204                     [あき]    glassy substance               None
# 2221                     None           companion               None
# 2235                     None               clear               None
# 2254                     [るり]        lapis lazuli               None
# 2286                 [とも, なが]       phonetic [ro]               None
# 1442                     None            daybreak               None
# 2288                     None               bribe               None
# 2301                     None  foot of a mountain               None
# 2309                     None                side             armpit
# 2315                     None          large bowl               None
# 2317                     None            arrogant               None
# 2318                     None     Buddhist temple               None
# 2320                     None               nurse               None
# 2321                     None            metaphor               None
# 2322                     None               smell               None
# 2323                     None            scoff at               None
# 2293                     None            toy with               None
# 2385                     None                fill               None
# 1436                     None                 who               None
# 1390                     None          piled high               None
# 269                      None            iron pot               None
# 270                  [かた, かね]              sickle               None
# 273                      None                tile               None
# 319                      None         South Korea               None
# 325                      None    take pleasure in               None
# 332                      None           performer               None
# 356                      None             capital               None
# 370                 [ひさ, ひさし]              turtle               None
# 465                      None            a little               None
# 468                      None               cloth               None
# 469              [かね, あや, にし]             brocade               None
# 493                      None               horse           chessman
# 501                      None              skewer               None
# 504                      None                cave               None
# 538                      None               think               None
# 545                      None  visit a holy place               None
# 555                      None                 gap               None
# 556                      None                beam              digit
# 577                      None                fist               None
# 262     [か, かず, かずら, かっ, かつら]               kudzu               None
# 591                      None                 key               None
# 253                      None                 jaw               None
# 229                      None           dead body               None
# 14                       None             address               None
# 21                       None                dark               None
# 36                       None               chair               None
# 38                       None         be overawed               None
# 44                       None              wither               None
# 63                       None              throat               None
# 69                       None                lewd               None
# 81                       None              mortar               None
# 83                       None               ditty               None
# 87                       None         animal feed               None
# 112                      None       hold a grudge               None
# 120                  [もろ, よし]            charming            romance
# 133                      None           energetic               None
# 145                      None          feel timid               None
# 147                      None                   I               None
# 178                      None               harsh               None
# 189                      None                fang               None
# 222                      None               cliff               None
# 226                      None               cover               None
# 232                      None           persimmon               None
# 605                      None             gunwale               None
# 620                      None              crotch               None
# 622                      [たけ]               tiger               None
# 1201                     None             uncanny               None
# 1226                     None               awake               None
# 1234                     None           relatives               None
# 1242                     None               spine               None
# 1274                     [いり]               roast             decoct
# 1278                     None          be envious               None
# 1279                     None               gland               None
# 1282                     [あき]             expound               None
# 1296                  [ぜ, よし]         legged tray               meal
# 1299                     None               great               None
# 1300                     None                 aim               None
# 1310                     None         go upstream               None
# 1318                     None          refreshing               None
# 1332                     None            get thin               None
# 1361                     None               grasp               None
# 1372                     None              sleeve               None
# 1378                     None              humble               None
# 1382                     None            sift out               None
# 1383                     None              saliva               None
# 1194                     None                 hem               None
# 1168                 [もとむ, ぞ]                must               None
# 1165                     None              kidney               None
# 1150                     None                core               None
# 643                      None                 beg               None
# 653                     [まがり]              arrest               None
# 658                      None              throat               None
# 680                      None             stop up               None
# 730                     [ころも]                time              about
# 740                      None                scar               None
# 749                      None                sand               None
# 756                      None              sprain               None
# 762                      None             stop up               fort
# 1397                     None      receive humbly               None
# 772                      None              gather               None
# 806                      None               press               None
# 827                      None    cut with a sword               None
# 900                      None               scold               None
# 903                      None          be jealous               None
# 945                      None            swelling               None
# 951                      None               spell               None
# 974                      None                kick               None
# 1118                     None                wipe               None
# 1127                     [がみ]            buttocks               None
# 797                  [ませ, やな]               fence               None
# 2386                     None               cheek               None
#
#      core_meaning_3  original_grade new_jlpt_level  wr_old  strokes
# 4              None               8            NaN       0       10
# 1757           None               8            NaN       0       10
# 1770           None               8            NaN       0       15
# 1790           None               8            NaN       0       12
# 1792           None               8            NaN       0        5
# 1793           None               8            NaN       0        6
# 1836           None               8             N1       0        9
# 1842           None               8            NaN       0       15
# 1843           None               8            NaN       0        7
# 1932           None               8            NaN       0       15
# 1940           None               8            NaN       0       14
# 1984           None               8            NaN       0       13
# 2011           None               8            NaN       0       14
# 2020           None               8             N1       0       13
# 2021           None               8            NaN       0        9
# 2035           None               8            NaN       0        9
# 2041           None               8            NaN       0        8
# 2059           None               8            NaN       0       14
# 2073           None               8            NaN       0       10
# 2085           None               8            NaN       0       16
# 1735           None               8            NaN       0       15
# 2098           None               8            NaN       0       14
# 1717           None               8            NaN       0       11
# 1700           None               8            NaN       0        4
# 1447           None               8            NaN       0       14
# 1491           None               8            NaN       0       10
# 1523           None               8            NaN       0       10
# 1533           None               8             N1       0       12
# 1542           None               8            NaN       0       15
# 1545           None               8            NaN       0        4
# 1547           None               8             N1       0       21
# 1570           None               8            NaN       0       16
# 1580           None               8            NaN       0       13
# 1591           None               8            NaN       0       12
# 1600           None               8            NaN       0        8
# 1606           None               8            NaN       0       15
# 1639           None               8             N1       0       18
# 1655           None               8             N1       0       15
# 1657           None               8             N1       0       17
# 1682           None               8            NaN       0       13
# 1686           None               8             N1       0        7
# 1689           None               8            NaN       0       16
# 1691           None               8            NaN       0       17
# 1702           None               8             N1       0        9
# 2105           None               8             N1       0        7
# 2109           None               8             N1       0        8
# 2135           None               8             N1       0       12
# 2331           None               8            NaN       0       13
# 2332           None               8            NaN       0       15
# 2333           None               8            NaN       0        8
# 2334           None               8            NaN       0       15
# 2340           None               8            NaN       0       17
# 2342           None               8            NaN       0       13
# 2344           None               8            NaN       0       29
# 2354           None               8            NaN       0       18
# 2355           None               8            NaN       0       14
# 2359           None               8            NaN       0       14
# 2360           None               8            NaN       0       22
# 2363           None               8            NaN       0       16
# 2364           None               8            NaN       0       11
# 2370           None               8            NaN       0        9
# 2373           None               8            NaN       0       16
# 2374           None               8            NaN       0       11
# 2376           None               8            NaN       0       15
# 2377           None               8            NaN       0       14
# 2379           None               8            NaN       0       16
# 2330           None               8            NaN       0       11
# 2329           None               8            NaN       0       10
# 2328           None               8            NaN       0       13
# 2324           None               8            NaN       0       13
# 2153           None               8            NaN       0        7
# 2178           None               8            NaN       0        7
# 2192           None               8             N1       0       12
# 2195           None               8             N1       0       18
# 2204           None               8             N1       0       15
# 2221           None               8            NaN       0        9
# 2235           None               8             N1       0       17
# 2254           None               8             N1       0       14
# 2286           None               8             N1       0        7
# 1442           None               8             N1       0        5
# 2288           None               8            NaN       0       13
# 2301           None               8            NaN       0       19
# 2309           None               8            NaN       0       10
# 2315           None               8            NaN       0        5
# 2317           None               8            NaN       0       13
# 2318           None               8            NaN       0        8
# 2320           None               8            NaN       0       10
# 2321           None               8            NaN       0       12
# 2322           None               8            NaN       0       13
# 2323           None               8            NaN       0       15
# 2293           None               8            NaN       0        7
# 2385           None               8            NaN       0       13
# 1436           None               8            NaN       0       15
# 1390           None               8            NaN       0       11
# 269            None               8            NaN       0       10
# 270            None               8             N1       0       18
# 273            None               8            NaN       0        5
# 319            None               8            NaN       0       18
# 325            None               8            NaN       0        8
# 332            None               8             N1       0        6
# 356            None               8            NaN       0       15
# 370            None               8             N1       0       11
# 465            None               8            NaN       0       12
# 468            None               8            NaN       0        3
# 469            None               8             N1       0       16
# 493            None               8             N1       0       15
# 501            None               8            NaN       0        7
# 504            None               8            NaN       0       13
# 538            None               8            NaN       0       15
# 545            None               8            NaN       0       13
# 555            None               8            NaN       0       13
# 556            None               8            NaN       0       10
# 577            None               8             N1       0       10
# 262            None               8            NaN       0       11
# 591            None               8            NaN       0       17
# 253            None               8            NaN       0       18
# 229            None               8            NaN       0       16
# 14             None               8            NaN       0        8
# 21             None               8            NaN       0       17
# 36             None               8            NaN       0       12
# 38             None               8            NaN       0        9
# 44             None               8            NaN       0       11
# 63             None               8            NaN       0        9
# 69             None               8            NaN       0       11
# 81             None               8            NaN       0        6
# 83             None               8             N1       0       10
# 87             None               8            NaN       0       14
# 112            None               8            NaN       0        9
# 120            None               8             N1       0       19
# 133            None               8             N1       0        8
# 145            None               8            NaN       0       17
# 147            None               8            NaN       0       10
# 178            None               8            NaN       0        8
# 189            None               8            NaN       0        5
# 222            None               8            NaN       0       11
# 226            None               8            NaN       0       13
# 232            None               8            NaN       0        9
# 605            None               8            NaN       0       11
# 620            None               8            NaN       0        8
# 622            None               8             N1       0        8
# 1201           None               8            NaN       0       10
# 1226           None               8            NaN       0       16
# 1234           None               8            NaN       0       11
# 1242           None               8            NaN       0       10
# 1274           None               8            NaN       0       13
# 1278           None               8            NaN       0       13
# 1279           None               8            NaN       0       13
# 1282           None               8            NaN       0       13
# 1296           None               8            NaN       0       16
# 1299           None               8            NaN       0       11
# 1300           None               8             N1       0        8
# 1310           None               8            NaN       0       13
# 1318           None               8             N1       0       11
# 1332           None               8            NaN       0       12
# 1361           None               8            NaN       0       10
# 1372           None               8            NaN       0       10
# 1378           None               8            NaN       0       13
# 1382           None               8             N1       0        7
# 1383           None               8            NaN       0       11
# 1194           None               8            NaN       0       13
# 1168           None               8             N1       0       12
# 1165           None               8            NaN       0       13
# 1150           None               8            NaN       0        7
# 643            None               8            NaN       0        3
# 653            None               8            NaN       0        4
# 658            None               8            NaN       0       12
# 680            None               8            NaN       0       11
# 730            None               8            NaN       0       11
# 740            None               8            NaN       0       11
# 749            None               8             N1       0        7
# 756            None               8            NaN       0       10
# 762            None               8            NaN       0       13
# 1397           None               8            NaN       0       17
# 772            None               8             N1       0        8
# 806            None               8            NaN       0        9
# 827            None               8            NaN       0       11
# 900            None               8            NaN       0        5
# 903            None               8            NaN       0       13
# 945            None               8            NaN       0       13
# 951            None               8            NaN       0        8
# 974            None               8            NaN       0       19
# 1118           None               8            NaN       0        9
# 1127           None               8            NaN       0        5
# 797            None               8            NaN       0        9
# 2386           None               8            NaN       0       16

# %%
len(key)
# Out:
# 185

# %% [markdown]
# ## Produce data file for missing cards to supplement

# %% [markdown]
# ### Initial set to supplement

# %%
supplement = key.loc[key['wr_old'] == 0].copy()

# %%
list(supplement['kanji'])
# Out:
# ['挨',
#  '剥',
#  '箸',
#  '斑',
#  '氾',
#  '汎',
#  '眉',
#  '膝',
#  '肘',
#  '蔽',
#  '蔑',
#  '蜂',
#  '貌',
#  '睦',
#  '勃',
#  '昧',
#  '枕',
#  '蜜',
#  '冥',
#  '麺',
#  '罵',
#  '餅',
#  '捻',
#  '匂',
#  '綻',
#  '酎',
#  '捗',
#  '椎',
#  '潰',
#  '爪',
#  '鶴',
#  '諦',
#  '溺',
#  '貼',
#  '妬',
#  '賭',
#  '藤',
#  '憧',
#  '瞳',
#  '頓',
#  '那',
#  '謎',
#  '鍋',
#  '虹',
#  '冶',
#  '弥',
#  '湧',
#  '慄',
#  '憬',
#  '拉',
#  '摯',
#  '曖',
#  '楷',
#  '鬱',
#  '璧',
#  '瘍',
#  '箋',
#  '籠',
#  '緻',
#  '羞',
#  '訃',
#  '諧',
#  '貪',
#  '踪',
#  '辣',
#  '錮',
#  '惧',
#  '恣',
#  '彙',
#  '毀',
#  '妖',
#  '沃',
#  '嵐',
#  '藍',
#  '璃',
#  '侶',
#  '瞭',
#  '瑠',
#  '呂',
#  '旦',
#  '賂',
#  '麓',
#  '脇',
#  '丼',
#  '傲',
#  '刹',
#  '哺',
#  '喩',
#  '嗅',
#  '嘲',
#  '弄',
#  '塡',
#  '誰',
#  '堆',
#  '釜',
#  '鎌',
#  '瓦',
#  '韓',
#  '玩',
#  '伎',
#  '畿',
#  '亀',
#  '僅',
#  '巾',
#  '錦',
#  '駒',
#  '串',
#  '窟',
#  '稽',
#  '詣',
#  '隙',
#  '桁',
#  '拳',
#  '葛',
#  '鍵',
#  '顎',
#  '骸',
#  '宛',
#  '闇',
#  '椅',
#  '畏',
#  '萎',
#  '咽',
#  '淫',
#  '臼',
#  '唄',
#  '餌',
#  '怨',
#  '艶',
#  '旺',
#  '臆',
#  '俺',
#  '苛',
#  '牙',
#  '崖',
#  '蓋',
#  '柿',
#  '舷',
#  '股',
#  '虎',
#  '凄',
#  '醒',
#  '戚',
#  '脊',
#  '煎',
#  '羨',
#  '腺',
#  '詮',
#  '膳',
#  '曽',
#  '狙',
#  '遡',
#  '爽',
#  '痩',
#  '捉',
#  '袖',
#  '遜',
#  '汰',
#  '唾',
#  '裾',
#  '須',
#  '腎',
#  '芯',
#  '乞',
#  '勾',
#  '喉',
#  '梗',
#  '頃',
#  '痕',
#  '沙',
#  '挫',
#  '塞',
#  '戴',
#  '采',
#  '拶',
#  '斬',
#  '叱',
#  '嫉',
#  '腫',
#  '呪',
#  '蹴',
#  '拭',
#  '尻',
#  '柵',
#  '頰']

# %%
# supplement[['kanji', 'grade']].sort_values('grade')

# %% [markdown]
# ### Process the readings
# This ensures that they look nice, i.e. "approved, [unapproved]".

# %%
def expand_readings(x):
    if x is None:
        return None
    
    if len(x):
        jouyou = []
        non_jouyou = []
        
        for reading in x:
            if '[' in reading:
                non_jouyou.append(reading[1:-1])
            else:
                jouyou.append(reading)

        if len(jouyou) and len(non_jouyou):
            return f"{', '.join(jouyou)}, [{', '.join(non_jouyou)}]"
        elif len(jouyou):
            return ', '.join(jouyou)
        else:
            return f"[{', '.join(non_jouyou)}]"
        
    return None

supplement['onyomi'] = supplement['onyomi'].apply(expand_readings)
supplement['kunyomi'] = supplement['kunyomi'].apply(expand_readings)
supplement['nanori'] = supplement['nanori'].apply(expand_readings)

# %% [markdown]
# ### Merge the core meanings into one string

# %%
supplement['core_meanings'] = supplement.apply(
    lambda row: ', '.join(filter(None, [row[f'core_meaning_{i}'] for i in [1, 2, 3]])), axis=1)

supplement = supplement.drop([f'core_meaning_{i}' for i in [1, 2, 3]], axis=1)

# %% [markdown]
# ### Add some example compounds

# %% [markdown]
# Get the most frequent words from JMdict.

# %%
df = jmdict.merge(freqs, on='main_spelling', how='left')
df = df.loc[df['main_spelling'].str.len() > 1].sort_values('rank').copy()

# %% [markdown]
# Find the kanji for each word.

# %%
kanji_block = r'[㐀-䶵一-鿋豈-頻]'
df['kanji'] = df['main_spelling'].apply(lambda x: re.findall(kanji_block, x))

df = df.explode('kanji', ignore_index=True)

# %% [markdown]
# Merge the kanji in the supplement to the words. This produces a list of candidate words to be used as example compounds. Some manual editing is needed here, because identifying the compounds to actually use just by frequency doesn't work. The list of candidate words is saved as `csv`. To use a given word, add an integer from 1 to 6 in the column `use_position`. Any necessary edits to the meaning and the reading should also be made here. When complete, save the file to a new csv, replacing `candidates` with `final` in the file name.

# %%
words = supplement.merge(df, on='kanji', how='left')
words['use_position'] = None
words.to_csv(f'./data/wr_old_supplements/{filename}_candidates.csv', index=False)

# %% [markdown]
# Load back the manually edited words, pivot them, and merge them to the supplement.

# %%
words_final = pd.read_csv(f'./data/wr_old_supplements/{filename}_final.csv')

words_final = words_final.loc[words_final['use_position'].between(1, 6)]
words_final = words_final[['kanji', 'main_spelling', 'main_reading', 'meaning', 'use_position']]
words_final = words_final.sort_values(['kanji', 'use_position']).copy()

words_final['use_position'] = words_final['use_position'].astype(int)

words_final['front'] = words_final.apply(lambda row: f"{row['use_position']}. {row['main_spelling']}", axis=1)
words_final['back'] = words_final.apply(
    lambda row: f"{row['use_position']}. {row['main_reading']}, {row['meaning']}", axis=1)

words_final = words_final[['kanji', 'use_position', 'front', 'back']]

words_final = pd.pivot(words_final, index='kanji', columns=['use_position']).reset_index()
words_final.columns = [f'{col[0]}_{col[1]}' for col in words_final.columns.values]
words_final = words_final.rename({'kanji_': 'kanji'}, axis=1)

words_final.head()

# %%
supplement = supplement.merge(words_final, on='kanji', how='left').copy()

# %% [markdown]
# ### Add the link to the stroke order diagram
# InDesign requires an `@` in front of the column name if it's an image.

# %%
supplement['@stroke_order_diagram'] = (
    supplement['kanji'].apply(lambda k: f'/Users/gabriele/Code/kanji/data/wr_old_supplements/stroke_order_{k}.jpg')
)

# %% [markdown]
# ### Export the final file
# InDesign requires `UTF-16` encoding for all the Japanese characters to work.

# %%
supplement.loc[supplement['kanji'] == '虞', 'kunyomi'] = 'おそれ'

# %%
supplement.head()

# %%
supplement.to_csv(f'./data/wr_old_supplements/{filename}_supplement.csv', index=False, encoding='UTF-16')
