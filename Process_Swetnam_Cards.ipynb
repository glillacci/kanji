# %% [markdown]
# # Process Swetnam Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_LESSON = 13

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'swetnam_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'swetnam_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#        greek remarks_greek                              italian  \
# 102  ἄμπελος        -ου, ἡ                                 vite
# 15     ἅγιος       -α, -ον                         santo, sacro
# 36       ἀπό           NaN                         (lontano) da
# 136    ἀκούω           NaN  ascolto, sento; presto attenzione a
# 145     ἀλλά           NaN                                   ma
#
#                              remarks_italian part_of_speech  lesson
# 102                                      NaN     sostantivo       8
# 15                                       NaN      aggettivo       2
# 36                         regge sempre gen.   preposizione       4
# 136  oggetto con gen. (più frequente) o acc.          verbo      10
# 145                                   non δέ   congiunzione      10

# %%
df_grammar = df_grammar.loc[df_grammar['lesson'] <= MAX_LESSON].copy()
df_grammar['lesson'] = df_grammar['lesson'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                         prompt remarks_prompt   answer remarks_answer  lesson  \
# 111          gloria (gen. sg.)         ἡ δόξα    δόξης            NaN       4
# 515  egli stesso (dat. n. sg.)         ἑαυτοῦ    ἑαυτῷ            NaN      12
# 200       questo (gen. m. pl.)          οὗτος   τούτων            NaN       5
# 486            mese (dat. pl.)          ὁ μήν  μησί(ν)       μησῐ́(ν)      12
# 506    tu stesso (dat. m. sg.)        σεαυτοῦ   σεαυτῷ            NaN      12
#
#                                                  topic
# 111                       declinazione di δόξα [Sst 3]
# 515                             declinazione di ἑαυτοῦ
# 200                  declinazione di οὗτος [Agg 1 Prn]
# 486  terza declinazione, temi in -ν- con vocale inv...
# 506                            declinazione di σεαυτοῦ

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['greek'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, lesson, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'greek', 'remarks_greek', 'italian', 'remarks_italian',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                            id    greek remarks_greek  \
# 150  3ad2fac7066f73d6b4071e80198844ef94be3864    κράζω    fut. κράξω
# 40   bc79346e2df4e9a2e8418b953007f0d7590e91b2       γῆ        -ῆς, ἡ
# 114  98685c2c22a49f03d7621858ee55cceb8aa0df31    γράφω           NaN
# 109  1ca59cabb0f27582548b7fe3c2e1d825b2b3dc27    αὐτός    αὐτή, αὐτό
# 6    161bf406ec792441f1477453f0658efd0dbbc573  ἀδελφός        -οῦ, ὁ
# 39   cbac3921c4b231ef154b0c1a905c59fbd447a80d    ἀγάπη        -ης, ἡ
# 106  8f24ed99e370bb645745621fcdc3b8203db2fe51    νόσος        -ου, ἡ
# 20   5582ec262a37f56a08c538dd01f3222ee36c960a      οὐχ           NaN
# 174  b0d3621a2c603deb12fe1f6e26b15d388e9a83f5   χειμών   χειμῶνος, ὁ
# 44   9d5d7cc93db6b1feff2fd392d2dcb294ffddccfb  ἁμαρτία        -ας, ἡ
#
#                                         italian  \
# 150                   grido, urlo, alzo la voce
# 40                        terra; paese, regione
# 114                                      scrivo
# 109                      egli; stesso; medesimo
# 6    fratello, parente, consanguineo, congiunto
# 39                                        amore
# 106                         malattia, infermità
# 20     non (davanti a vocale con spirito aspro)
# 174                             inverno; bufera
# 44                       peccato; colpa; errore
#
#                               remarks_italian part_of_speech  lesson  \
# 150                                       NaN          verbo      11
# 40                                        NaN     sostantivo       4
# 114                                       NaN          verbo       9
# 109                                       NaN        pronome       8
# 6                                         NaN     sostantivo       2
# 39                                        NaN     sostantivo       4
# 106                                       NaN     sostantivo       8
# 20   negazione usata con verbi all'indicativo          altra       2
# 174                                       NaN     sostantivo      12
# 44                                        NaN     sostantivo       4
#
#     last_updated_on
# 150      2022-09-04
# 40       2022-09-04
# 114      2022-09-04
# 109      2022-09-04
# 6        2022-09-04
# 39       2022-09-04
# 106      2022-09-04
# 20       2022-09-04
# 174      2022-09-04
# 44       2022-09-04

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'lesson', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                            id                        prompt  \
# 501  d11a3f26e8aade9b6b7200a43762f80ea504f5bb       io stesso (dat. f. sg.)
# 343  13936a004408c60a3427147103b427dce5d4bff0  colui che sarà (gen. n. pl.)
# 31   5bcd07716270f2de292cde0f439f4dd17ce929ef             parola (voc. sg.)
# 171  7c60dacee4e19c84f5c21df5b218fe0e0a1e93bb           buono (gen. f. pl.)
# 157  a22f0028b5d39c55480e7fdf83aa9b4d2525494a           buono (gen. n. sg.)
# 378  d7c4bcf322054ba8257bbca7b3e270fb9e04a9bf              carne (dat. sg.)
# 422  d05e9aab0e132944bc4c852a493d3e014be0de72              arabo (acc. pl.)
# 184  058a7c5e99a6ecb659279d5b8a22f8ef98ca4770              (che essi) siano
# 552  8ce1cb04d1196ed21d54791aed46e94037a2071e            oratore (dat. pl.)
# 483  aabd1fb4ba202884618779ff588164feecbf1f1f               mese (nom. pl.)
#
#     remarks_prompt      answer remarks_answer  lesson  \
# 501        ἐμαυτοῦ      ἐμαυτῇ            NaN      12
# 343       ἐσόμενος    ἐσομένων            NaN       8
# 31         ὁ λόγος        λόγε            NaN       2
# 171         ἀγαθός      ἀγαθῶν            NaN       4
# 157         ἀγαθός      ἀγαθοῦ            NaN       4
# 378        ἡ σᾰ́ρξ       σαρκί         σᾰρκῐ́       8
# 422       ὁ Ắρᾰψ      Ἄραβας       Ắρᾰβᾰς      10
# 184           εἰμί      ὦσι(ν)            NaN       5
# 552        ὁ ῥήτωρ  ῥήτορσι(ν)     ῥήτορσῐ(ν)      13
# 483          ὁ μήν       μῆνες            NaN      12
#
#                                                  topic last_updated_on
# 501                            declinazione di ἐμαυτοῦ      2022-09-04
# 343                          participio futuro di εἰμί      2022-09-04
# 31                      declinazione di λόγος [Sst 6m]      2022-09-04
# 171                     declinazione di ἀγαθός [Agg 1]      2022-09-04
# 157                     declinazione di ἀγαθός [Agg 1]      2022-09-04
# 378                      declinazione di σάρξ [Sst 8f]      2022-09-04
# 422                      declinazione di Ἄραψ [Sst 12]      2022-09-04
# 184                       congiuntivo presente di εἰμί      2022-09-04
# 552  terza declinazione, temi in -ρ- con vocale var...      2022-09-04
# 483  terza declinazione, temi in -ν- con vocale inv...      2022-09-04

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_swetnam_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 192

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_swetnam_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 569
