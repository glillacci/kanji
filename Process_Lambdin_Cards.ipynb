# %% [markdown]
# # Process Lambdin Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_VOCAB_LESSON = 42
MAX_GRAMMAR_PARAGRAPH = 156

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_VOCAB_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#          hebrew remarks_hebrew              english  remarks_english  \
# 487        שָׁת        יָשִׁית   to put, place, set  synonym of שָׂם
# 407       עֳנִי            NaN           affliction              NaN
# 165      אֵימָה            NaN  fear, terror, dread              NaN
# 274   מִחוּץ לְ            NaN  on (the) outside of              NaN
# 243  שַׁבָּתוֹת            NaN             sabbaths       irreg. pl.
#
#     part_of_speech  lesson
# 487           verb      32
# 407           noun      27
# 165           noun      13
# 274         phrase      20
# 243           noun      18

# %%
df_grammar = df_grammar.loc[df_grammar['paragraph'] <= MAX_GRAMMAR_PARAGRAPH].copy()
df_grammar['paragraph'] = df_grammar['paragraph'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                                   prompt remarks_prompt     answer  \
# 1049                    let him be light            קלל      יֵקַל
# 209                   you (f. pl.) built            בנה  בְּנִיתֶן
# 849               they (m. pl.) will sit           ישׁב   יֵשְׁבוּ
# 988              you (m. sg.) will place           שׂים   תָּשִׂים
# 263   from them (f. pl.), longer version            מִן  מֵהֵֿנָּה
#
#      remarks_answer  paragraph  \
# 1049            NaN        126
# 209             NaN         57
# 849             NaN        120
# 988             NaN        124
# 263             NaN         65
#
#                                                   topic
# 1049  imperfect and imperative of geminate verbs, ty...
# 209                              perfect of verbs III-ה
# 849   imperfect and related forms of verbs I-י, type...
# 988    imperfect and related forms of hollow verbs II-י
# 263                        מִן with pronominal suffixes

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['hebrew'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, paragraph, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'hebrew', 'remarks_hebrew', 'english', 'remarks_english',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                            id       hebrew remarks_hebrew  \
# 311  08e926cb179a454de259a9c7ec5b08b13b2c21a1        חָרָה            NaN
# 580  d2323c43b9e4c8c0b731f87b0013bf8195e20fca       נִצַּב     no imperf.
# 75   1ed5efd53754ae701314dc4330c478303b5a6623      שֹׁלֵחַ            NaN
# 484  676ed462ef630c2d754c5dc95fd54adecfad62ca       סָרִיס            NaN
# 418  8c04897e78cf28494c2be54b6156542c6d0313f2        אָסַף        יֶאֱסֹף
# 642  ef6d6ee2904155ee214e1b82fc1885568f6afaec        עָוֹן            NaN
# 461  0219370af19e882f4748cdf05722923bb9f14c6a       טֶֿרֶם            NaN
# 378  736af7c21fc36fa5a068a97659fc4df6fea5c188    בַּעֲבוּר            NaN
# 179  557238b1de7d741f5002d1d18ea0bc50e4e2ea27         שָׂם            NaN
# 607  f6c6b32b14e426f38dbe12ab31eb307df7c82154  וַיְגָֿרֶשׁ            NaN
#
#                                         english            remarks_english  \
# 311                             to become angry  used impersonally with לְ
# 580  to station oneself, stand; to be stationed                        NaN
# 75                                      sending                        NaN
# 484                             eunuch, officer                        NaN
# 418                                   to gather                  not קָבַץ
# 642                 guilt, iniquity; punishment                    pl. -ôṯ
# 461                        before (without בְּ)      followed by imperfect
# 378                 for the sake of, because of             not עַל־דְּבַר
# 179                          to put, set, place                        NaN
# 607                           and he drove away                        NaN
#
#     part_of_speech  lesson last_updated_on
# 311           verb      21      2022-03-20
# 580           verb      38      2022-03-20
# 75            verb       6      2022-03-20
# 484           noun      32      2022-03-20
# 418           verb      28      2022-03-20
# 642           noun      42      2022-03-20
# 461    preposition      30      2022-03-20
# 378    preposition      24      2022-03-20
# 179           verb      14      2022-03-20
# 607           verb      40      2022-03-20

# %%
df_grammar.columns
# Out:
# Index(['prompt', 'remarks_prompt', 'answer', 'remarks_answer', 'paragraph',
#        'topic', 'id', 'last_updated_on'],
#       dtype='object')

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'paragraph', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                             id  \
# 1024  c1511c6c757a132c189b70920873151dc49216e2
# 795   875ee16b73e21d02482eb0359f834a22498224ac
# 608   b42b1ef5963689f6efd68dc185689812f7f2a4cf
# 1351  841befc0184535fa59d120c02f72eb1b8369beb9
# 1017  cdcafb85fcdb7eef38b7b65db65ed860ae8e2d70
# 1257  9a47fcb736f1b25f77476b8a6066f513a8af349c
# 883   a642e38cf0720cf8896ed824da81923fe3ef3835
# 85    3bd74e13c2d699edd1c7f9868f9281927a442f4d
# 1332  1ec4c5e65531708868f7a0fe46dcb04a676739ac
# 916   d5406292bdce0b0f04931ce3eb858f6398f2d3b6
#
#                                                  prompt remarks_prompt  \
# 1024                       they (m. pl.) will go around            סבב
# 795                              you (f. sg.) will fall            נפל
# 608                                   and I shall write            כתב
# 1351  (is) praising (f. sg., form with ultimate stress)            הלל
# 1017                             become light! (m. sg.)            אור
# 1257                                      my being firm            כון
# 883                                   inherit! (f. sg.)           ירשׁ
# 85                                           to {in} me       לְ {בְּ}
# 1332                   (is) filling (f. sg., form in ה)            מלא
# 916                                      we shall build            בנה
#
#             answer remarks_answer  paragraph  \
# 1024     יָסֹֿבּוּ            NaN        126
# 795      תִּפְּלִי            NaN        118
# 608   וְכָתַבְתִּי            NaN         98
# 1351    מְהַלְּלָה            NaN        151
# 1017          אוֹר            NaN        124
# 1257     הִכּוֹנִי            NaN        146
# 883         רְשִׁי            NaN        120
# 85             לִי         {בִּי}         38
# 1332    מְמַלְּאָה            NaN        151
# 916        נִבְנֶה            NaN        122
#
#                                                   topic last_updated_on
# 1024  imperfect and imperative of geminate verbs, ty...      2022-03-20
# 795   imperfect and related forms of verbs I-נ, type...      2022-03-20
# 608                   stress shift in converted perfect      2022-03-20
# 1351                 piel conjugation of geminate roots      2022-03-20
# 1017  imperfect and related forms of hollow verbs wi...      2022-03-20
# 1257                 niphal conjugation of hollow roots      2022-03-20
# 883   imperfect and related forms of verbs I-י, type...      2022-03-20
# 85                  בְּ and לְ with pronominal suffixes      2022-03-20
# 1332                    piel conjugation of roots III-א      2022-03-20
# 916          imperfect and related forms of verbs III-ה      2022-03-20

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 649

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 1390
