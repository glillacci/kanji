# %% [markdown]
# # Process Lambdin Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_VOCAB_LESSON = 53
MAX_GRAMMAR_PARAGRAPH = 191

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_VOCAB_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#         hebrew remarks_hebrew                english remarks_english  \
# 806  תְּפִלָּה            NaN                 prayer         pl. -ôṯ
# 772     שָׁכַן      יִשְׁכֹּן  to settle down, dwell             NaN
# 422        אֵם            NaN                 mother         pl. -ôṯ
# 231  חֲמִישִׁי            NaN             fifth (m.)             NaN
# 87     עָשִׁיר            NaN                   rich             NaN
#
#     part_of_speech  lesson
# 806           noun      50
# 772           verb      49
# 422           noun      28
# 231      adjective      17
# 87       adjective       7

# %%
df_grammar = df_grammar.loc[df_grammar['paragraph'] <= MAX_GRAMMAR_PARAGRAPH].copy()
df_grammar['paragraph'] = df_grammar['paragraph'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                                  prompt remarks_prompt            answer  \
# 279                    they went around            סבב           סָבֲבוּ
# 1698  you (f. pl.) will kill yourselves            קטל  תִּתְקַטֵּֿלְנָה
# 1917            I observed you (m. sg.)   שָׁמַֿרְתִּי    שְׁמַרְתִּֿיךָ
# 1407      you (f. pl.) will exterminate           שׁמד    תַּשְׁמֵֿדְנָה
# 495             you (f. sg.) are afraid            ירא            יָרֵאת
#
#      remarks_answer  paragraph  \
# 279             NaN         68
# 1698            NaN        177
# 1917            NaN        189
# 1407            NaN        158
# 495             NaN         87
#
#                                                   topic
# 279                           perfect of geminate verbs
# 1698                          basic hithpael imperfect
# 1917  object suffixes on the remaining forms of the ...
# 1407                            basic hiphil imperfect
# 495                            perfect of stative verbs

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['hebrew'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, paragraph, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'hebrew', 'remarks_hebrew', 'english', 'remarks_english',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                            id      hebrew remarks_hebrew  \
# 690  8f829fce5097f699705aa1307c876af1b2285597    הוֹשִׁיב            NaN
# 475  bf6375c3ccf66c2db5c48c6d239ec19911c16120      עַתָּה            NaN
# 522  af7e7b29ba81c59b7d3c68c37ffacdb5d5e0c449      שָׂפָה            NaN
# 625  5a4a16a4c826eb7cc4e1e549179393f1ab395a50      קָשַׁר       יִקְשֹׁר
# 853  57fcf87534b73f498a4305d27cbd36c2ba8dcd3e   כִּבְשָׂה            NaN
# 843  7b3c53fc35f1fcceaa99a7debcd7fb58674a3b34       רָמָה            NaN
# 314  3ed9dbaf7df21793cd1fbb45247fcd7d0bed91ae      קַֿיִן            NaN
# 673  deb049eaefdbf7be4c7848b3df2d2b61e3a7c231      נִצַּל            NaN
# 285  54d2f3df3ab9c0cfd0928608092db20ac5224367  פָּרָשִׁים            NaN
# 276  21dad3f52ea11d1b619aefb96be82d345ae11f4b    חֲיָלִים            NaN
#
#                                                english  \
# 690  to cause to dwell; to settle (someone in a place)
# 475                             now, and so then, then
# 522                                lip; edge, language
# 625                   to bind, band together, conspire
# 853                                      lamb (female)
# 843                                              Ramah
# 314                                               Cain
# 673                                      to be rescued
# 285                                           horsemen
# 276                                          strengths
#
#                                        remarks_english part_of_speech  lesson  \
# 690                                         cf. יָשַׁב           verb      45
# 475                                                NaN         adverb      31
# 522                                                NaN           noun      34
# 625  + עַל + אֶת = to bind something to something; ...           verb      41
# 853                                            pl. -ôṯ           noun      53
# 843  town in the hill country of Ephraim, home of S...    proper name      52
# 314                                                NaN           noun      21
# 673                                                NaN           verb      43
# 285                                         irreg. pl.           noun      20
# 276                            from חַֿיִל, irreg. pl.           noun      20
#
#     last_updated_on
# 690      2022-08-11
# 475      2022-08-11
# 522      2022-08-11
# 625      2022-08-11
# 853      2022-08-11
# 843      2022-08-11
# 314      2022-08-11
# 673      2022-08-11
# 285      2022-08-11
# 276      2022-08-11

# %%
df_grammar.columns
# Out:
# Index(['prompt', 'remarks_prompt', 'answer', 'remarks_answer', 'paragraph',
#        'topic', 'id', 'last_updated_on'],
#       dtype='object')

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'paragraph', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                             id                   prompt  \
# 613   987684b828324efd9d3f334661bbd0f68087a322      your (m. pl.) kings
# 1310  a40cc339bf796828ab08b6be550dfeafdec95f82                expelling
# 1701  415cfc41a52f706a169d58565f3cbecf885dfe6c  kill (f. sg.) yourself!
# 1271  0d85a67887689f26d657200eaa9cbbf767955c6b         being surrounded
# 481   0403d0ad622b63be7d73f48c2788dc1798f1e153                  my sons
# 250   e94b58cf67720cf0bee692bce7c3a4e5b2be268c         arising (f. sg.)
# 206   1a824b443d026e58aa1cb9d2c763a7b2017c986a                  I built
# 164   63be4967a54228ecbc75f3608452c25ec4d0280d                  he gave
# 271   7c74660566fde6a94e9feb72bf7e24b6206b793f        like you (f. pl.)
# 1656  833861ae6e7a7f7af035c892c35506e194a7bd3e     he will be presented
#
#      remarks_prompt        answer remarks_answer  paragraph  \
# 613        מְלָכִים    מַלְכֵיכֶם            NaN         99
# 1310           שׁלח       שַׁלַּח            NaN        149
# 1701            קטל  הִתְקַטְּלִי            NaN        177
# 1271            סבב        הִסֵּב            NaN        146
# 481         בָּנִים        בָּנַי            NaN         85
# 250             קום         קָמָה            NaN         64
# 206             בנה    בָּנִֿיתִי            NaN         57
# 164             נתן         נָתַן            NaN         49
# 271             כְּ        כָּכֶן            NaN         65
# 1656            מצא       יָמְצָא            NaN        175
#
#                                          topic last_updated_on
# 613                                 segholates      2022-08-11
# 1310    piel conjugation of roots III-guttural      2022-08-11
# 1701                basic hithpael imperative       2022-08-11
# 1271      niphal conjugation of geminate roots      2022-08-11
# 481       plural noun with pronominal suffixes      2022-08-11
# 250          active participle of hollow verbs      2022-08-11
# 206                     perfect of verbs III-ה      2022-08-11
# 164                           perfect of נָתַן      2022-08-11
# 271               כְּ with pronominal suffixes      2022-08-11
# 1656  hophal conjugation of hollow roots III-א      2022-08-11

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 869

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 1967
