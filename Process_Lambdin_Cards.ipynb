# %% [markdown]
# # Process Lambdin Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_VOCAB_LESSON = 55
MAX_GRAMMAR_PARAGRAPH = 195

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_VOCAB_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#         hebrew remarks_hebrew                                 english  \
# 15     נָשִׁים            NaN                                   women
# 710  מִמַּֿעַל            NaN                                   above
# 137     בָּרָא            NaN                               to create
# 730      זָנָה        יִזְנֶה     to be a prostitute; to act wantonly
# 558    נֶאֱמַן        יֵאָמֵן  to be confirmed, verified, trustworthy
#
#     remarks_english part_of_speech  lesson
# 15       irreg. pl.           noun       2
# 710    + לְ = prep.         adverb      45
# 137             NaN           verb      11
# 730             NaN           verb      47
# 558             NaN           verb      37

# %%
df_grammar = df_grammar.loc[df_grammar['paragraph'] <= MAX_GRAMMAR_PARAGRAPH].copy()
df_grammar['paragraph'] = df_grammar['paragraph'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                                                  prompt    remarks_prompt  \
# 376                                       lands (cstr.)          אֲרָצוֹת
# 1277                            you (m. sg.) brought up               גדל
# 2025  he will mention you (m. sg., without linking e...           יַרְאֶה
# 526              your (m. sg.) brother {father - mouth}  אָח {אָב – פֶּה}
# 331                                       death (cstr.)            מָֿוֶת
#
#             answer        remarks_answer  paragraph  \
# 376       אַרְצוֹת                   NaN         79
# 1277  גִּדַּֿלְתָּ                   NaN        149
# 2025      יַרְאֲךָ                   NaN        192
# 526       אָחִֿיךָ  {אָבִֿיךָ – פִּֿיךָ}         88
# 331           מוֹת                   NaN         75
#
#                                                   topic
# 376   construct plural of disyllabic nouns with penu...
# 1277                                 basic piel perfect
# 2025                   object suffixes on the imperfect
# 526                                nouns פֶּה ,אָח ,אָב
# 331   construct singular of nouns of the type בַּֿיִ...

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['hebrew'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, paragraph, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'hebrew', 'remarks_hebrew', 'english', 'remarks_english',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                            id      hebrew remarks_hebrew  \
# 598  7fefa51d35c16fa92f3f215961963700cdc7a7b0     קִדֵּשׁ      יְקַדֵּשׁ
# 730  3222439aae508f44433cef01cd0ad42ddf956117       זָנָה        יִזְנֶה
# 805  8d30dc12bc3a0ae455dd92f237de1b32aa3b60db      עֻזִּי            NaN
# 896  700167d05bc48ab0f9787f9ced9600d525815d8e   פִּשְׁעִי            NaN
# 484  676ed462ef630c2d754c5dc95fd54adecfad62ca      סָרִיס            NaN
# 96   6934ddbf6de28580d1d4c25e282096f64554ec8c       עֹלֶה            NaN
# 383  ab697cbe6ed04ec59d6107acbacb4a9c6a896a3f      עֵֿדֶר            NaN
# 685  0739ab8d22044e6475eebda10b9b2b787a35751f      מַטֶּה            NaN
# 285  54d2f3df3ab9c0cfd0928608092db20ac5224367  פָּרָשִׁים            NaN
# 465  a03c6e4b581437c395fc2f398bacd4f99237170e       בּוֹר            NaN
#
#                                  english remarks_english part_of_speech  \
# 598                          to sanctify     cf. קָדוֹשׁ           verb
# 730  to be a prostitute; to act wantonly             NaN           verb
# 805              my strength (form in u)        from עֹז           noun
# 896                     my transgression             NaN           noun
# 484                      eunuch, officer             NaN           noun
# 96                   ascending, going up             NaN           verb
# 383                          flock, herd         pl. -îm           noun
# 685                    staff, rod; tribe         pl. -ôṯ           noun
# 285                             horsemen      irreg. pl.           noun
# 465       pit, cistern; (fig.) the grave         pl. -ôṯ           noun
#
#      lesson last_updated_on
# 598      40      2022-09-13
# 730      47      2022-09-13
# 805      50      2022-09-13
# 896      55      2022-09-13
# 484      32      2022-09-13
# 96        8      2022-09-13
# 383      25      2022-09-13
# 685      44      2022-09-13
# 285      20      2022-09-13
# 465      31      2022-09-13

# %%
df_grammar.columns
# Out:
# Index(['prompt', 'remarks_prompt', 'answer', 'remarks_answer', 'paragraph',
#        'topic', 'id', 'last_updated_on'],
#       dtype='object')

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'paragraph', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                             id  \
# 1856  f43c24d6d9744e6c27642274a7100ac0dbafae7d
# 297   e9a4f3071e4158433ec97970d10c04cb6e3022e3
# 862   86bc421699665101036ab033dd49346e9993632f
# 1375  151ddb496526f49c1060f7156b2501ac0fcf6d25
# 1200  7bd0f8ff559c35abf0eaac169a8b65c43d496f54
# 1211  496d4c274c6ce16e39017a31ef21aad4abd76935
# 402   6f89cc7c0d0995b6945fd4b5ef6c6beee2991682
# 1246  06330f12634a8646663b65c871feb3381148f2bc
# 759   2628c5d95192caa1aae804527fc530dc8508444a
# 613   987684b828324efd9d3f334661bbd0f68087a322
#
#                               prompt remarks_prompt       answer  \
# 1856           you (m. sg.) found me       מָצָֿאתָ  מְצָאתַֿנִי
# 297                         with her            עִם      עִמָּהּ
# 862             knowing (inf. cstr.)            ידע      דַּֿעַת
# 1375  (are) being magnified (f. pl.)            גדל  מְגֻדָּלוֹת
# 1200            between you (f. sg.)          בֵּין     בֵּינֵךְ
# 1211               be born! (m. sg.)            ילד     הִוָּלֵד
# 402              toward you (f. pl.)            אֶל     אֲלֵיכֶן
# 1246          you (m. sg.) were firm            כון  נְכוּנֿוֹתָ
# 759                    my affliction          עֳנִי      עָנְיִי
# 613              your (m. pl.) kings       מְלָכִים   מַלְכֵיכֶם
#
#      remarks_answer  paragraph  \
# 1856            NaN        186
# 297             NaN         69
# 862             NaN        120
# 1375            NaN        154
# 1200            NaN        142
# 1211            NaN        143
# 402             NaN         83
# 1246            NaN        146
# 759             NaN        112
# 613             NaN         99
#
#                                                   topic last_updated_on
# 1856            object suffixes on the perfect 2 m. sg.      2022-09-13
# 297                        עִם with pronominal suffixes      2022-09-13
# 862   imperfect and related forms of verbs I-י, type...      2022-09-13
# 1375                              basic pual participle      2022-09-13
# 1200                     בֵּין with pronominal suffixes      2022-09-13
# 1211                    niphal conjugation of roots I-י      2022-09-13
# 402                        אֶל with pronominal suffixes      2022-09-13
# 1246                 niphal conjugation of hollow roots      2022-09-13
# 759                            nouns of the type פְּרִי      2022-09-13
# 613                                          segholates      2022-09-13

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 900

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 2054
