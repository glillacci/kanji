# %% [markdown]
# # Process Lambdin Cards for Anki

# %%
import datetime as dt
import hashlib
import os
import pandas as pd

# %%
MAX_VOCAB_LESSON = 44
MAX_GRAMMAR_PARAGRAPH = 159

# %%
PATH_TO_FILES = '/Users/gabriele/Library/Mobile Documents/com~apple~CloudDocs/Anki/'

df_vocab = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_vocab.csv'))
df_grammar = pd.read_csv(os.path.join(PATH_TO_FILES, 'lambdin_grammar.csv'))

# %%
df_vocab = df_vocab.loc[df_vocab['lesson'] <= MAX_VOCAB_LESSON].copy()
df_vocab['lesson'] = df_vocab['lesson'].astype(int)

# %%
df_vocab.sample(n=5)
# Out:
#         hebrew      remarks_hebrew                      english  \
# 197  כַּאֲשֶׁר                 NaN       as, according as, when
# 581    נִפְלָא            יִפָּלֵא  to be wonderful, marvellous
# 661    הִצִּיל  יַצִּיל – root נצל           to rescue, deliver
# 544   אֲמִתִּי                 NaN                     my truth
# 113   בְּתוֹךְ                 NaN              in the midst of
#
#     remarks_english part_of_speech  lesson
# 197             NaN    conjunction      15
# 581             NaN           verb      38
# 661             NaN           verb      43
# 544             NaN           noun      36
# 113             NaN    preposition       9

# %%
df_grammar = df_grammar.loc[df_grammar['paragraph'] <= MAX_GRAMMAR_PARAGRAPH].copy()
df_grammar['paragraph'] = df_grammar['paragraph'].astype(int)

# %%
df_grammar.sample(n=5)
# Out:
#                             prompt remarks_prompt       answer  \
# 1319              refuse! (m. sg.)            מאן        מָאֵן
# 12                           kings        מֶֿלֶךְ     מְלָכִים
# 1056  they (m. pl.) will go around            סבב   יִסֹּֿבּוּ
# 459                    my judgment      מִשְׁפָּט  מִשְׁפָּטִי
# 556                 we shall write            כתב     נִכְתֹּב
#
#                      remarks_answer  paragraph  \
# 1319                            NaN        149
# 12                              NaN         19
# 1056  also with reduction: יִסְּבוּ        126
# 459                             NaN         85
# 556                             NaN         90
#
#                                                   topic
# 1319  piel conjugation of roots II-guttural with com...
# 12    plural of disyllabic nouns with penultimate st...
# 1056  imperfect of geminate verbs following the I-נ ...
# 459              singular noun with pronominal suffixes
# 556                                           imperfect

# %%
def create_unique_id(word):
    return hashlib.sha1(word.encode('utf-8')).hexdigest()

# %%
df_vocab['id'] = (df_vocab['hebrew'] + ' ' + df_vocab['lesson'].astype(str)).apply(create_unique_id)

assert df_vocab['id'].duplicated().sum() == 0

# %%
df_vocab['last_updated_on'] = str(dt.date.today())

# %%
df_grammar['id'] = (df_grammar['answer'] + ' ' + df_grammar['prompt'].astype(str)).apply(create_unique_id)

assert df_grammar['id'].duplicated().sum() == 0

# %%
df_grammar.loc[df_grammar['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [prompt, remarks_prompt, answer, remarks_answer, paragraph, topic, id]
# Index: []

# %%
df_grammar['last_updated_on'] = str(dt.date.today())

# %%
df_vocab = df_vocab[['id', 'hebrew', 'remarks_hebrew', 'english', 'remarks_english',
                     'part_of_speech', 'lesson', 'last_updated_on']]

# %%
df_vocab.sample(n=10)
# Out:
#                                            id                    hebrew  \
# 287  7c2cd63f328cb2ad037148b15d009df74ca4b326                     צְבָא
# 355  42c8d0ee3c9749ae5e0d2234953f1454e116b133                      לוֹט
# 549  cf898cdb05e283333bcffae7de45a0849326c537  חֵי פַרְעֹה אִם תֵּצְאוּ
# 64   36500858c624f31550e6eca00ac2df31370a0cb7                    רָשָׁע
# 643  ca07a2dc9659449a1f1aad88f1bae4f5d1c1f1ff                  מַדּוּעַ
# 592  53c972acc41a22b3cc8e7115e71b8606ce2d316a                       נָם
# 478  ee5ebba0441c2f54bc368d8f538b3e0a804e83ed                  רְאוּבֵן
# 152  a580922ff0b2a778a792ded2b1c313f18a8b45bf                       אֵת
# 70   b2cfb5423f46e70fbcf4f9b3a4ecfde2c98b2f30                      קוֹל
# 154  59bcecf7bdec6fcce7a039325372603c728d697b       מָצָא חֵן בְּעֵינֵי
#
#     remarks_hebrew                                    english  \
# 287            NaN                                       army
# 355            NaN                                        Lot
# 549            NaN  as the Pharaoh lives, you shall not leave
# 64             NaN                        evil, bad, criminal
# 643            NaN                      why? for what reason?
# 592         יָנוּם                                   to sleep
# 478            NaN                                     Reuben
# 152            NaN                            (together) with
# 70             NaN                                      voice
# 154            NaN                         to find favor with
#
#                        remarks_english part_of_speech  lesson last_updated_on
# 287                       irreg. cstr.           noun      20      2022-04-22
# 355                   Abraham’s nephew    proper name      23      2022-04-22
# 549                           with חֵי         phrase      36      2022-04-22
# 64                                 NaN      adjective       5      2022-04-22
# 643                                NaN         adverb      42      2022-04-22
# 592                         not יָשֵׁן           verb      39      2022-04-22
# 478  first-born son of Jacob (by Leah)    proper name      31      2022-04-22
# 152            not עִם, without מַקֵּף    preposition      12      2022-04-22
# 70                             pl. -ôṯ           noun       6      2022-04-22
# 154                                NaN         phrase      12      2022-04-22

# %%
df_grammar.columns
# Out:
# Index(['prompt', 'remarks_prompt', 'answer', 'remarks_answer', 'paragraph',
#        'topic', 'id', 'last_updated_on'],
#       dtype='object')

# %%
df_grammar = df_grammar[['id', 'prompt', 'remarks_prompt', 'answer', 'remarks_answer',
                         'paragraph', 'topic','last_updated_on']]

# %%
df_grammar.sample(n=10)
# Out:
#                                             id                prompt  \
# 1030  abe239d792d4b5b78ca94d184c784cc8b5ddfd7f   go around! (f. sg.)
# 868   6fd4d2a3d0cba2a72cf51a58198ed83a33975a92            he will go
# 731   31b492cc56c901662743451e738cdb80013b3c52          he will love
# 1084  d9952654bf80f0f61adfe1c3091669d59d1a09e6      three (m. cstr.)
# 305   def00e61881a2e22ecc8ad5de6d9c8bfc7abbb81     with you (m. sg.)
# 466   52974c8efe955131f4a68c4217d2e15c7e8d93bd    your (m. pl.) year
# 315   e9a1ac52394bb91c9788a6966e525bbbb37e8a6e         place (cstr.)
# 743   27e5146657cdea0e0ae7f292013885905eb30115              my shame
# 1174  9532cedfe6b3571a566d80834817a454f967a3cb  be written! (f. sg.)
# 1001  8fe0e8e49dd951255071553b067d97fcbf597dfc               placing
#
#      remarks_prompt      answer remarks_answer  paragraph  \
# 1030            סבב     סֹֿבִּי            NaN        126
# 868             הלך      יֵלֵךְ            NaN        120
# 731             אהב     יֶאֱהַב            NaN        108
# 1084            NaN  שְׁלֹֿשֶׁת            NaN        130
# 305            אֶת־     אִתְּךָ            NaN         69
# 466          שָׁנָה  שְׁנַתְכֶם            NaN         85
# 315          מָקוֹם      מְקוֹם            NaN         73
# 743        בֹּֿשֶׁת  בָּשְׁתִּי            NaN        111
# 1174            כתב  הִכָּתְבִי    הִכָּֽתְבִי        141
# 1001           שׂים       שִׂים            NaN        124
#
#                                                   topic last_updated_on
# 1030  imperfect and imperative of geminate verbs, ty...      2022-04-22
# 868   imperfect and related forms of verbs I-י, type...      2022-04-22
# 731           imperfect of verbs I-א with peculiarities      2022-04-22
# 1084                          numbers from three to ten      2022-04-22
# 305                       אֶת־ with pronominal suffixes      2022-04-22
# 466              singular noun with pronominal suffixes      2022-04-22
# 315              forms of the construct singular rule 1      2022-04-22
# 743                feminine nouns ending in -eṯ and -aṯ      2022-04-22
# 1174                            basic niphal imperative      2022-04-22
# 1001   imperfect and related forms of hollow verbs II-י      2022-04-22

# %%
df_vocab.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_vocab_cards.csv'), index=False, header=False)
len(df_vocab)
# Out:
# 675

# %%
df_grammar.to_csv(os.path.join(PATH_TO_FILES, 'anki_lambdin_grammar_cards.csv'), index=False, header=False)
len(df_grammar)
# Out:
# 1444
