# %% [markdown]
# # Create kanji flashcards

# %%
import datetime
import hashlib
import numpy as np
import pandas as pd

# %%
(datetime.date(2022, 7, 1) - datetime.date.today()).days * 20
# Out:
# 6380

# %%
DATA_PATH = '/Users/glillacci/OneDrive - Tesco/Personal/Data/kanjidata'

# %% [markdown]
# ## Select flashcard set to produce based on grade

# %%
GRADE_SETTINGS = {
    1: '１年生',
    2: '２年生',
    3: '３年生',
    4: '４年生',
    5: '５年生',
    6: '６年生',
    8.1: '常用ー漢検４級',
    8.2: '常用ー漢検３級',
    8.3: '常用ー漢検準２級',
    8.4: '常用ー漢検２級',
    9.1: '人名用ー日本語能力試験１級'
}

SET_NUMBER = 9.1

GRADE = GRADE_SETTINGS[SET_NUMBER]

# %% [markdown]
# ## Load Kanjidic with additional data

# %%
kanji = pd.read_parquet(f'{DATA_PATH}/kanjidic_with_additional_data.parquet')

kanji = kanji[['kanji', 'stroke_count', 'grade', 'jlpt_level', 'onyomi', 'kunyomi',
               'nanori', 'n_onyomi', 'n_onyomi_in_jouyou', 'n_kunyomi', 'n_kunyomi_in_jouyou',
               'n_kunyomi_distinct', 'n_nanori', 'skip_code_corrected', 'kkld_no', 'kkd_no',
               'core_meaning_1', 'core_meaning_2', 'core_meaning_3',
               'radical_element', 'rad_names', 'non_rad_strokes', 'jis_level', 'unicode']]

kanji = kanji.rename({
    'skip_code_corrected': 'skip_code'
}, axis=1)

kanji['jlpt_level'] = kanji['jlpt_level'].fillna(0).astype(int)
kanji['kkld_no'] = kanji['kkld_no'].fillna(0).astype(int)
kanji['kkd_no'] = kanji['kkd_no'].fillna(0).astype(int)

kanji.sample(n=10)
# Out:
#       kanji  stroke_count     grade  jlpt_level          onyomi  \
# 12284     𤎼            16   11(nan)           0            None
# 9247      眯            11   11(nan)           0  [ベイ, マイ, ビ, ミ]
# 2473      幣            15  常用ー漢検準２級           1            [ヘイ]
# 10243     蕐            15   11(nan)           0          [カ, ケ]
# 1969      艇            13  常用ー漢検準２級           1            [テイ]
# 7490      帔             8   11(nan)           0             [ヒ]
# 5494      襁            16   11(1.0)           0           [キョウ]
# 3632      廬            19   11(1.0)           0         [ロ, リョ]
# 9147      瘀            13   11(nan)           0          [ヨ, オ]
# 8266      椸            13   11(nan)           0             [イ]
#
#              kunyomi nanori  n_onyomi  n_onyomi_in_jouyou  n_kunyomi  ...  \
# 12284           None   None         0                   0          0  ...
# 9247          [くる.む]   None         4                   0          1  ...
# 2473          [[ぬさ]]   [しで]         1                   1          1  ...
# 10243           [はな]   None         2                   0          1  ...
# 1969            None   None         1                   1          0  ...
# 7490           [ふくろ]   None         1                   0          1  ...
# 5494           [むつき]   None         1                   0          1  ...
# 3632   [いお, いおり, いえ]   None         2                   0          3  ...
# 9147           [やまい]   None         2                   0          1  ...
# 8266         [ころもかけ]   None         1                   0          1  ...
#
#        kkld_no  kkd_no  core_meaning_1 core_meaning_2  core_meaning_3  \
# 12284        0       0            None           None            None
# 9247         0       0            None           None            None
# 2473      1844    3582        currency           None            None
# 10243        0       0            None           None            None
# 1969       923    1727            boat           None            None
# 7490         0       0            None           None            None
# 5494         0       0            None           None            None
# 3632         0       0            None           None            None
# 9147         0       0            None           None            None
# 8266         0       0            None           None            None
#
#        radical_element rad_names non_rad_strokes jis_level unicode
# 12284             None      None               0         0   243BC
# 9247              None      None               0         0    772F
# 2473                 ⼱        はば              12         1    5E63
# 10243             None      None               0         0    8550
# 1969               「⾈」      ふねへん               7         1    8247
# 7490              None      None               0         0    5E14
# 5494              None      None               0         2    8941
# 3632              None      None               0         2    5EEC
# 9147              None      None               0         0    7600
# 8266              None      None               0         0    6938
#
# [10 rows x 24 columns]

# %%
kanji.columns
# Out:
# Index(['kanji', 'stroke_count', 'grade', 'jlpt_level', 'onyomi', 'kunyomi',
#        'nanori', 'n_onyomi', 'n_onyomi_in_jouyou', 'n_kunyomi',
#        'n_kunyomi_in_jouyou', 'n_kunyomi_distinct', 'n_nanori', 'skip_code',
#        'kkld_no', 'kkd_no', 'core_meaning_1', 'core_meaning_2',
#        'core_meaning_3', 'radical_element', 'rad_names', 'non_rad_strokes',
#        'jis_level', 'unicode'],
#       dtype='object')

# %% [markdown]
# ## Create the desired set of flashcards

# %%
subset = (
    kanji.loc[kanji['grade'] == GRADE]
).copy()

# %% [markdown]
# ## Expand the readings

# %%
def expand_readings(x):
    if x is None:
        return None
    
    if len(x):
        jouyou = []
        non_jouyou = []
        
        for reading in x:
            if '[' in reading:
                non_jouyou.append(reading[1:-1])
            else:
                jouyou.append(reading)

        if len(jouyou) and len(non_jouyou):
            return f"{', '.join(jouyou)}, [{', '.join(non_jouyou)}]"
        elif len(jouyou):
            return ', '.join(jouyou)
        else:
            return f"[{', '.join(non_jouyou)}]"
        
    return None

# %%
subset['onyomi'] = subset['onyomi'].apply(expand_readings)
subset['kunyomi'] = subset['kunyomi'].apply(expand_readings)
subset['nanori'] = subset['nanori'].apply(expand_readings)

# %%
subset
# Out:
#      kanji  stroke_count          grade  jlpt_level       onyomi  \
# 3        阿             8  人名用ー日本語能力試験１級           1         ア, オ
# 9        葵            12  人名用ー日本語能力試験１級           1            キ
# 10       茜             9  人名用ー日本語能力試験１級           1           セン
# 14       渥            12  人名用ー日本語能力試験１級           1           アク
# 15       旭             6  人名用ー日本語能力試験１級           1          キョク
# ...    ...           ...            ...         ...          ...
# 6055     頌            13  人名用ー日本語能力試験１級           1  ショウ, ジュ, ヨウ
# 6071     颯            14  人名用ー日本語能力試験１級           1       サツ, ソウ
# 6307     黎            15  人名用ー日本語能力試験１級           1        レイ, リ
# 6353     凜            15  人名用ー日本語能力試験１級           1           リン
# 6354     熙            15  人名用ー日本語能力試験１級           1            キ
#
#                                                 kunyomi  \
# 3                                             おもね.る, くま
# 9                                                   あおい
# 10                                                  あかね
# 14                                          あつ.い, うるお.う
# 15                                                  あさひ
# ...                                                 ...
# 6055                                   かたち, たた.える, ほめ.る
# 6071                                               さっ.と
# 6307                                               くろ.い
# 6353                                              きびし.い
# 6354  たのし.む, ひか.る, ひろ.い, よろこ.ぶ, かわ.く, あきらか, ひろ.める, ひ...
#
#                       nanori  n_onyomi  n_onyomi_in_jouyou  n_kunyomi  ...  \
# 3     ほとり, あず, あわ, おか, きた, な         2                   0          2  ...
# 9                     まもる, け         1                   0          1  ...
# 10                      None         1                   0          1  ...
# 14                       あつし         1                   0          2  ...
# 15            あきら, あき, てる, ひ         1                   0          1  ...
# ...                      ...       ...                 ...        ...  ...
# 6055                  つぐ, のぶ         3                   0          3  ...
# 6071                    None         2                   0          1  ...
# 6307                       れ         2                   0          1  ...
# 6353                    None         1                   0          1  ...
# 6354                    None         1                   0          8  ...
#
#       kkld_no  kkd_no         core_meaning_1 core_meaning_2  core_meaning_3  \
# 3         256     408           phonetic [a]           None            None
# 9        1493    2906                 mallow           None            None
# 10       1448    2811                 madder           None            None
# 14        435     731               gracious           None            None
# 15       1890    3697             rising sun           None            None
# ...       ...     ...                    ...            ...             ...
# 6055      715    1319               eulogize           None            None
# 6071      825    1563  sound of gusting wind           None            None
# 6307     1799    3487                  black           None            None
# 6353      126     195          severely cold           None            None
# 6354     1837    3559                 bright           None            None
#
#       radical_element     rad_names non_rad_strokes jis_level unicode
# 3                   ⻖         こざとへん               5         1    963F
# 9                   ⺾        くさかんむり               9         1    8475
# 10                  ⺾        くさかんむり               6         1    831C
# 14                  ⺡          さんずい               9         1    6E25
# 15                  ⽇          ひ・にち               2         1    65ED
# ...               ...           ...             ...       ...     ...
# 6055                ⾴    おおがい・いちのかい               4         2    980C
# 6071                ⾵            かぜ               5         2    98AF
# 6307                ⿉            きび               3         2    9ECE
# 6353                ⼎           にすい              13         2    51DC
# 6354                ⺣  れっか・れんが・よつてん              11         2    7199
#
# [251 rows x 24 columns]

# %% [markdown]
# ## Add unique id

# %%
def create_kanji_id(kanji):
    return hashlib.sha1(kanji.encode('utf-8')).hexdigest()

# %%
subset['id'] = subset['kanji'].apply(create_kanji_id)

# %% [markdown]
# ## Export final results

# %%
subset = subset[['id', 'kanji', 'stroke_count', 'grade', 'jlpt_level', 'onyomi', 'kunyomi',
                 'nanori', 'n_onyomi', 'n_onyomi_in_jouyou', 'n_kunyomi', 'n_kunyomi_in_jouyou',
                 'n_kunyomi_distinct', 'n_nanori', 'skip_code', 'kkld_no', 'kkd_no',
                 'core_meaning_1', 'core_meaning_2', 'core_meaning_3',
                 'radical_element', 'rad_names', 'non_rad_strokes']]

# %%
assert np.sum(subset['id'].duplicated()) == 0

# %%
len(subset)
# Out:
# 251

# %%
subset.sample(n=10)
# Out:
#                                             id kanji  stroke_count  \
# 1284  55e93b8aa7254074ad8b73476e720c8bfc849a3a     淳            11
# 180   071ddf58a8aa38cfcdd22c4360ca2b4f93c8dc02     於             8
# 868   cb2747af180c20566c7b0e28cf16afe6df212c30     昂             8
# 83    d18f0d32937e6118c1ed92b734fdda07edad31c8     允             4
# 1871  3e2d3914a7d30479050e2da9d8bf0bb3070024d1     猪            11
# 2331  38497fe8b31490014540f48cc1478ec944d9c3f6     緋            14
# 2236  6fd777e1bf155d4b9e8b4325ee4ead57c9c3a986     萩            12
# 1186  dc2b0c9c59ec6f268ade294e9700e16063c82155     勺             3
# 2282  18ac806e759d109dc6b1ae3f33107424c8ad2a08     隼            10
# 979   a9174a11a2935f6ecd8152a6c4e72b644e60f4d9     哉             9
#
#               grade  jlpt_level    onyomi             kunyomi  \
# 1284  人名用ー日本語能力試験１級           1  ジュン, シュン                あつ.い
# 180   人名用ー日本語能力試験１級           1      オ, ヨ  おい.て, お.ける, ああ, より
# 868   人名用ー日本語能力試験１級           1    コウ, ゴウ   あ.がる, たか.い, たか.ぶる
# 83    人名用ー日本語能力試験１級           1        イン     じょう, まこと.に, ゆるす
# 1871  人名用ー日本語能力試験１級           1        チョ             い, いのしし
# 2331  人名用ー日本語能力試験１級           1         ヒ              あけ, あか
# 2236  人名用ー日本語能力試験１級           1       シュウ                  はぎ
# 1186  人名用ー日本語能力試験１級           1       シャク                None
# 2282  人名用ー日本語能力試験１級           1  シュン, ジュン                はやぶさ
# 979   人名用ー日本語能力試験１級           1        サイ               かな, や
#
#                                nanori  n_onyomi  n_onyomi_in_jouyou  ...  \
# 1284       あつ, あつし, きよ, きよし, まこと, すなお         2                   0  ...
# 180                              None         2                   0  ...
# 868             あき, あきら, たか, たかし, のぼる         2                   0  ...
# 83    まこと, のぶ, まさ, みつ, すけ, よし, ちか, とも         1                   0  ...
# 1871                               いの         1                   0  ...
# 2331                             None         1                   0  ...
# 2236                                は         1                   0  ...
# 1186                             None         1                   0  ...
# 2282                               はや         2                   0  ...
# 979                か, すけ, とし, ちか, はじめ         1                   0  ...
#
#       n_nanori  skip_code  kkld_no  kkd_no        core_meaning_1  \
# 1284         6      1-3-8      378     626           purehearted
# 180          0      1-4-4      571    1059                    at
# 868          5      2-4-4     1562    3065                  high
# 83           8      2-2-2     1252    2476          give consent
# 1871         1      1-3-8      392     652             wild boar
# 2331         0      1-6-8      925    1732               scarlet
# 2236         1      2-3-9     1495    2908                  hagi
# 1186         0      3-2-1     1863    3650                 shaku
# 2282         1      2-8-2     1766    3427                falcon
# 979          5      3-6-3     2071    4084  exclamatory particle
#
#       core_meaning_2  core_meaning_3 radical_element      rad_names  \
# 1284            None            None               ⺡           さんずい
# 180             None            None             「方」      「ほう・かた」へん
# 868             None            None               ⽇           ひ・にち
# 83              None            None               ⼉     にんにょう・ひとあし
# 1871            None            None               ⺨          けものへん
# 2331            None            None             「糸」           いとへん
# 2236            None            None               ⺾         くさかんむり
# 1186            None            None               ⼓  「つつみ・く・ほう」がまえ
# 2282            None            None               ⾫           ふるとり
# 979             None            None               ⼝             くち
#
#      non_rad_strokes
# 1284               8
# 180                4
# 868                4
# 83                 2
# 1871               8
# 2331               8
# 2236               9
# 1186               1
# 2282               2
# 979                6
#
# [10 rows x 23 columns]

# %%
subset.to_csv(f'{DATA_PATH}/kanji_flashcards_{GRADE}.csv', index=False, header=False)

f'{DATA_PATH}/kanji_flashcards_{GRADE}.csv'
